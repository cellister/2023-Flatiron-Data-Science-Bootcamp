# %% [markdown]
# # Introduction
#
# ## Problem Statement
#
# A company is expanding into new industries to diversify its portfolio. Specifically, they are interested in purchasing and operating airplanes for commercial and private enterprises, but do not know anything about the potential risks of aircrafts. I will be determining which aircrafts are the lowest risk for the company to start this new business endeavor.
#
# I will translate my findings into actionable insights that the head of the new aviation division can use to help decide which aircrafts to purchase.
#
# ## My Approach
#
# I will determine which aircrafts have the lowest risk for a company to begin a new business endeavor. To do this, I will start by investigating data on various makes and models of airplanes and their fatality counts to understand a percentage rate of plane model linked to fatality in plane crashes.
# Next, using that percentage rate and logistical regression models, I’ll explore relationships to plane damage and level of injury in plane investigations to describe a risk.
# I’ll seek to answer the following questions:
# 1.	Which plane model has the lowest rate of fatality? (What plane is a safe choice to limit risk of fatality?)
# 2.	During investigation, which model was found to sustain the least amount of aircraft damage? (Which plane model is the most durable?)
# 3.	What level of injury was found in investigations relating to different plane models? (What plane is a safe choice to limit liability for bodily injuries?)
# 4. FAA regulation liability? Safe Harbor?
# Finally, I will explore two particular aspects of safety:
# 1.	A rank of the number of accidents by month and weather.  Knowing which time of year are accidents more likely to happen as a result of weather, can advise the company on heavy or light scheduling of flights.
# 2.	A look at how the aircraft model correlates to place of accident or incident (broad phase of flight). This could advise which parts of the plane need to be meticulously monitored for performance before and during each flight to prevent investigations.
#
# ## Data Sources
#
# Data for this project was obtained from the following repository and also saved in ZippedData folder in this repositpory.
#
# The data comes from Kaggle, Aviation Accident Database & Synopses, up to 2023.
#
# ## Methodology
#
# The process can be divided into two stages:
#
# A. Data preparation
#     1. Importing libraries
#     2. Reading and cleaning provided data
#     3. Dealing with missing values
#     4. Joining datasets
#     5. Scraping additional data and cleaning it
#
# B. Visualizations and insights
#     1. Creating visualizations
#     2. Drawing conclusions
#     3. Providing recommendations
#
# ## Summary
#
# This final section includes my findings, key actionable insights, suggested future questions to explore, and any limitations.

# %% [markdown]
# Data Preparation

# %%
#import the necessary packages
import pandas as pd
import numpy as np

pd.options.display.max_rows =500
pd.options.display.max_columns =500
np.set_printoptions(threshold=np.inf)#no trunkcated lists

# %% [markdown]
# # Data Provided
#
# Data reading
#
# The data provided is in the ZippedData folder.

# %%
#read in the csv file
aviation_data = pd.read_csv('./AviationData.csv', index_col=0)
aviation_data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 5: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-6e9d716eb56d> in <module>
#       1 #read in the csv file
# ----> 2 aviation_data = pd.read_csv('./AviationData.csv', index_col=0)
#       3 aviation_data.head()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 5: invalid continuation byte

# %%
#Import the 'AviationData.csv' file using a proper encoding
aviation_data = pd.read_csv('./AviationData.csv', index_col=0, header=0, encoding='latin-1')
aviation_data.head()
# Out:
# /Users/Erin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country Latitude Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      NaN       NaN
# 20001218X45447   BRIDGEPORT, CA  United States      NaN       NaN
# 20061025X01555    Saltville, VA  United States  36.9222  -81.8781
# 20001218X45448       EUREKA, CA  United States      NaN       NaN
# 20041105X01764       Canton, OH  United States      NaN       NaN
#
#                Airport.Code Airport.Name Injury.Severity  ...  \
# Event.Id                                                  ...
# 20001218X45444          NaN          NaN        Fatal(2)  ...
# 20001218X45447          NaN          NaN        Fatal(4)  ...
# 20061025X01555          NaN          NaN        Fatal(3)  ...
# 20001218X45448          NaN          NaN        Fatal(2)  ...
# 20041105X01764          NaN          NaN        Fatal(1)  ...
#
#                Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444          Personal         NaN                  2.0
# 20001218X45447          Personal         NaN                  4.0
# 20061025X01555          Personal         NaN                  3.0
# 20001218X45448          Personal         NaN                  2.0
# 20041105X01764          Personal         NaN                  1.0
#
#                Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                    0.0                  0.0             0.0
# 20001218X45447                    0.0                  0.0             0.0
# 20061025X01555                    NaN                  NaN             NaN
# 20001218X45448                    0.0                  0.0             0.0
# 20041105X01764                    2.0                  NaN             0.0
#
#                 Weather.Condition Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                Cruise  Probable Cause
# 20001218X45447                UNK               Unknown  Probable Cause
# 20061025X01555                IMC                Cruise  Probable Cause
# 20001218X45448                IMC                Cruise  Probable Cause
# 20041105X01764                VMC              Approach  Probable Cause
#
#                Publication.Date
# Event.Id
# 20001218X45444              NaN
# 20001218X45447       19-09-1996
# 20061025X01555       26-02-2007
# 20001218X45448       12-09-2000
# 20041105X01764       16-04-1980
#
# [5 rows x 30 columns]

# %% [markdown]
# In this error message I notice that the file may have some corrupt or mixed values. Some missing values are labeled as NA, others as N/A or empty. Values are separated with leading and trailing spaces (in some cases).
#
# I'll conduct an exploratory data analysis to learn more about the data set.

# %%
aviation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Latitude                34382 non-null  object
#  6   Longitude               34373 non-null  object
#  7   Airport.Code            50249 non-null  object
#  8   Airport.Name            52790 non-null  object
#  9   Injury.Severity         87889 non-null  object
#  10  Aircraft.damage         85695 non-null  object
#  11  Aircraft.Category       32287 non-null  object
#  12  Registration.Number     87572 non-null  object
#  13  Make                    88826 non-null  object
#  14  Model                   88797 non-null  object
#  15  Amateur.Built           88787 non-null  object
#  16  Number.of.Engines       82805 non-null  float64
#  17  Engine.Type             81812 non-null  object
#  18  FAR.Description         32023 non-null  object
#  19  Schedule                12582 non-null  object
#  20  Purpose.of.flight       82697 non-null  object
#  21  Air.carrier             16648 non-null  object
#  22  Total.Fatal.Injuries    77488 non-null  float64
#  23  Total.Serious.Injuries  76379 non-null  float64
#  24  Total.Minor.Injuries    76956 non-null  float64
#  25  Total.Uninjured         82977 non-null  float64
#  26  Weather.Condition       84397 non-null  object
#  27  Broad.phase.of.flight   61724 non-null  object
#  28  Report.Status           82508 non-null  object
#  29  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(25)
# memory usage: 21.0+ MB

# %%
type(aviation_data) #just checking to be sure
# Out:
# pandas.core.frame.DataFrame

# %%
aviation_data.describe(include='all') #getting an overview/preview of the data
# Out:
#        Investigation.Type Accident.Number  Event.Date       Location  \
# count               88889           88889       88889          88837
# unique                  2           88863       14782          27758
# top              Accident      WPR23LA045  1982-05-16  ANCHORAGE, AK
# freq                85015               2          25            434
# mean                  NaN             NaN         NaN            NaN
# std                   NaN             NaN         NaN            NaN
# min                   NaN             NaN         NaN            NaN
# 25%                   NaN             NaN         NaN            NaN
# 50%                   NaN             NaN         NaN            NaN
# 75%                   NaN             NaN         NaN            NaN
# max                   NaN             NaN         NaN            NaN
#
#               Country Latitude Longitude Airport.Code Airport.Name  \
# count           88663    34382     34373        50249        52790
# unique            219    25592     27156        10375        24871
# top     United States  332739N  0112457W         NONE      Private
# freq            82248       19        24         1488          240
# mean              NaN      NaN       NaN          NaN          NaN
# std               NaN      NaN       NaN          NaN          NaN
# min               NaN      NaN       NaN          NaN          NaN
# 25%               NaN      NaN       NaN          NaN          NaN
# 50%               NaN      NaN       NaN          NaN          NaN
# 75%               NaN      NaN       NaN          NaN          NaN
# max               NaN      NaN       NaN          NaN          NaN
#
#        Injury.Severity  ... Purpose.of.flight Air.carrier  \
# count            87889  ...             82697       16648
# unique             109  ...                26       13590
# top          Non-Fatal  ...          Personal       Pilot
# freq             67357  ...             49448         258
# mean               NaN  ...               NaN         NaN
# std                NaN  ...               NaN         NaN
# min                NaN  ...               NaN         NaN
# 25%                NaN  ...               NaN         NaN
# 50%                NaN  ...               NaN         NaN
# 75%                NaN  ...               NaN         NaN
# max                NaN  ...               NaN         NaN
#
#        Total.Fatal.Injuries Total.Serious.Injuries Total.Minor.Injuries  \
# count          77488.000000           76379.000000         76956.000000
# unique                  NaN                    NaN                  NaN
# top                     NaN                    NaN                  NaN
# freq                    NaN                    NaN                  NaN
# mean               0.647855               0.279881             0.357061
# std                5.485960               1.544084             2.235625
# min                0.000000               0.000000             0.000000
# 25%                0.000000               0.000000             0.000000
# 50%                0.000000               0.000000             0.000000
# 75%                0.000000               0.000000             0.000000
# max              349.000000             161.000000           380.000000
#
#        Total.Uninjured  Weather.Condition Broad.phase.of.flight  \
# count     82977.000000              84397                 61724
# unique             NaN                  4                    12
# top                NaN                VMC               Landing
# freq               NaN              77303                 15428
# mean          5.325440                NaN                   NaN
# std          27.913634                NaN                   NaN
# min           0.000000                NaN                   NaN
# 25%           0.000000                NaN                   NaN
# 50%           1.000000                NaN                   NaN
# 75%           2.000000                NaN                   NaN
# max         699.000000                NaN                   NaN
#
#          Report.Status Publication.Date
# count            82508            75118
# unique           17075             2924
# top     Probable Cause       25-09-2020
# freq             61754            17019
# mean               NaN              NaN
# std                NaN              NaN
# min                NaN              NaN
# 25%                NaN              NaN
# 50%                NaN              NaN
# 75%                NaN              NaN
# max                NaN              NaN
#
# [11 rows x 30 columns]

# %% [markdown]
# Now that I have a sense of the data that is available to me, I'll focus on some more specific questions to dig into.

# %% [markdown]
# ## What make and model planes are included in this dataset?

# %%
#What data will I use? 
    #I will need to use the make and model columns
#What type of logic and calculation will I use?
    #.value_counts() to count the different animal types
#What type of visualization would help answer the question?
    #a bar chart would be good for this purpose

# %%
#how can I connect these two columns of data? .groupby()? .join()?
#make copies of the columns in a new DataFrame?

# %%
aviation_data_clean = aviation_data.copy()

# %%
type(aviation_data_clean)
# Out:
# pandas.core.frame.DataFrame

# %%
aviation_data_clean['Make'] = aviation_data_clean['Make'].apply(str)#looks like we have both string and float data so converting it all to string

# %%
aviation_data_clean['Make'] = aviation_data_clean['Make'].map(str.upper)#now make them uppercase

# %% [markdown]
# Some brands only have one plane in the data set. Some makers may only make for specific buyers and not generally available for purchase.

# %%
aviation_data_clean['Make'].value_counts() #rename and combine Cessna and any other duplicates .map?
# Out:
# CESSNA             27149
# PIPER              14870
# BEECH               5372
# BOEING              2745
# BELL                2722
#                    ...
# OWEN KINGSLEY B        1
# HUDDLESTON-BELL        1
# CAVALIER               1
# BOTTERON               1
# TAYLOR LONSDALE        1
# Name: Make, Length: 7588, dtype: int64

# %%
aviation_data_clean['Make'].value_counts().to_string()
# Out:
# "CESSNA                            27149\nPIPER                             14870\nBEECH                              5372\nBOEING                             2745\nBELL                               2722\nMOONEY                             1334\nROBINSON                           1230\nGRUMMAN                            1172\nBELLANCA                           1045\nHUGHES                              932\nSCHWEIZER                           773\nAIR TRACTOR                         691\nAERONCA                             636\nMCDONNELL DOUGLAS                   608\nMAULE                               589\nCHAMPION                            519\nSTINSON                             439\nAERO COMMANDER                      429\nDE HAVILLAND                        422\nLUSCOMBE                            414\nAEROSPATIALE                        388\nNORTH AMERICAN                      383\nTAYLORCRAFT                         383\nROCKWELL                            355\nHILLER                              348\nENSTROM                             296\nAIRBUS                              291\nDOUGLAS                             281\nEMBRAER                             238\nAYRES                               238\nSIKORSKY                            233\nROBINSON HELICOPTER                 230\nGRUMMAN AMERICAN                    226\nCIRRUS DESIGN CORP                  223\nEUROCOPTER                          220\nAIR TRACTOR INC                     219\nROBINSON HELICOPTER COMPANY         194\nSWEARINGEN                          180\nAIRBUS INDUSTRIE                    164\nFAIRCHILD                           161\nERCOUPE (ENG & RESEARCH CORP.)      160\nPITTS                               154\nCIRRUS                              150\nLAKE                                150\nBALLOON WORKS                       147\nSCHLEICHER                          146\nMITSUBISHI                          145\nWACO                                143\nAVIAT                               140\nLEARJET                             136\nLET                                 136\nVANS                                129\nGRUMMAN-SCHWEIZER                   127\nSOCATA                              126\nLOCKHEED                            123\nBURKHART GROB                       121\nHELIO                               113\nRYAN                                110\nDEHAVILLAND                         101\nGLOBE                                98\nWEATHERLY                            94\nSCHEMPP-HIRTH                        91\nBRITISH AEROSPACE                    90\nAEROSTAR                             89\nERCOUPE                              88\nWSK PZL MIELEC                       88\nGULFSTREAM                           87\nRAVEN                                86\nNAVION                               79\nAVIAT AIRCRAFT INC                   77\nBOMBARDIER                           77\nCIRRUS DESIGN CORP.                  75\nROCKWELL INTERNATIONAL               75\nAMERICAN                             75\nDIAMOND AIRCRAFT IND INC             74\nRANS                                 74\nMBB                                  73\nRAYTHEON AIRCRAFT COMPANY            70\nROTORWAY                             68\nBOMBARDIER INC                       68\nCANADAIR                             68\nFOKKER                               66\nGREAT LAKES                          66\nGATES LEARJET                        66\nQUICKSILVER                          65\nAGUSTA                               65\nCAMERON                              63\nNAN                                  63\nPILATUS                              60\nSMITH                                60\nGRUMMAN ACFT ENG COR-SCHWEIZER       58\nGULFSTREAM AMERICAN                  56\nAMERICAN CHAMPION AIRCRAFT           54\nCHRISTEN INDUSTRIES                  54\nLANCAIR                              52\nSMITH, TED AEROSTAR                  51\nBOEING STEARMAN                      51\nGRUMMAN AMERICAN AVN.  ...

# %%
#in order to not skew the data, filtering all value counts 10 or more for evaluation of safety

filteredfreqct=aviation_data_clean['Make'].value_counts()
filteredfreqct[filteredfreqct > 9]
# Out:
# CESSNA                            27149
# PIPER                             14870
# BEECH                              5372
# BOEING                             2745
# BELL                               2722
# MOONEY                             1334
# ROBINSON                           1230
# GRUMMAN                            1172
# BELLANCA                           1045
# HUGHES                              932
# SCHWEIZER                           773
# AIR TRACTOR                         691
# AERONCA                             636
# MCDONNELL DOUGLAS                   608
# MAULE                               589
# CHAMPION                            519
# STINSON                             439
# AERO COMMANDER                      429
# DE HAVILLAND                        422
# LUSCOMBE                            414
# AEROSPATIALE                        388
# NORTH AMERICAN                      383
# TAYLORCRAFT                         383
# ROCKWELL                            355
# HILLER                              348
# ENSTROM                             296
# AIRBUS                              291
# DOUGLAS                             281
# EMBRAER                             238
# AYRES                               238
# SIKORSKY                            233
# ROBINSON HELICOPTER                 230
# GRUMMAN AMERICAN                    226
# CIRRUS DESIGN CORP                  223
# EUROCOPTER                          220
# AIR TRACTOR INC                     219
# ROBINSON HELICOPTER COMPANY         194
# SWEARINGEN                          180
# AIRBUS INDUSTRIE                    164
# FAIRCHILD                           161
# ERCOUPE (ENG & RESEARCH CORP.)      160
# PITTS                               154
# CIRRUS                              150
# LAKE                                150
# BALLOON WORKS                       147
# SCHLEICHER                          146
# MITSUBISHI                          145
# WACO                                143
# AVIAT                               140
# LEARJET                             136
# LET                                 136
# VANS                                129
# GRUMMAN-SCHWEIZER                   127
# SOCATA                              126
# LOCKHEED                            123
# BURKHART GROB                       121
# HELIO                               113
# RYAN                                110
# DEHAVILLAND                         101
# GLOBE                                98
# WEATHERLY                            94
# SCHEMPP-HIRTH                        91
# BRITISH AEROSPACE                    90
# AEROSTAR                             89
# ERCOUPE                              88
# WSK PZL MIELEC                       88
# GULFSTREAM                           87
# RAVEN                                86
# NAVION                               79
# AVIAT AIRCRAFT INC                   77
# BOMBARDIER                           77
# CIRRUS DESIGN CORP.                  75
# ROCKWELL INTERNATIONAL               75
# AMERICAN                             75
# DIAMOND AIRCRAFT IND INC             74
# RANS                                 74
# MBB                                  73
# RAYTHEON AIRCRAFT COMPANY            70
# ROTORWAY                             68
# BOMBARDIER INC                       68
# CANADAIR                             68
# FOKKER                               66
# GREAT LAKES                          66
# GATES LEARJET                        66
# QUICKSILVER                          65
# AGUSTA                               65
# CAMERON                              63
# NAN                                  63
# PILATUS                              60
# SMITH                                60
# GRUMMAN ACFT ENG COR-SCHWEIZER       58
# GULFSTREAM AMERICAN                  56
# AMERICAN CHAMPION AIRCRAFT           54
# CHRISTEN INDUSTRIES                  54
# LANCAIR                              52
# SMITH, TED AEROSTAR                  51
# BOEING STEARMAN                      51
# GRUMMAN AMERICAN AVN. CORP.          50
# FLIGHT DESIGN GMBH                   50
# DIAMOND                              49
# AEROTEK                              47
# EIPPER                               46
# YAKOVLEV                             46
# AYRES CORPORATION                    45
# EUROCOPTER FRANCE                    45
# ZENITH                               44
# DIAMOND AIRCRAFT INDUSTRIES          44
# SAAB-SCANIA AB (SAAB)                44
# CONVAIR                              43
# BRITTEN-NORMAN                       42
# ROLLADEN-SCHNEIDER                   42
# EAGLE AIRCRAFT CO.                   42
# ALON                                 41
# MD HELICOPTER                        41
# BRANTLY HELICOPTER                   39
# FAIRCHILD HILLER                     39
# SIAI-MARCHETTI                       38
# CONSOLIDATED AERONAUTICS INC.        38
# KAMAN                                38
# REPUBLIC                             36
# ISRAEL AIRCRAFT INDUSTRIES           36
# ATR                                  35
# MOONEY AIRCRAFT CORP.                35
# SHORT BROTHERS                       35
# COSTRUZIONI AERONAUTICHE TECNA       34
# AMERICAN CHAMPION (ACAC)             33
# SNOW                                 33
# MCDONNELL DOUGLAS HELICOPTER         33
# QUICKIE                              33
# DORNIER                              32
# GARLICK                              32
# HAWKER SIDDELEY                      32
# RAYTHEON                             32
# TEXAS HELICOPTER                     30
# DASSAULT                             30
# HOMEBUILT                            30
# BEECHCRAFT                           30
# CONTINENTAL COPTERS                  30
# ZENAIR                               30
# GULFSTREAM AEROSPACE                 30
# EVEKTOR-AEROTECHNIK AS               30
# GLASFLUGEL                           30
# FLIGHT DESIGN                        29
# TEMCO                                29
# I.C.A. BRASOV                        28
# STEARMAN                             27
# PIPER AIRCRAFT INC                   27
# AMERICAN AVIATION                    27
# GULFSTREAM-SCHWEIZER                 27
# CALLAIR                              26
# UNKNOWN                              26
# CAMERON BALLOONS                     25
# GLASAIR                              25
# JOHNSON                              25
# CUB CRAFTERS                         24
# VANS AIRCRAFT                        24
# VARGA                                24
# CESSNA AIRCRAFT CO                   24
# ADAMS                                24
# BOMBARDIER, INC.                     23
# BELL HELICOPTER TEXTRON              23
# THUNDER AND COLT                     23
# BELL HELICOPTER TEXTRON CANADA       23
# CASA                                 22
# BAE                                  22
# CUBCRAFTERS INC                      22
# AMERICAN AVIATION CORP. (AAC)        22
# BARNES                               22
# ROBINSON HELICOPTER CO               22
# SAAB                                 22
# SUKHOI                               22
# PZL-MIELEC                           22
# DASSAULT-BREGUET                     21
# EXTRA FLUGZEUGBAU                    21
# EUROCOPTER DEUTSCHLAND GMBH          21
# QUAD CITY                            20
# MILLER                               20
# SILVAIRE                             20
# CUB CRAFTERS INC                     20
# CURTISS-WRIGHT                       20
# INTERSTATE                           20
# SCHWEIZER AIRCRAFT CORP              20
# EIRIAVION OY                         20
# BRANTLY                              20
# GLASER-DIRKS                         20
# RUTAN                                20
# ENGINEERING & RESEARCH               20
# AIR COMMAND                          19
# DAVIS                                19
# PIPISTREL                            18
# BUCKEYE                              18
# LINDSTRAND BALLOONS                  18
# BENSON                               18
# THORP                                18
# AIR CREATION                         18
# AERO VODOCHODY                       18
# KOLB COMPANY                         17
# ARTIC AIRCRAFT CORP.                 17
# AMERICAN LEGEND AIRCRAFT CO          17
# BENSEN                               17
# CULVER                               17
# KITFOX                               17
# CLASSIC AIRCRAFT CORP.               17
# FORNEY                               17
# FLEET                                17
# PITTS SPECIAL                        16
# AIRBORNE                             16
# PARTENAVIA                           16
# RAYTHEON CORPORATE JETS              16
# JONES                                16
# AMERICAN GENERAL AIRCRAFT            16
# CHRISTEN INDUSTRIES INC              16
# ROTEC                                15
# AMERICAN CHAMPION                    15
# COMMANDER                            15
# NANCHANG                             15
# CONSOLIDATED-VULTEE                  15
# CZECH AIRCRAFT WORKS SPOL SRO        15
# DASSAULT AVIATION                    15
# AEROSTAR INTERNATIONAL               15
# COLUMBIA AIRCRAFT MFG                15
# EAGLE                                15
# BURKHART GROB FLUGZEUGBAU            15
# HAWKER BEECHCRAFT                    15
# AIRBORNE WINDSPORTS PTY LTD          14
# TECNAM                               14
# PTERODACTYL                          14
# TITAN                                14
# KOLB                                 14
# HOWARD AIRCRAFT CORP.                14
# ULTRAMAGIC                           14
# CAMERON BALLOONS US                  14
# CASSUTT                              14
# AEROSTAR INTERNATIONAL INC           14
# NAVAL AIRCRAFT FACTORY               13
# HAWKER BEECHCRAFT CORP               13
# AEROFAB INC.                         13
# AIR & SPACE                          13
# MITCHELL                             13
# AIRBUS HELICOPTERS                   13
# CIRRUS DESIGN CORPORATION            13
# REMOS AIRCRAFT GMBH                  13
# BRITTEN NORMAN                       13
# TEXTRON AVIATION INC                 13
# PIETENPOL                            13
# EXTRA                                13
# STEEN                                13
# AEROPRO CZ                           12
# VANS AIRCRAFT INC                    12
# MAXAIR                               12
# GROB                                 12
# CENTRAIR                             12
# BEDE AIRCRAFT                        12
# THRUSH AIRCRAFT INC                  12
# WEEDHOPPER                           12
# MORRISEY                             12
# CZECH SPORT AIRCRAFT AS              12
# PZL-BIELSKO                          12
# YOUNG                                12
# BROWN                                12
# CURTISS WRIGHT                       12
# EXTRA FLUGZEUGBAU GMBH               12
# CESSNA AIRCRAFT COMPANY              12
# FAIRCHILD SWEARINGEN                 12
# MCCULLOCH                            11
# ERCO                                 11
# AIRCRAFT MFG & DEV. CO. (AMD)        11
# HISPANO AVIACION                     11
# UNIVERSAL STINSON                    11
# FISHER                               11
# MONNETT                              11
# LEARJET INC                          11
# STARDUSTER                           11
# ANDERSON AIRCRAFT CORP.              11
# BLANIK                               11
# MCDONNELL DOUGLAS HELI CO            11
# GULFSTREAM AMERICAN CORP             11
# BUSHBY                               11
# TAYLOR                               11
# CLARK                                11
# VELOCITY                             11
# HALL                                 11
# PIPER AIRCRAFT CORPORATION           11
# LINDSTRAND                           10
# EVANS AIRCRAFT                       10
# MEYERS AIRCRAFT CO.                  10
# NORD (SNCAN)                         10
# HEAD BALLOONS, INC.                  10
# PIAGGIO                              10
# ROSE                                 10
# SCHEMPP HIRTH                        10
# WILLIAMS                             10
# EUROCOPTER DEUTSCHLAND               10
# AMERICAN AEROLIGHTS                  10
# MOONEY AIRPLANE CO INC               10
# WEBER                                10
# TEXAS HELICOPTER CORP                10
# RYAN AERONAUTICAL                    10
# CHANCE VOUGHT                        10
# PICCARD                              10
# AERO VODOCHODY AERO. WORKS           10
# HAWKER                               10
# CESSNA AIRCRAFT                      10
# REIMS                                10
# AVID                                 10
# AVIAT INC                            10
# WILSON                               10
# NORTH WING                           10
# AVID AIRCRAFT                        10
# RANS, INC.                           10
# Name: Make, dtype: int64

# %%
aviation_data_clean[aviation_data_clean['Make'].isin(filteredfreqct[filteredfreqct > 9].index)]
#dropping all rows where the 'make' frequency count is 9 or less
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Latitude Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      NaN       NaN
# 20001218X45447   BRIDGEPORT, CA  United States      NaN       NaN
# 20061025X01555    Saltville, VA  United States  36.9222  -81.8781
# 20001218X45448       EUREKA, CA  United States      NaN       NaN
# 20041105X01764       Canton, OH  United States      NaN       NaN
# ...                         ...            ...      ...       ...
# 20221227106491    Annapolis, MD  United States      NaN       NaN
# 20221227106494      Hampton, NH  United States      NaN       NaN
# 20221227106497       Payson, AZ  United States  341525N  1112021W
# 20221227106498       Morgan, UT  United States      NaN       NaN
# 20221230106513       Athens, GA  United States      NaN       NaN
#
#                Airport.Code Airport.Name Injury.Severity Aircraft.damage  \
# Event.Id
# 20001218X45444          NaN          NaN        Fatal(2)       Destroyed
# 20001218X45447          NaN          NaN        Fatal(4)       Destroyed
# 20061025X01555          NaN          NaN        Fatal(3)       Destroyed
# 20001218X45448          NaN          NaN        Fatal(2)       Destroyed
# 20041105X01764          NaN          NaN        Fatal(1)       Destroyed
# ...                     ...          ...             ...             ...
# 20221227106491          NaN          NaN           Minor             NaN
# 20221227106494          NaN          NaN             NaN             NaN
# 20221227106497          PAN       PAYSON       Non-Fatal     Substantial
# 20221227106498          NaN          NaN             NaN             NaN
# 20221230106513          NaN          NaN           Minor             NaN
#
#                Aircraft.Category Registration.Number  \
# Event.Id
# 20001218X45444               NaN              NC6404
# 20001218X45447               NaN              N5069P
# 20061025X01555               NaN              N5142R
# 20001218X45448               NaN              N1168J
# 20041105X01764               NaN               N15NY
# ...                          ...                 ...
# 20221227106491               NaN              N1867H
# 20221227106494               NaN              N2895Z
# 20221227106497          Airplane              N749PJ
# 20221227106498               NaN              N210CU
# 20221230106513               NaN              N9026P
#
#                                       Make      Model Amateur.Built  \
# Event.Id
# 20001218X45444                     STINSON      108-3            No
# 20001218X45447                       PIPER   PA24-180            No
# 20061025X01555                      CESSNA       172M            No
# 20001218X45448                    ROCKWELL        112            No
# 20041105X01764                      CESSNA        501            No
# ...                                    ...        ...           ...
# 20221227106491                       PIPER  PA-28-151            No
# 20221227106494                    BELLANCA       7ECA            No
# 20221227106497  AMERICAN CHAMPION AIRCRAFT      8GCBC            No
# 20221227106498                      CESSNA       210N            No
# 20221230106513                       PIPER  PA-24-260            No
#
#                 Number.of.Engines    Engine.Type FAR.Description Schedule  \
# Event.Id
# 20001218X45444                1.0  Reciprocating             NaN      NaN
# 20001218X45447                1.0  Reciprocating             NaN      NaN
# 20061025X01555                1.0  Reciprocating             NaN      NaN
# 20001218X45448                1.0  Reciprocating             NaN      NaN
# 20041105X01764                NaN            NaN             NaN      NaN
# ...                           ...            ...             ...      ...
# 20221227106491                NaN            NaN             091      NaN
# 20221227106494                NaN            NaN             NaN      NaN
# 20221227106497                1.0            NaN             091      NaN
# 20221227106498                NaN            NaN             091      NaN
# 20221230106513                NaN            NaN             091      NaN
#
#                Purpose.of.flight         Air.carrier  Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444          Personal                 NaN                   2.0
# 20001218X45447          Personal                 NaN                   4.0
# 20061025X01555          Personal                 NaN                   3.0
# 20001218X45448          Personal                 NaN                   2.0
# 20041105X01764          Personal                 NaN                   1.0
# ...                          ...                 ...                   ...
# 20221227106491          Personal                 NaN                   0.0
# 20221227106494               NaN                 NaN                   0.0
# 20221227106497          Personal                 NaN                   0.0
# 20221227106498          Personal  MC CESSNA 210N LLC                   0.0
# 20221230106513          Personal                 NaN                   0.0
#
#                 Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                   0.0              0.0
# 20001218X45447                     0.0                   0.0              0.0
# 20061025X01555                     NaN                   NaN              NaN
# 20001218X45448                     0.0                   0.0              0.0
# 20041105X01764                     2.0                   NaN              0.0
# ...                                ...                   ...              ...
# 20221227106491                     1.0                   0.0              0.0
# 20221227106494                     0.0                   0.0              0.0
# 20221227106497                     0.0                   0.0              1.0
# 20221227106498                     0.0                   0.0              0.0
# 20221230106513                     1.0                   0.0              1.0
#
#                Weather.Condition Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444               UNK                Cruise  Probable Cause
# 20001218X45447               UNK               Unknown  Probable Cause
# 20061025X01555               IMC                Cruise  Probable Cause
# 20001218X45448               IMC                Cruise  Probable Cause
# 20041105X01764               VMC              Approach  Probable Cause
# ...                          ...                   ...             ...
# 20221227106491               NaN                   NaN             NaN
# 20221227106494               NaN                   NaN             NaN
# 20221227106497               VMC                   NaN             NaN
# 20221227106498               NaN                   NaN             NaN
# 20221230106513               NaN                   NaN             NaN
#
#                Publication.Date
# Event.Id
# 20001218X45444              NaN
# 20001218X45447       19-09-1996
# 20061025X01555       26-02-2007
# 20001218X45448       12-09-2000
# 20041105X01764       16-04-1980
# ...                         ...
# 20221227106491       29-12-2022
# 20221227106494              NaN
# 20221227106497       27-12-2022
# 20221227106498              NaN
# 20221230106513       30-12-2022
#
# [78942 rows x 30 columns]

# %%
type(aviation_data_clean['Make'].unique()) #what type or return is this data?
# Out:
# numpy.ndarray

# %%
len(aviation_data_clean['Make'].unique()) #how long is this list
# Out:
# 7588

# %%
aviation_data_clean['Make'].unique()
# Out:
# array(['STINSON', 'PIPER', 'CESSNA', 'ROCKWELL', 'MCDONNELL DOUGLAS',
#        'NORTH AMERICAN', 'BEECH', 'BELLANCA', 'NAVION', 'ENSTROM',
#        'SMITH', 'BELL', 'GRUMMAN', 'BEECHCRAFT', 'MAULE', 'AIR TRACTOR',
#        'AEROSPATIALE', 'MOONEY', 'BOEING', 'CURTIS', 'SCHLEICHER',
#        'QUICKIE', 'LOCKHEED', 'EMBRAER', 'HUGHES', 'SWEARINGEN',
#        'DE HAVILLAND', 'BELL HELICOPTER', 'BEDE AIRCRAFT', 'CONVAIR',
#        'BEACHNER', 'CANADAIR', 'DOUGLAS', 'SONS MUSTANG', 'DASSAULT/SUD',
#        'SIKORSKY', 'BELL/TEXTRON', 'ROBERTSON', 'AERONCA',
#        'SMITH MINIPLANE', 'MITSUBISHI', 'MCDONNELL-DOUGLAS',
#        'TAYLORCRAFT', 'TED SMITH', 'ROBINSON', 'RAVEN', 'ERCOUPE',
#        'ROCKWELL COMDR', 'HOWARD AIRCRAFT CORP.', 'PORTERFIELD', 'NIHON',
#        'GREAT LAKES', 'BALLOON WORKS', 'PITTS', 'FAIRCHILD HILLER',
#        'KAMAN', 'WEATHERLY', 'EAGLE', 'BARNES', 'SCHWEIZER',
#        'STARDUSTER II', 'HOMEBUILT', 'SMITH MINI', 'SMITH AEROSTAR',
#        'ROCKWELL INTL', 'HILLER', 'SCHREDER', 'VARGA', 'HATZ',
#        'NORD AVIATION', 'CROOK', 'AMERICAN YANKEE', 'HELIO', 'COLONIAL',
#        'GULFSTREAM AMERICAN', 'BENSON', 'LUSCOMBE', 'MCKINLEY EAA',
#        'AIRMATE', 'B??LKOW', 'SNOW', 'ROCKWELL COMMANDER', 'ROTORWAY',
#        'GULFSTREAM', 'CHAMPION', 'FOURNIER AVIATION', 'CURTISS-WRIGHT',
#        'AERO COMMANDER', 'MBB-BOLKOW', 'PIPER-AEROSTAR', 'ROCKWELL INTL.',
#        'RYAN', 'JURCA', 'MARTIN-PITTS', 'S.N.I.A.S.', 'GOODYEAR', 'RAND',
#        'RUTAN', 'BURKHART GROB FLUGZEUGBAH', 'SUD AVIATION',
#        'AVRES CORP.', 'GRUM AMER', 'EVANS AIRCRAFT', 'SCHWEIZER SGS',
#        'AYRES', 'STAMPE RENARD', 'FAIRCHILD', 'PITTS SPECIAL', 'TAILWIND',
#        'HILLER-SOLOY', 'AEROTEK-PITTS', 'AVIAN BALLOON', 'HARTMAN',
#        'SPEZIO', 'DAUNTLESS', 'MBB', 'BELL/SOLOY', 'RAZ-MUT', 'CHRISTIAN',
#        'FUNK AIRCRAFT CO.', 'MONG SPORT', 'RAYAN', 'STARFIRE', 'OSPREY',
#        'HUDSON', 'CONTINENTAL', 'GATES LEARJET', 'SCORPION',
#        'THUNDER BALLOONS, LTD.', 'MOORE BELL', 'BLANIK', 'TAYLOR', 'LAKE',
#        'BRANTLEY', 'BRYAN', 'BELL 47G-3B', 'VOLMER AIRCRAFT', 'CITABRIA',
#        'MARTIN', 'NASH CASSUTT RACER', 'PLAYMATE', 'OLDFIELD', 'BAC',
#        'BROYILL-COWAN-MURRAY', 'ERCO', 'BRANTLY', 'CALLAIR',
#        'CONSOLIDATED AERONAUTICS INC.', 'CONTINENTAL MK5A', 'ARCTIC',
#        'THURSTON', 'SWANSON', 'ADAMS', 'MIGNET', 'STARDUSTER', 'HARDIE',
#        'SAVAGE', 'STARKE', 'MCCALL', 'FOKKER', 'SCHEICHER', 'BENSEN',
#        'WING', 'GREGG', 'LEARJET', 'MCCLARY', 'MIDGET', 'NA',
#        'I.C.A. BRASOV - ROMANIA', 'SOUTHERN AIRMOTIVE CORP SAC',
#        'BARRETT', 'VARIEZE', 'CAMERON BALLON', 'I.C.A. BRASOV',
#        'PETER CLARK', 'DAVIS', 'BELLANCE', 'ROCKWELL INTERNATIONAL',
#        'DOWNER AIRCRAFT INDUSTRIES', 'PTERODACTYL', 'RYAN AERONAUTICS',
#        'GRUMMAN AMERICAN', 'NAN', 'CLANCY', 'BELL-CONT 42G',
#        'BRITTEN-NORMAN', 'WACO', 'GOANS', 'GLASSFLUGEL', 'PIETENPOL',
#        'MILLER', 'AERONCA CHAMPION', 'COOT', 'BREEZY', 'JUNIOR ACE',
#        'GLOBE', 'LARK (I.C.A.)', 'REPUBLIC', "ROCKWELL INT'T", 'MONG',
#        'AMERICAN', 'FIREFLY', 'TEXAS HELICOPTER CORP.', 'THORP',
#        'ROTORWAY AIRCRAFT, INC.', 'OMAC', 'BUCKER JUNGMANN', 'STEEN',
#        'ALON', 'AUSTIN', 'MORRISEY', 'EIPPER MX II QUICKSILVER',
#        'HALLQUIST', 'AERONCA CHAMP', 'Q-BERRY', 'OAR', 'SIAI MARCHETTI',
#        'CORBEN', 'SONERAI', 'BELL HELICOPTER TEXTRON', 'BOEING STEARMAN',
#        'EIRIAVION OY', 'CONDOR', 'EAA', 'VON BERG', 'MENEES',
#        'ENGINEERING & RESEARCH', 'DRAGON FLY', 'AUSTER', 'AIR & SPACE',
#        'QUICKSILVER', 'CASSUTT', 'MUSTANG', 'LAWSON SPECIAL', 'CAMERON',
#        'BENTLY', 'WAYNE ISON', 'LINDGREN EVANS', 'AMERICAN AVIATION',
#        'FALKENTHAL', "VILLINE'S", 'CONSOLIDATED AERO', 'DAVENPORT',
#        'SCHEMPP-HIRTH', 'BENNET', 'VARI-EZE', 'LONG-EZ',
#        'FAIRCHILD/SWEARINGEN', 'FLITECRAFT', 'FOSTER', 'SCORPION TOO',
#        'NAVY', 'GLASFLUGEL', 'TANKE', 'WAINSCOTT', 'KEN BROCK',
#        'SAVILLE HUMMER', 'COUGAR', 'GENERAL BALLOON', 'RAVEN INDUSTRIES',
#        'BOEING VERTOL', 'TOMCAT', 'BOWERS FLYBABY', 'VOLKSPLANE',
#        'E.L. CRAIG', 'EIPPER-FORMANCE', 'C. EFF', 'J.A.MULLAN', 'FLAGG',
#        'ARCTIC AIRCRAFT', 'VANHOOSE/SCORPIO', 'JOHNSON, DOUGLAS L.',
#        'SHORT BROS.', 'ROLLADEN-SCHNEIDER', 'FROEHLICH', 'TEMCO',
#        'AMATEUR BUILT', 'MCDONALD DOUGLAS', 'TIFFT-V', 'BEAGLE AIRCRAFT',
#        'AEROSPORT', 'CGS AVIATION', 'GATES LEAR JET', 'FRANK TURBEN',
#        'HOLLMAN', 'BURKE-PARKER', 'NORMAN NEGUS', 'PICCARD',
#        'JAVELIN AIRCRAFT', 'TEAL', 'WILLBIRD',
#        'ISRAEL AIRCRAFT INDUSTRIES', 'CROMWELL/PITTS',
#        'SMITH, TED AEROSTAR', 'OBRYON', 'PACE', 'PRATT-READ',
#        'JOHN TYLENDA', 'MONNETT', 'SCHEIBE FLUGZEUGBAU',
#        'EAGLE (ULTRALIGHT)', 'HARRISON VOLMER', 'DODD', 'BECKNER',
#        'GLASAIR', 'RAND KR1', 'ROTEC', 'VANS AIRCRAFT', 'BURKHART GROB',
#        'EAA BIPLANE', 'GRAY', 'BROWN', 'WEEDHOPPER', "GEMINI INT'L.",
#        'MOLINO OY', 'MANTA', 'WASPAIR', 'CONSOLIDATED-VULTEE',
#        'MURRAYAIR', 'KIT BUILT (ROTORWAY)', 'WARE TEENIE',
#        'EAGLE AIRCRAFT CO.', 'ANDERSON, GREENWOOD', 'CONTINENTAL COPTERS',
#        'PARTENAVIA', 'CGS', 'LET', 'ERCOUPE (ENG & RESEARCH CORP.)',
#        'MITCHELL', 'WIZARD', 'WALSTON', 'PTERADACTYL', 'SPENCER',
#        'BRANTLY HELICOPTER', 'LOGAN', 'TUK GREGORY', 'AIRMASS', 'SWIFT',
#        'ULTRALIGHT FLIGHT', 'CARTER', 'RIETMAN', 'BOLAND',
#        'NORTH AMERICAN ROCKWELL CORP.', 'HOLMES', 'FAIRCHILD SWEARINGEN',
#        'EIPPEN AIRCRAFT', 'GOLDWING', 'SKYPOWER', 'VECTOR', 'ROGERS',
#        'CUMMINGS QUICKIE', 'FORNEY', 'EIPPER', 'SCHAFFER-PROVENCHER',
#        'INTL ULTRALIGHT', 'PARSON', 'AIRCOUPE', 'HERPST',
#        'GRUMMAN-SCHWEIZER', 'SIAI-MARCHETTI', 'RYAN-NAVION',
#        'ULTRALIGHT ENGINEERING', 'ARTIC AIRCRAFT CORP.', 'MCDONALD',
#        'YARNELL', 'BARNSTORMER', 'LINK-JOHNSON-CHESSMAN',
#        'ROTEC ENGINEERING, INC.', 'SUNBURST', 'DG', 'JOHNSON', 'MONERAI',
#        'TEXAS HELICOPTER', 'DIAL-THORP', 'PARA-SAIL', 'LOMBARD DILLEY',
#        'MEYERS AIRCRAFT CO.', 'MAREIK-BENSEN', 'EASTERN ULTRALIGHT',
#        'STOLP', 'GARLICK', 'EIPPER FORMANCE', 'PROUT', 'KATE',
#        'SMITH-POSTON', 'AMERICAN AEROLIGHTS', 'ALESON', 'BOWLIN',
#        'MONNETT - LARSEN', 'THORPE', 'HAMILTON', 'LONG', 'TWITCHELL',
#        'CLARK', 'ROTEC/BOTSFORD', 'VANS-RUPERT', 'MATTISON',
#        'GILBERT L. HOUSTON', 'EAMES', 'VIKING',
#        'FLUG-UND FAHRZEUGWERKE (FFA)', 'CURTISS', 'WSK PZL MIELEC',
#        'J. ROBERTS', 'SPORTAVIA-PUTZER', 'GYAKI', 'EASY RISER',
#        'AMERICAN EAGLE', 'HACKETT/MCKOWN', 'E.R. HUTSON', 'CONDOR II',
#        'FINAMORE', 'SOPWITH', 'BREEZY RLU', 'RAND ROBINSON', 'DIMARIA',
#        'LAISTER', 'VANGRUNSVEN', 'BERKSHIRE', 'SCHIPPERS', 'KANE',
#        'PIETENPAL', 'CHAMBERLAIN', 'MONKE', 'TRAGER', 'PESTES', 'GRAU',
#        'FISHER', 'SWAIN', 'NAVAL AIRCRAFT FACTORY', 'BLACK', 'ZENAIR',
#        'PIETONPOL-IMRIE', 'BEEMER', 'AEROSTAR', 'BERWIN',
#        'CAMAIR AIRCRAFT CORP.', 'LOWTHER', 'PIERCE', 'BURNETT', 'JODEL',
#        'CASA', 'SCARBORO', 'CORBIN', 'AEROTEK', 'ARROW AIRCRAFT CO.',
#        'DEMETER', 'LEONARD', 'MANTA PRODUCTS', 'TERATORN', 'GRIEME',
#        'MIDWEST MICROLITES -', 'SEMCO', 'BIRD', 'PIONEER', 'PRELL',
#        'CATTO', 'STARFLIGHT', 'STEWART', 'MOCKRUD', 'EDWARDS',
#        'WASPAIR TOMCAT', 'WEST-HECKMAN', 'KUSTER', 'JOHNSTON',
#        'BUCKER FLUGZEUGBAU', 'BRITISH AIRCRAFT CORP. (BAC)', 'WARREN',
#        'STOL AIRCRAFT', 'PTERODACTYL/LAMBERT', 'CLARKS PITT SPECIAL',
#        'EIPPER QUICKSILVER', 'WORMLEY', 'BRANDT', 'MORTENSEN', 'KRUER',
#        'ANDERSON AIRCRAFT CORP.', 'FUESLEIN', 'KECSKES',
#        'JILEK-SMITH MINIPLANE', 'GULFSTREAM-SCHWEIZER',
#        'EIPPER QUICKSIVER E', 'PILATUS', 'KIMBAL', 'HORDEMANN',
#        'KEMMEYER', 'HAWKER SIDDELEY', 'LANNY RUNDELL', 'ALDERFER',
#        'DELEY STARDUSTER', 'HIGHT SMARAGD', 'HIGHCRAFT', 'POPELKA',
#        'SHORT BROTHERS', 'BAKING', 'WICHAWK', 'JORDAN',
#        'DELTS WING KITES', 'AIRBUS INDUSTRIE', 'BRADEY',
#        'WESTLAND HELICOPTERS', 'MORTON', 'TEMAN', 'JODEL-BERNIER',
#        'GARY WILSON', 'RIDER', 'LAZAIR', 'KEPPLE', 'SKOV-PAPWORTH',
#        'PAUL S. KERR', 'MOTORIZED GLIDERS', 'VICKERS', 'SABRELINER CORP.',
#        'RYGG', 'STRIPLIN', 'YAPLE, ROBERT G.', 'YOUNG-LOSEY', 'JODELL',
#        'WELLS/RAND', 'BRITISH AEROSPACE', 'LARK AVIATION', 'DASSAULT',
#        'BACH', 'GORDON', 'SHUEY', 'MOSELEY/SCORPION', 'MAUPIN', 'HARVEY',
#        'PANAPLANE', 'ULTRACLASSICS', 'VAMPIRE', 'CHANCE VOUGHT',
#        'ROBERT H. LOW', 'KEITH A SMITH', 'GARDNER', 'HEINEMANN',
#        'AMERICAN AVIATION CORP. (AAC)', 'SIGERS', 'TERATORN ACFT INC.',
#        'EAGLE BALLOONS', 'GROSS', 'SOUTHERN', 'SHARK', 'SWANSON/BENSEN',
#        'VARI', 'ALLEVA', 'BENGTSON', 'ROBERT MCDONNELL', 'LEE M. BROWN',
#        'BOWERS', 'BIRDMAN ENTERPRISES', 'OWEN ROBERT R', 'MARTIN COMPANY',
#        'BLISS CORBIN', 'UNKNOWN', 'STURGES', 'FOLKE WULF',
#        'AMERICAN AIRCRAFT', 'FORNAIRE', 'BROWN, R. M. JR.', 'PZL-MIELEC',
#        'BOWEN-POWELL', 'BEASLEY, GERALD L.', 'TERATORN AIRCRAFT, INC.',
#        'WILLIAM FREEMAN', 'MURPHY-CHARLES', 'RALLY ROTEC',
#        'HALL-CAVALIER', 'CHRISTEN EAGLE', 'SONERIA', 'OLSON', 'GABLE',
#        'GINN', 'HARPER/CRICRI', 'MEYERS', 'BRUBAKER', 'PIETENPOL-GREGA',
#        'ULTRAFLIGHT', 'ISTENES', 'WAGNER', 'GERMANY WETHERELL', 'LEBLANC',
#        'JAKEL', 'LEE', 'WILLIAM A. WAAS', 'LYCAN',
#        'STOLP STARDUSTER CORP.', 'ROBERT JUDD', 'ULTRALIGHT FLIGHT, INC.',
#        'BAUGH-HUBERT', 'SORRELL', 'HALFPAP', 'STOREY', 'ROBERT B. BOSTON',
#        'GRIFFIN TRANE INC.', 'INTERSTATE', 'HUMER', 'GRIFFIN',
#        'JOHN R JONES', 'HOWARD E. LEE', 'STEPHENS', 'RITZ',
#        'APPLEBAY SAILPLANES', 'MONETT-KEATING', 'REARWIN',
#        'AMER. AEROLIGHT', 'PETER A. YARGER', 'JORDAN HENRY J',
#        'ENTWICKLUNGSGEMEINSCHAFT', 'UFM', 'GILLMORE', 'CULVER',
#        'ULTRALIGHT SOARING', 'HAXTON', 'JERRY D. FISH', 'TERATON',
#        'CESSNA WREN', 'TRAVEL AIR', 'EXPERIMENTAL AMATEUR BUILT',
#        'MORGAN T. MELTON', 'SPERLING', 'BOBBY WAYNE WATKINS',
#        'MOSLEY HIGH SCHOOL', 'VANCE-HAMM', 'NESMITH', 'VULTEE', 'HEVERON',
#        'BURNS', 'SIMS - BASSET', 'INTERMOUNTAIN MFG. (IMCO)',
#        'E.L. GRIGGS', 'COLLINS', 'S.I. BRIGGS', 'DEMICK JAMES A',
#        'BELL-OLYMPIC HELICOPTERS, INC.', 'ZAPPIA GABRIEL J', 'DAHLMAN',
#        'ARNOLD FOREST', 'TATE', 'LIGHTHIZER, RICHARD E.',
#        'DARRELL W. MC MORAN', 'BAKEMAN-CHAPMAN', 'FRED WILLIAMS',
#        'LINDSAY DAVIS', 'DONALD E. BRADSHAW', 'WHITMAN', 'VAUGHN',
#        'BASTIAN', 'HAYES', 'CALYPSO', 'SHINDLER-SMILEY', 'ULTRALIGHT UFM',
#        'UNIVERSAL STINSON', 'RUSSELL ST. ARNOLD', 'CESSNA ECTOR',
#        'PHANEUF', 'MILLER AIR SPORTS', 'HEAD BALLOONS, INC.', 'UNGERECHT',
#        'HARRIS', 'JETT', 'DENIL', 'AGUSTA', 'FOCKE-WULF',
#        'WILLIAM T. HODGES', 'REICHER', 'DRAKE', 'PICKEL',
#        'FULLER/FINDLAY', 'WINDECKER RESEARCH', 'ROBERT EGGEBRECHT',
#        'THOMAS', 'GARRE LEO J', 'BREWER', 'HAMBURGER FLUGZEUGBAU (HFB)',
#        'KALLANSRUD/PITTS', 'MCCOY', 'MITCHELL RONALD A',
#        'HARBAUGH JOHN T', 'CROSETTI', 'HARVARD',
#        'LIGHT AERO,INC. (ASHLEY)', 'JACK L. BIGHAM',
#        'FOUR SEASONS AVIATIONS', 'MOORE', 'ASPEN', 'WELLS', 'STEVENS',
#        'KRAGNES', 'REED', 'PENNINGTON-EAA BIPLANE', 'DONALD W DEVINE',
#        'CORLETT-BEAHM', 'BARRY ZIELINSKI', 'HART-THORP',
#        'KENNETH ROEBUCK', 'HARDY', 'DOUGLAS SWANNINGSON',
#        'RAWDON BROS. AIRCRAFT', 'LOUNSBERY', 'GYROCOPTER', 'FUJI',
#        'POLLIWAGEN', 'CROWDER', 'SAABYE', 'EMAIR', 'MILENTZ', 'MASSELINK',
#        'JIM MCKINSTRY', 'MCCLELLAN J. GROTE', 'LYOYD THOMPSON',
#        'AUTON - DUNHAM', 'BENJAMIN', 'SEVDY PITTS SPECIAL',
#        'MITCHELL HARVEY', 'ENGEL', 'ARONSON', 'STRACENER EXPERIMENTAL',
#        'HILLIARD', 'MARR/ECKBURG', 'KIRST ALLEN J', 'BAINBRIDGE',
#        'EHLERS', 'JOHNSON-RAND', 'CANARD, INC.', 'SMELKO', 'CIRRUS',
#        'SEDERBERG', 'HUFF', 'CONDOR AIRCRAFT', 'WISCONSIN STATE PRISON',
#        'ISTVANICK', 'WHEAT', 'SLINGSBY', 'MCCULLOCH', 'VICKERS SLINGSBY',
#        'LESTER F.W. WEST', 'GREER', 'JACK BOLDT', 'GAMBLE', 'HOLDER',
#        'CENTRAIR', 'DEMPSEY', 'EARNST', 'STEARMAN', 'DASSAULT-BREGUET',
#        'SILVAIRE', 'AIRSHIP INDUSTRIES', 'RINGSDORF-MCCONNELL',
#        'GALLOWAY', 'BEDEELL', 'HEEKIN', 'STEENS', 'CHADWICK', 'JENKINS',
#        'E.T. MEREDITH III', 'MCPHERSON', 'HANEY',
#        'BRIEGLEB AMATURE BUILT', 'OTIS G. LYONS', 'JOEL K. SENTER',
#        'HILDEBRAND', 'BRIANS', 'GENERAL DYNAMICS', 'KILLIAN',
#        'FAILING/RAND-ROBINSON', 'PZL', 'NEUMANN-EVERETT',
#        'LESLIE J. ROYAL', 'RICHARD E. ROWLAND', 'BORRESON', 'KIBLER-BEDE',
#        'SHINDLER', 'KOKES', 'QUINN AVIATION', 'POLLIWAGEN INC.', 'BURCH',
#        'LETT', 'RAND/ROBINSON', 'WILLIAM G. CLOANINGER', 'PETRACCA',
#        'LARRY ROBBINS', 'FAIN', 'JOHN H. MC CLAIN, JR.', 'WAG-AERO, INC.',
#        'ROBERT THIBODEAU', 'DIETZ', 'NEW STANDARD', 'KAUFFMAN',
#        'HAZELRIGE', 'FRANK H MARCHETTI', 'JAMES GRESS', 'WOOLSEY',
#        'NEYMAN-PIETENPOL', 'CHRISTOPHER D. BROWN', 'SCHUBERT', 'STAMPE',
#        'LARRY SCHINDLER', 'JAMES POSTLEWAIT', 'EARL F. FOLSOM',
#        'MCFARLAND', 'JONES', 'STAR DUSTER TOO', 'RONALD C. RENDER',
#        'RICHARD A. WHITE', 'RONALD HOUK', 'PEZETEL', 'MIKE STONE',
#        'MAR-FLITE', 'ADVANCED TECHNOLOGY', 'SKYRANGER', 'JAMES/VIKING',
#        'MITCHELL/BEDE', 'DUCE PROJECT', 'VALENTIN', 'EMROTH EMAIR',
#        'ROGER W. STIGEN', 'JAUCH', 'WELCH', 'THORNHILL', 'PZL-BIELSKO',
#        'STOLT-ADAMS', "CONOVER'S", 'PETERSON', 'JONAS', 'PITTS SPL.',
#        'LAUX PITTS', 'TODD', 'BROKAW', 'VANBENTHUYSEN JOHN', 'WIPPLER',
#        'LON J. MCKNIGHT', 'CHALLENGER', 'UNIVAIR', 'AEROFAB INC.',
#        'DOUGLAS MASELINK', 'LEONE', 'WILLIE', 'SKURICH', 'LESLIE',
#        'HODSON', 'KEN BROCK MFG. CO', 'OFRIA', 'SILVAGGIO',
#        'S. PICCOLOTTO/DAVE MORSS', 'SAAB-FAIRCHILD', 'LEWIS-PEXTON',
#        'CAROTHERS', 'PARSONS', 'LONNIE W. RATLIFF', 'DORFMAN,WILLIAM A.',
#        'JOHN PATRICK COLEMAN', 'GARY E. WILSON', 'BRISBIN', 'LAGATORE',
#        'GENSEN', 'BILL MCCARLEY', 'GRIFFIN, THOMAS',
#        'DOUGLAS C. CAMPBELL', 'ROBERT D. CAMPBELL', 'ADAMS WILLIAM C',
#        'MONNET', 'WORLD WIDE INDUSTRIES', 'SOCATA', 'STEPHENSON',
#        'COMMINGS', 'BUSHBY', 'KUHN', 'UNIVERSAL AIRCRAFT INDUSTRIES',
#        'WAYNE MATHEWS', 'WHIGHAM', 'HENLEY', 'FOLSOM', 'SWANNINGSON',
#        'PATRICK HENRY', 'SHAFFER', 'DURKOTA', 'JIM ELLIOTT', 'LTV',
#        'GLEN DAVIS', 'CHRISTEN INDUSTRIES', 'BOB WHITE', 'EASLEY',
#        'JOACHIM HOEHNE', 'DONALD R. CASPER', 'PERKINS', 'MORLEY',
#        'STEINORTH', 'RJB AVIATION', 'TAYLOR LONSDALE', 'VERE EZE',
#        'BLYTHE', 'BABY BIRD', 'DAY', 'LTV AEROSPACE INDUSTRIES',
#        'RUSSELL', 'GLASER-DIRKS', 'AVIATION ADV.', 'WING AIRCRAFT CO.',
#        'CONNER', 'HANSON', 'WRIGHT', 'BREWSTER', 'MILLIKEN',
#        'BEAUPRE ELFERING', 'WSK', 'JACKMAN', 'MYERS', 'COLLIN CAMPBELL',
#        'DENNEY AEROCRAFT', 'SOWARD', 'JERRY COX', 'LANGEFORD', 'FLY BABY',
#        'ARBAUGH EVANS', 'MORRIS B. STEPHENS', 'HISPANO AVIACION',
#        "BAUER'S MITCHELL WING", 'BERNARD DARMSTADT', 'GREEN', 'AIR',
#        'ROSE', 'HALL CHRISTEN EAGLE', 'NELSON/NELSON', 'AVIAN', 'CARNES',
#        'RANDY TREDO', 'BEAVER', 'SANDERS', 'REPLIEA 78 RAL', 'ROBBINS',
#        'BENSEN-JANSEN', 'EDWARD R. MERKNER', 'QUICK SILVER', 'H. PREISS',
#        'ANDREW D. MOORE', 'MELLEMA', 'STEEN SKYBOLT',
#        'CHARLES S.HATCHETTE', 'MATHEW M. KERR', 'PIASECKI ACFT. CORP.',
#        'LAZARINI', 'STAINBROOK', 'JERRY BERRY', 'GOERTZ BUSHBY',
#        'STEVENSON', 'BELL-CAMPBELL', 'WHITTMAN', 'PATTON PITTS',
#        'WEISS-HAYNES', 'ROSE RHINEHART', 'HANSEN', 'TROUTMAN', 'HUIZENGA',
#        'RANDOLPH R.CLARK', 'WOODROW S.A.', 'KENNETH PATSCH', 'CHERRY',
#        'STEVEN SOPER', 'SAMUEL R. HOSKINS', 'WHEELER', 'BOMBERGER',
#        'CAPETOWN BUILDERS', 'COLLINS CHARLES A', 'JAKS',
#        'ATTEBERY-STAINBROOK', 'THORP AERO, INC.', 'PATE', 'WARD',
#        'BERNARD', 'E. E. SCHILLING', 'DAVID GORDON', 'SENIOR AERO SPORT',
#        'WISE', 'ROGER WARNELL', 'STAR-LITE', 'ERICKSON', 'RUSSELL POST',
#        'BRENNAN', 'MAYALA', 'PASSONNO', 'HEGSTED', 'FRILING/COTHERN',
#        'EUGENE BOOS', 'BENHAM', 'PHILLIPS', 'LAWRENCE', 'JOE ALMON',
#        'SHANKS/BECKER', 'ELLIS', 'TAPASZY', 'RARSCH', 'MURPHY',
#        'FORBES-WOLFRAM SPECIAL', 'ALEXANDER', 'NORD (SNCAN)',
#        'JEROME DODGE', 'INAV', 'STAR DUSTER', 'MCCOY ROBERT-MICHAEL',
#        'WHITE LIGHTNING AIRCRAFT CORP.', 'FLOYD R.HARRIS',
#        'WALTER D. BURLESON', 'GILLON', 'SMITH & R. MATHEWS',
#        'STAHL-AMETER', 'BUHL', 'JAMES OLIVIER', 'JERE L. ROSSER',
#        'RALLEY', 'KOONS-DONALD', 'HOUK', 'TURNBLOOM', 'HICKHAM',
#        'DEVRIES', 'MULLINAX', 'ROHDECAP/THORP', 'MOORE-VAN',
#        'NORTH AMERICAN-MASLON', 'SOLEM', 'ATR', 'BEGGS', 'KOSCH',
#        'MARRONE', 'DORNIER', 'MICHAEL D. MANSFIELD', 'AIR COMMAND',
#        'RICHARD A. BROWN', 'STRISSEL', 'PRUE STANDARD', 'RESNEY',
#        'KENNY DEWARD', 'BARLOW', 'AERO MIRAGE', 'REPLICA', 'VERBEEK',
#        'SPRAGUE', 'MCLACHLAN', 'HUNTER', 'DEVORE SUNBIRD', 'CREMER',
#        'JAGGER', 'MCLANE', 'FRIMELT WERNER MONI', 'SPARTAN', 'LAW',
#        'WOEHRLE', 'PIK', 'BEAUSOLEIL', 'MOSS TIMOTHY C', 'NOONAN',
#        'MEYER', 'NORTHROP', 'HUFFMAN', 'MONI', 'BUTLER', 'HAM',
#        'AERODYNAMICS .', 'ZANK', 'GASTON/LAKES', 'GRECO BRUNO',
#        'BANNWART', 'KENNEDY', 'CONCEPT', 'DENNEY', 'TALBOTT', 'MCENTEE',
#        'ROLLINS', 'TEAGUE', 'LOWDER', 'NOBLE', 'KIESEL', 'WAYNE HOOKS',
#        'GREAT LAKES ADAMS', 'BUDDE CASSUTT', 'DUBOIS', 'FLEET',
#        'HASTINGS', 'HENDRICKSON', 'SCHARSCHMIDT', 'ROE/PIETENPOL',
#        'WATTS', 'RUSHTON', 'BUCCANEER', 'ALLEN', 'BURKHOLDER',
#        'WILLIAM M. BURGE', 'ARNOLD', 'EMBREE', 'MAXFIELD', 'REDER',
#        'LUTZ', 'SAWYER', 'CANTON', 'BOYLES', 'HALL',
#        'GOVERNMENT AIRCRAFT FACT (GAF)', 'TOMISHIN', 'NATIONAL BALLOON',
#        'KOLB COMPANY', 'WOODY', 'GEIGER', 'MERCER', 'COMMONWEALTH',
#        'ELLSWORTH', 'BAKENG', 'G&C HELICOPTERS', 'BENNETTER-STEVENS',
#        'WILLI/BENSEN', 'NIXON', 'KLIEN', 'ROGERS-GIBSON',
#        'WATKINS/MONNETT', 'QUESTAIR', 'NAPPER', 'EXTRA FLUGZEUGBAU',
#        'PUGH', 'STITS', 'WARNKE', 'PARRISH', 'MERCHANT', 'COUDEN',
#        'DURBIN', 'LAMB', 'HERMAN', 'SADLER', 'ALEXANDER VOLKSPLANE',
#        'STOOPIN', 'CRUMP', 'MANDLEY', 'ISGRIGG', 'CRUSENBERRY', 'COLMAN',
#        'TIMM', 'HESS', 'GRIBOSH', 'HILL', 'HODGES', 'SHINER', 'WEBER',
#        'BUNCH EAA BIPLANE', 'MORANE-SAULNIER', 'BARNETT', 'GROSVENOR',
#        'PAGE', 'SURLINE', 'PAXTON', 'MARREK SMYTH', 'MARLOW HILYARD',
#        'KITCHEN', 'DREYER-STARDUSTER', 'START & FLUG', 'NEFF',
#        'ANDERSON PITTS', 'FALCON SPECIAL', 'FISCHER', 'HENDERSON',
#        'CIRRUS DESIGN CORP.', 'HERNANDEZ', 'NEW', 'SCHUMANN', 'HYDE',
#        'STOLP-STARDUSTER TOO', 'HURD/DRIFTER', 'STARR', 'JUDGE',
#        'MCCURRY', 'CHAPPEL', 'LLOYD FEARY', 'BOST', 'BOHNKER',
#        'BYRON/SORRELL', 'CRAVEN', 'KOOPSEN', 'KERLIN', 'TERRY',
#        'ANDERSON-TUCKER', 'TERATRON', 'BARON', 'DARLINGTON',
#        'HELFRICH-LEONARD', 'LOCOLCE/BLACKWELL', 'VAN WORMER', 'RUTGERS',
#        'FRANKLIN', 'HUNTLEY', 'HAHN', 'GULFSTREAM AEROSPACE',
#        'CLASSIC AIRCRAFT CORP.', 'SOLLARS', 'APPLEBAY',
#        'FANTASY SKY PROMOTIONS', 'SILLIMAN', 'COSTA', 'GEDDES', 'ATKINS',
#        'FERRIS', 'WILLIAMS', 'KRALL', 'VANS', 'SHIRLAN DICKEY', 'TOWNSON',
#        'VAN', 'STANFORD', 'BRASWELL', 'PRAIRIE FLYERS', 'ROSSI PITTS',
#        'ROSENMAYER', 'FALCO', 'COCKS', 'WITTMAN', 'HULLIBERGER', 'MACE',
#        'SACKETT', 'DEBARRY/STARDUSTER', 'TEDFORD', 'LATHAM ALCO',
#        'GARLICK/GUPPY', 'COMMENS', 'ARTHUR', 'THUNDER AND COLT',
#        'YOUNG-OWENS', 'BANKS/MONG', 'BILLINGS/HUMBYRD', 'DILLINGER',
#        'SNYDER', 'HEIBEL', 'SVENSSON', 'BINGELIS', 'BARKER',
#        'CESSNA ROBERTSON', 'SHANNON', 'PILGRIM', 'SHAMGAUGH', 'ROMAN',
#        'AUTRA', 'VANGORDEN', 'LEWIS', 'LAYCOCK', 'ARLINGTON',
#        'HICKS/MERVIN', 'EXPERIMENTAL', 'MICKELSON',
#        'SAAB-SCANIA AB (SAAB)', 'KLOB-GORDON', 'SANDRIDGE', 'HITCHCOCK',
#        'TESORI', 'KNOWLES', 'BEARD', 'SLOAN', 'BUMGARTNER/HIRT',
#        'G.D.I.E.', 'MURPHEY', 'MASON', 'LEHMAN/JERRELL', 'WAR REPLICAS',
#        'STOLP-ADAMS', 'HARMON', 'WARWICK', 'ELLER',
#        'COMPOSITE AIRCRAFT MFG CO.', 'AEROMOT', 'RODGERS', 'STEARNS',
#        "CRAVEN'S QUICKIE", 'JENNINGS', 'AIRCRAFT PARTS & DEV. CORP',
#        'HALSTEAD', "VAN'S/FISH", 'POEHLS', 'UPCHURCH', 'DYAR',
#        'LEE, DAVID', 'SCHMAHL', 'LOWE', 'THIESSEN', 'SHARP', 'MORSE',
#        'COUTZ', 'VESTAL', 'DONNER/PARTON', 'BRIDGES', 'TESMER GLASSAIR',
#        'GRIGG/BOWERS', 'GALBREATH', 'SMITHGALL PITTS SPECIAL',
#        'DAVIS STARSHIP', 'FIELDS', 'AVIONS MAX HOLSTE', 'PAZMANY',
#        'BILLINGS/WHITE', 'ZENGEL', 'RUSCHKE', 'GLASSAIR III',
#        'HOLMAN/SEARS', 'BLOODWORTH', 'DILLEY', 'CUSHING', 'GOOD', 'JOB',
#        'WHITTAKER', 'HADLEY', 'OREGON HELICOPTERS', 'UHLEY-MASON',
#        'COX/PITTS', 'BENETEAU', 'BEAUCHESNE/WELLS', 'SCHUNING/TERATORN',
#        'RENNINGER', 'VEHAFRIC', 'WOOD-OLDFIELD', 'MUSICK/TERRATORN',
#        'STITTS', 'PROGRESS AERO R&D', 'HENRY VICKERS', 'SALMON',
#        'BRISTOW', 'LOWE/BENSEN', 'MIRSEPASY', 'WITTMAN, S.J.', 'CLOUD',
#        'KING', 'CABRINHA/FREE SPIRIT', 'BONDS & BUNGEY', 'PROSPECTOR',
#        'JAMES EGGLESTON', 'ABBOTT', 'LANCAIR', 'GATZEMEYER 88', 'KEENER',
#        'BRATTON', 'DAMMANN', 'ACRODUSTER', 'SKELTON', 'MCCORMICK',
#        'COCCHIARELLA', 'DORMOY', 'TIERRA II', 'FEIL', 'BRUMBAUGH/HUBIN',
#        'BRADLEY', 'RUPPERCHT', 'MONETT', 'RAYNE', 'CLATTI',
#        'HARRIS-HAFEN', 'MINICAB', 'WOODS', 'YAKOVLEV', 'MAXAIR', 'WESLEY',
#        'SOURS/MIDGET MUSTANG', 'COOLEY', 'HOWE', 'EVANSON', 'NIEDZIELSKI',
#        'SKILLING', 'FLETCHER', 'HANCOCK', 'STOLP STARDUSTER',
#        'STITS-ITRICH', 'ZIMMERMAN', 'SMEESTERS', 'ROGER NELSON',
#        'BAKER/SANTIAGO PITTS', 'BRICKMAN', 'RAND ENGINEERING',
#        'MANNON-UNDERWOOD', 'WYCHEN', 'WHEELER ACFT. CO.',
#        'FUNK, D.D. AVIATION CO.', 'EICKMEIER', 'MCCOMB', 'POND',
#        'WARREN/KELEHER/LARK', 'BELL-KITZ KOPTERS', 'BURDETTE',
#        'BRUCE MCKINNEY', 'LANIER', 'LOGAN, B.A.', 'WITTMAN TAILWIND',
#        'NELSEN-DAVID', 'SAINT LOUIS', 'EDWARD', 'BRYCE DUSTER',
#        'CRAWFORD-GORDON', 'SENIOR AEROSPORT/PAET', 'TUNDERMANN VENNE',
#        'LONG E-Z-E', 'STEELE', 'DAVIDSON', 'WALDRON', 'MANCINI',
#        'STANGER', 'CONN', 'BIAGI, ARTHUR R.', 'THOMPSON',
#        'C&J SONTHEIMER', 'GROVES', 'HEINDENREICH', 'RANSOME', 'BURTON',
#        'REID', 'LINK', 'WOHLERS', 'TALMADGE SCOTT', 'SMYTH SIDEWINDER',
#        'FREEMAN H EASTON', 'WALTER HUDSON', 'JAMES A NELSON',
#        'FARRINGTON', 'SWING', 'BECKER', 'JOLLY', 'DANIELS', 'HOOD',
#        'TRUCKEE MEADOWS', 'STOLT', 'BENNETT', 'AVIONS MUDRY',
#        'RYAN, ROBERT R.', 'DAN T. ZELAZO', 'WILLIAMS, ROBERT G.',
#        'LERSTANG', 'MICHAEL C. QUIGLEY', 'LIGHTCAP', 'BELL-MOORE',
#        'TOUSSAINT/QUAD CITY', 'CUNNINGHAM', 'ROBERT VAN SCOYOC',
#        'CECIL, RICHARD C.', 'SABELINO', 'GOSS', 'BATALLER',
#        '67 FLYING DUTCHMAN', 'ROLLINS-BOWERS', 'SATTLER', 'CULLEN/ROTH',
#        'SPEZIO SPORT', 'LUND', 'BRIEGLEB', 'GRACE', 'GYROFLUG',
#        'CIRRUS KLAPPMEIER', 'VANEK', 'AERODYNE', 'RAY EDMISTONN',
#        'K. W. JEFFERS', 'EUGENE M. VERAS', 'SUKHOI', 'BUCHANAN',
#        'ROBERT C. CAMPBELL', 'CHILDS', 'EUGENE N. RAUSCH',
#        'SPARK/ACRODUSTER', 'GARY WILLIAMS', 'OO-CULLEY', 'DICKEY',
#        'MINGESS-BENNETT', 'CASSUIT', 'HARDESTY/HAYS',
#        'LARSEN CHARLES BENNETT', 'SELSTAD', 'E.J. NOVOTNY', 'HUFFAHER',
#        'CHARLES T. BRIETIGAM', 'RONALD D. COTHERN', 'OLSEN',
#        'GEORGE R. LOSEY', 'DAVID B. ROBERTSON', 'CLOUTIER',
#        'WHEELER TECHNOLOGY, INC.', 'CUSTOM AEROTECH, INC.', 'FOUGA',
#        'FINN A. ARNOLD', 'BELL-CONTINENTAL COPTERS', 'FORBING',
#        'LEFFLER/MCFARLANE', 'BRYANT ROWLAND', 'BD 4- FRANCISCO', 'BOSON',
#        'HILVETY', 'BENNERT', 'PROSSER', 'WARKENTIN', 'DON G. KAYE',
#        'ILLI', 'NAAMAN HAREN', 'HARPER', 'VADEN', 'ALFRED STEVENS',
#        'MICALIZIO', 'CALVART', 'NEAL', 'HEINRICHS',
#        'FISHER FLYING PRODUCTS', 'TRICE', 'CHRISTEN/WALTER',
#        'AEROSPATIALE/SOCATA', 'BROSE', 'TRAMMEL', 'MILES ATWOOD',
#        'BOB SANDLIN', 'MORRIS', 'BLAINE LAUX', 'COMBEN', 'DOOLEY',
#        'PARRIGIN', 'MASSEGEE', 'ROGER A HANSEN', 'ELY', 'BLAISE',
#        'MOFFITT, WILLIAM A.', 'FOLLAND', 'CARLSON AIRCRAFT',
#        'JEFF PIERSON', 'PALEN', 'ERIK K. VAN DER KAAY', 'MELTON',
#        'HISTORICAL AIRCRAFT CORP.', 'SKYTEK', 'JAMES COTE',
#        'JOSEPH W. HILLBRAND', 'E TN PLTS STARDUSTER', 'JOE L. HARR',
#        'DANIEL S. TAYLOR', 'OLSEN-GORDON', 'MARIER', 'DEAN BARTEL',
#        'YOUNG', 'FOGARTY PITTS', 'CRAIG A. GORDON', 'TAYLOR TITCH',
#        'ROBERT BRESSLER', 'LOWE/LAW', 'ASTA', 'ASTAR', 'VIRGIL D. HAWKS',
#        'MOCOCK', 'RANS COMPANY', 'WALTER CHANDLER', 'RIDDELL', 'HAGG',
#        'DONALD E. SAMUELS', 'HUDDLESTON/BECKTOLD', 'QUESTAIRE',
#        'AVIONS MARCEL DASSAULT', 'PARKER WARREN', 'LATHAM',
#        'BARTHOLOMEW KOLB', 'ELLIOTT', 'CLYDE L. KING',
#        'MONOCOUPE AIRCRAFT', 'GLASSAIR', 'HERBERT W. ROSS', 'DAVID LOWE',
#        'AKINS', 'SUNRISE ULTRALIGHT', 'PAULBICKE', 'GLASAIR III',
#        'BURNETT, JERRY D.', 'BRAULT GLASAIR', 'SNIDER', 'FRED B. STENCEL',
#        'TOWNSEND', 'SCHWARTZ', 'SMELSER', 'FAGERBERG',
#        'RUTAN AIRCRAFT FACTORY', 'RUDOLPH ZELLER', 'DONALD L. HEDEMAN',
#        'W. R. MATHIS', 'AEROSPACE TECH. OF AUSTRALIA', 'RICHARD CHENEY',
#        'VUNCANNON', 'GILDERSLEEVE', 'UNIVERSAL GLOBE', 'TIERRA',
#        'CORLEY HUBERT', 'AUSTRALITE', 'GEORGE E HEIDE, JR.',
#        'DAVID K. MAXWELL', 'BEAMONT', 'DAVE RONNEBERG',
#        'ALEXANDER SCHLEICHER', 'GREG SMITH', 'LAROCQUE, RAYMOND E.',
#        'PEECHER', 'CHARLES RAUCCI, JR.', 'GREMMINGER', 'AVID FLYER INC.',
#        'HAGAMAN PITTS', 'BRONNER', 'WEAVER', 'RIDER-CHARLES', 'DUFFY',
#        'JACK THOMAS', 'ALLAN R. GOLDMAN', 'GREEN-FOWLER', 'HEAL',
#        'PAUL M. F. WALKER', 'SEBLY AMATEUR BUILT', 'STERNS',
#        'DANIEL LA LEE', 'LGS AVIATION, INC.', 'JERRELL', 'DEREGO',
#        'WILBUR D. BATMAN', 'GALAXY', 'LACEY', 'MOECKEL', 'E.C TRYNKA',
#        'MORRISON-KEITEL', 'AIRNEW, INC.', 'DONALD R. LEE',
#        'SCHRADER, EDWARD', 'LUCKY', 'AEROSPACE', "O'CONNELL",
#        'VALENTIN GMB H', 'MARIDON', 'GRIMM', 'ENGLISH',
#        'FINK, CHARLES H.', 'AL WHITE', 'HINTON', 'WARNER, DAVID B.',
#        'GORDORN PRICE', 'LAURENT A. CLOUTIER', 'TAYLOR AIR COMMAND',
#        'CLIFTON DIXON', 'SCHULTZ', 'LARS', 'MILNER, DICK G',
#        'CANADIAN CAR & FOUNDRY', 'BECKLOFF', 'MANVILLE',
#        'BENSON/AMBROCINI/WENTZEL', 'HAROLD J. EAGEN', 'WEYERTS',
#        'PILATUS BRITTEN-NORMAN', 'BEIERLE', 'FRILING', 'HOCKER', 'TULLIS',
#        'ICARD, CLAUDE M.', 'BATES, FRANK L', 'CRESAWN PITTS', 'MERRITT',
#        'TIMOTHY WINGATE', 'BELL-K COPTER', 'DONALD W. SORRELS',
#        'JOHN H. LOGAN', 'HOFFMEYER', 'BOLAND/POE', 'JOSEPH A. MULLAN',
#        'ABERNATHY', 'CHRISTIAN IND.', 'JOSEPH P. FRASCA',
#        'LYONS STUECKLE', 'ULLMAN', 'CANO', 'BENTLEY',
#        "O'DELL, HERBERT L.", 'CHALLENGER II', 'DENNEY AIRCRAFT BEHN',
#        'MCHOLLAND', 'LASSITER', 'DON JACKMAN', 'WINCHESTER',
#        'MAHAN HARDAWAY', 'JESSE KNIGHT', 'BALKEMA/BOVEN',
#        'WILLKINS-WAYNE', 'GEORGA L. ATWOOD', 'ADVANCED AVIATION',
#        'SPEYER', 'KITFOX TEN, INC', 'BELL-TRANSWORLD', 'HILLER-OSBORN',
#        'NORTH AMERICAN-KENNEY', 'JOHN W UPTON', 'QUICKIE AIRCRAFT',
#        'DEVENPORT', 'KINKADE E.5', 'SMITH/DAVIS', 'ALVIN D. CAMPBELL',
#        'WALTER R. PENNEY', 'MOSLEY HS', 'JAMES HOUSTON', 'AIR TRANS. INC',
#        'WARFIELD', 'AERO MERCANTIL S.A.', 'RAYMOND BRISTOW', '85 MANISTA',
#        'QUAD CITY', 'RICHARD C. BALLOW', 'RALPH LEGATE',
#        'KNA,KEN,DAC,WEL', 'AVIONS FAIREY', 'MICHAEL CONNER', 'D.W. OWENS',
#        'ROBERT L. RICE', 'WIND RYDER', 'JR. ACE', 'ANKERMAN, DONALD L.',
#        'WILLIAM D. WEEKS', 'GERALD G. HOLLAND', 'MAYA, JAIME',
#        'JAMES D. RIEHM', 'AVID AIRCRAFT', 'R. W. SWITZER', 'TOMLINSON',
#        'PZL-OKECIE', 'GEORGE ADRIAN', 'CAREY GLASSAIR', 'MCEWEN DICK',
#        'STOLTZFUS', 'GUY WHISENANT', 'FLIGHT WORKS CAPELLA',
#        'ROSE WESLEY', 'EICHBLATT', 'CRAIG MOREHEAD', 'LARRY E. MEDLIN',
#        'WISHON', 'SHEWMAKER', 'SAM R. CROWELL', 'GILLESPIE/PITTS',
#        'LAWRENCE H. MACEY', 'AVIAT', 'NANCHANG', 'CORBUS/WINTERS',
#        'CEDRIC LEWELLEN', 'MCQUEN', 'ROBERT GRIFFITHS', 'BRANTLY-HYNES',
#        'E.E. SHILLING', 'JAMES D. BIERLY', 'COBB INTL',
#        'DONALD E. CROCKER', 'ARDOVINO MARIUCCI', 'WILLIS', 'SCHWEITZER',
#        'RICHARD N. BURNS', 'A. H. GETTINGS', 'RUTTER', 'WICKS',
#        'RONNIE BAKER', 'HOPKINS, R. AND M.', 'PARRISH, PAUL',
#        'WAYNE K. GILES', 'JACANIN', 'COMMANDER', 'LEWIS-STARDUSTER',
#        'BARTON, ROBERT A.', 'TAKEMOTO', 'MURDOCK/GATES/FIELD',
#        'POKORNEY SMITH', 'VANDENBOS/THORP', 'JAMES J. DEAN', 'MCLAUGHLIN',
#        'GUZZINO, P.A.', 'WILLIAM BOVARD', 'PERES', 'VICTOR E. NIGRO',
#        'DENNIS L. FETTERS', 'GOEHRING', 'HARRIMAN', 'DANNY W. SADEK',
#        'MADSEN', 'BELL-WORLD', 'JIMI YOUNGBLOOD', 'DOFKA, MARTIN F.',
#        'HOLMES-SALLEY/STARDUSTER TOO', 'VIRGIL LARSON',
#        'BERNARD W. RESNIK', "O'DONNELL", 'BORGAES', 'JOHN SCHACKEL',
#        'JOHANSEN', 'DANIEL M. DENT', 'TOWNSEND-SNYDER', 'BERKSHIRE MFG.',
#        'KRUG', 'KORY G. CORNUM', 'THOMSEN, HORST', 'HAAS',
#        'HAUSER, WILLIAM C.', 'JAMES SNYDER', 'GEORGE A CHAFFEE',
#        'JAMES SCHWARZMAN', 'CHAPUIS', 'DEWITT, RICHARD A.', 'GRETH',
#        'ROBERT D. WALDRON', 'ALKIRE', 'RANS', 'DONALD L. BETCHAN',
#        'MERCURY', 'BULL', 'CESSNA REEMS', 'EDRA/MCDERMITT',
#        'JOHN K. GROFF JR.', 'JOHN MITCHELL', 'JARRELL', 'BACON',
#        'DANNY M DAMRON', 'BROUSSARD', 'SCHNEIDER/BRASHEAR',
#        'JOHN S. HOLZEMER', 'STUART J. CARTER', 'R.P. WILLIAMS', 'FROST',
#        'BENSON-CALLAWAY', 'GERALD BARKER', 'SCHAKNOWSKI', 'TBM, SA',
#        'WOODSTOCK', 'WILLIAM C. KEILING', 'LAMB/STARDUSTER', 'REIF',
#        'DALE CONOVER', 'SNODGRASS', 'CURT HOFFSTAD', 'YORK',
#        'WARREN-THOMAS', 'TENNESSEE ENGINEERING & MANF', 'SLADE H. HOLMES',
#        'TINSMAN', 'TROY BELLAH', 'SPARKS-SCHREDER', 'RETTBERG',
#        'ABRAMS/NUDING', 'LANCEAIR', 'GOLIGHTLY, ROBERT B.', 'CLATANOFF',
#        'CARLSON', 'SMITROVICH', 'MCILRAITH', 'RICHARD O. MIDDLEN',
#        'SWICH', 'FRANKLIN-SULLIVAN TECHNOLOGIES', "O'CONNOR",
#        'JAMES R. PRIDEAUX', 'HARKNESS, RICHARD W.', 'GILBERT',
#        'VUNCANNON ROTORWAY', 'PATRICK F. BOWERS', 'PASPORELLO, J.F.',
#        'MARCY', 'R.W. SHERMAN', 'TODD GOUDEAU', 'COLGATE, HENRY A.',
#        'LITCHFORD', 'MASON, JACK A.', 'VAN ARSDELL/BRENT,M.', 'LYDICK',
#        'CUEVAS, ORLANDO S.', 'DONALD RHODES', 'SHAW', 'CROY',
#        'BUNN, RICHARD B.', 'DON SHOWALTER', 'KELLER', 'FERRAN', 'BATES',
#        'H. RAYMOND', 'BERTONE', 'AMERICAN GENERAL AIRCRAFT',
#        'CESSNA SOLOY', 'MORGAN', 'SCHICORA', 'HUDDLESTON-BELL',
#        'LANGERUD', 'ASSELYN', 'ROOT, ARTHUR T.', 'ACRO SPORT',
#        'E.L. ERICKSON', 'MISTRETTA', 'BARR', 'KIBIUK', 'SILVA',
#        'JOHN THOMASON', 'ROY REY', 'VAUGHAN', 'FAWCETT',
#        'KOJIMA, JUN LEWIS', 'VIOLET', 'KERTESZ', 'SIEGEL', 'MCREYNOLDS',
#        'ISEMAN', 'BRUCE', 'DOBBS', 'TUTTLE', 'SNOBIRD', 'HOMER DAVIS',
#        'STEVEN KURTIS', 'MACPHEE', 'MCMILLIN', 'LEVECK', 'HALTOM',
#        'T.R. BRISTOL', 'WITTS & CHURCH', 'ZEIGLER', 'EXTRA',
#        'FOREST RIPLEY', 'RAPP', 'HOCKENBURY', 'GROVE', 'BRYANT', 'MEADOR',
#        'RAINEY', 'LARKIN', 'RAMBOW', 'JOHN SHUFFLEBARGER', 'US/LTA',
#        'WSK PZL', 'SCHMIDT', 'AMATO', 'MARK STREITZ', 'HENRY J. CAMACHO',
#        'DRLIK', 'CLAUDE E. MERRIN', 'PZL WARZAWA-OKECIE',
#        'SAYER, TREVOR A.', 'ROBERT L. KENNEDY', 'SKILLMAN', 'TUCKER',
#        'EMORY W. GREER, JR.', 'REIMS AVIATION', 'GRITTER', 'ROMIG',
#        'RAYMOND', 'SMITRVICH STARDUSTER', 'SILL/THOMAS', 'IRVING SIEWERT',
#        'GLENN', 'DANIEL SQUIRE', 'TITAN AIRCRAFT', 'DOELLEFELD',
#        'CROWSER', 'WERNEGA', 'ADOLFSON', 'HOOPES', 'WILEY',
#        'AMERICAN EUROCOPTER', 'SCHULTZ/BOWERS', 'QUAD CITY AIRCRAFT',
#        'ROLANDO', 'HANCOCK- HARRIS', 'STARK RAND', 'ZBACNICK', 'BEATTY',
#        'CURRY', 'STOECKLER', 'KROWELL', 'FERDON', 'RICHES', 'NALL',
#        'HARRAL', 'HOWARD W. DUTTON', 'HADALLER', 'SUKANE', 'GERA',
#        'KIT FOX', 'DARST', 'AERO FALCON INTL., INC.', 'BRAUCH',
#        'LOVE, SANFORD W.', 'WM. D. BUTTERILL MUSTANG',
#        'WALTER D. COURTNEY', 'EKINS', 'R.D. BELL/PIETENPOL', 'KOPE',
#        'ULTIMATE', 'R. J. MCNAUL', 'JORDI, RONALD H.',
#        'BRADFORD PIETENPOL', 'SHEATS', 'BUSBY', 'REHER, KENT O.',
#        'KEUTHAN', 'LACH', 'COEN', 'MASCOLA', 'WESTHOLM', 'SMYTH',
#        'FERRIE', 'STERNER', 'WILSON', 'LEGRAND', 'ALFRED F. DIBERNARDINO',
#        'R&K SPECIAL', 'SCALED COMPOSITES', 'KEWLEY', 'CORNWELL',
#        'MCINROY', 'WHITE', 'KELM', 'CRYDER', 'FEATHERSTON', 'EMMERT',
#        'SCHLAPPI', 'HANNAH', 'SILVER', 'SPRINGER', 'LOVERN',
#        'BOWERMASTER', 'HAWKINS & POWERS', 'FLAKE', 'SCOTT', 'VACEY',
#        'COOPRIDER', 'ANGEL ELBERT S JR', 'BELL-CARSON', 'ALBRECHT',
#        'STEVEN ULRICH', 'KROTJE', 'JETSTREAM', 'CLEVELAND', 'BRAEGGER',
#        'UPTON', 'WONDER', 'EBERSHOFF', 'CARSON', 'GOLIGHTLY',
#        'SOMMERAUER', 'PALMER', 'NELSON', 'CLUNIS', 'FURCHE-BIELSKO',
#        'PLUMMER', 'OCONNELL', 'CANNON', 'LAMPMAN', 'ROBERTS',
#        'GANSHEIMER', 'ARGO', 'JENKS', 'MIKOYAN MIG', 'HARPER, JACK M.',
#        'CORBY STARLET', 'DAFFRON, HAROLD C.', 'PIOTROWSKI', 'UNREIN',
#        'KELLEY', 'AMERICAN CHAMPION (ACAC)', 'FIGHTER REBUILDERS',
#        'DEFELICI', 'RANDOLPH FLAGG', 'WALLACE', 'FOOTE', 'ROBERT O. ELY',
#        'ABC', 'TALAGO', 'BACK FORTY DEVELOPMENTS', 'ASHER', 'NEWGARD',
#        'JACOBSON', 'REMOTE SENSING', 'LAUREL AERO CLUB',
#        'VAVRA, MARTIN A.', 'RICH', 'FERGUSON', 'AIR CREATION',
#        'HESTERLEE', 'BLACKMUN, LARRY', 'ROBL', 'RICHMOND', 'HALLSTROM',
#        'TOWNSEND, H.L.', 'KELLY', 'MID STATE ULTRA LIGHT', 'HILLBERG',
#        'PRAKER THORP', 'BRADFORD', 'STAUDACHER', 'WRAY', 'PARKER',
#        'PERTH AMBOY', 'DONNER PITTS', 'LATTER', 'KOPP',
#        'MAXAIR AIRCRAFT CORP.', 'PECCHIO', 'WSK PZL KROSNO',
#        'HAYES/PIETENPOL', '1ST FTR GP', 'POPEHN ARTHUR J.',
#        'PRUE IRVING OWEN', 'HRUBY', 'FALEN', 'SCHUMACHER',
#        'TWIBELL RICHARD DALE', 'ARTHUR ALAN BLIND', 'BELLAH', 'SCHELL',
#        'MASCARI', 'STOLTE', 'RILEY, DONALD', 'MARVIN E. EUBANKS',
#        'STEPHEN', 'PAYNE FOSTER', 'BOURQUE EXPERIMENTAL', 'MUSTARI',
#        'MUELLER', 'DERR', 'FULLANA', 'HUNSBERGER', 'HUCKE, RONALD L.',
#        'FRANK M. KOPECKY', 'BAMBRICK', 'SAM HALE', 'HICKEY', 'FREEMAN',
#        'HAWK', 'EDWARD A. ALDERFER', 'DONOVAN', 'INMAN', 'ACES HIGH',
#        'MONTANA', 'MILLER, JOHN', 'LATTIMORE-DWYER', 'ARTHUR CHASE',
#        'STARMAN', 'GROCE', 'KEUTHAN, CHARLES J.', 'STUGART', 'STULP',
#        'HANKINS/DICKERSON', 'LAFRANCE V-WITT', 'ALLEN D. POTTS',
#        'SCHREIBER-STITTS', 'WATSON', 'ADVANCE AVIATION', 'ADVANCED ACFT',
#        'ROBERT ELDON IDLER', 'MANKOVICH', 'FRITH', 'WALTON',
#        'A. LE FRANCOIS', 'THALMAN', 'DONALD E. KOVOL', 'WILLIAM P. BOUDA',
#        'JAMES CHISUM', 'EUROCOPTER', 'SMART', 'WDL', 'SINGER',
#        'MOONEY, DAN', 'QUICKIE-MYERS', 'OESTREICH', 'PREST', 'ULTRALIGHT',
#        'DOOLEY, JAMES M', 'JAMES B. EDWARDS', 'CORLEY',
#        'THOMAS E. GEORGES', 'SIMCOX', 'MCMURTRIE', 'WINN', 'BONY',
#        'GLINES', 'LARSEN', 'REY', 'RANS/HINE', 'S M A N',
#        'STAN G. HALLAM', 'HERRON', 'ANGEL', 'GEORGE',
#        'UNITED CONSULTANT CORP.', 'NORTH AMERICAN-BARENE', 'BRISENDINE',
#        'GLEN A. SENECAL', 'FIGHTER ESCORT WINGS LTD', 'LESSEL',
#        'BARTHOLOMEW', 'WEEKS', 'P. D. CHAMBERS', 'WILLIAM MC GLUMPHY',
#        'COLVIN', 'ELVIN N. KIER', 'TIMOTHY J BROWN', 'RENDER', 'WYMAN',
#        'HOOVER', 'LARSON, C.H.', 'GAY', 'MATTO', 'STUART/WAGNER',
#        'BEEBE, DALE G.', 'CRAIGHEAD', 'ROY', 'BRUCE TIFFT',
#        'MORRISON, MARVIN E.', 'SCHMANSKI', 'BURKEN', 'HINSHAW, KEITH T.',
#        'CUMBERLAND-PITTS SPECIAL', 'BEECHER', 'WENTE',
#        'RYAN AERONAUTICAL', 'ROGGIO', 'BAKER', 'BULSKY', 'ANDRIS',
#        'GARRISON', 'HASELOH, D. W.', 'ECCKER, DONALD E.',
#        'PACKARD/SQUIRE', 'K. A. COVINGTON', 'STEMBRIDGE', 'KIRKPATRICK',
#        'SWANT', 'DUKE, CLARENCE E.', 'BRIGGS', 'BAXTER-WILSON', 'FABRE',
#        'KORZEP', 'AXELL, CHARLES', 'BUBEL, JOHN A.', 'KNAPP', 'SORREL',
#        'GODKEY', 'GRUNSKA EARL J', 'HARDING', 'PITCHER', 'STOL', 'ERWIN',
#        'PURDY', 'BAILEY', 'SCHLAGENHAUF', 'MONCRIEF', 'CORNELIUS',
#        'KNOLL-BENSEN', 'BURCHFIELD', 'DEVAUGHN', 'TOM KILGORE', 'STOKES',
#        'BRONISLAUS', 'JOY', 'BERG', 'WALTER W. BELL', 'BALL',
#        'TUPTA-SMITH MINIPLANE', 'ISSOIRE-AVIATION', 'WILLINGHAM, DAVE L.',
#        'ED BERGREEN', 'ROCKY MOUNTAIN', 'SPREUER', 'KEMP', 'COCCHI',
#        'PINCINCE', 'GRINER', 'SAGERSER', 'FIELD', 'MILLER, TERRY W.',
#        'KNOSP', 'NICOLAS BEASELY', 'KASHPUREFF', 'FIRST STRIKE', 'KOVAL',
#        'BOTTERON', 'STAFFORD', 'EDWIN J. ESTENSON', 'CRAIG', 'QUADCITY',
#        'MARGESON/HEIDEBRINK', 'DARRELL', 'WILLIAMS BELL', 'STEINKE',
#        'K. DAVEY AND B. DAVEY', 'KENNETH SAVIDGE',
#        'REVOLUTION HELICOPTER', 'PEDERSON', 'FOX AIRCRAFT CORP.',
#        'MCNULTY', 'HUGHLETT', 'VAN ZWOLL', 'YOTHMENT', 'GUEVREMONT',
#        'RONNEBERG/MURPHY', 'KINNER', 'BIRDMAN ENTERPRISES, INC.', 'PARK',
#        'GETTIG', 'RONSRANS', 'KRAETZNER', 'INSUA', 'SHORT', 'ISAACSON',
#        'MARKWOOD', 'ELAN GLASER DIRKS', 'JOSEPHSON', 'BRISTOL',
#        'KIESEL EASY', 'KEVIN NASER', 'FLOYD', 'MORROW', 'PATIN', 'GILLET',
#        'CHAMBERS', 'WELLES', 'GIFT', 'BALLOONBAU WOERNER GMBH',
#        'SINCLAIR', 'SJOSTRAND', 'HAUGEN', 'HARD', 'SNYDED', 'FRATUS',
#        'MCCLINTIC-PIERCIE', 'DEANGELO', 'MENEAR PITTS',
#        'PRO-BUILT AVIATION', 'RASMUSSEN', 'RUDY', 'CLAPP', 'CHENEY',
#        'DONEGAN BENTON', 'SCHLITTER', 'RUPE', 'LOUKS', 'MADSEN/RANS',
#        'CHARD', 'BLATTER-PITTS', 'KELOSKY', 'ROISUM TEAM',
#        'LOPEZ LANCAIR', 'CROWLEY/ZENAIR', 'PETRIK', 'FALLBECK',
#        'EAA CHAPTER 163', 'PEZOLD', 'BISCHOFF', 'COOKE', 'LODGE',
#        'LYNCH STARDUSTER', 'DIAMOND AIRCRAFT INDUSTRIES', 'SELLORS',
#        'KRUGLER', 'HARDESTY/HAYS QUICKIE', 'MCCLUNG', 'SCHAFER',
#        'GRAICHEN', 'KOUTZ', 'HERRING', 'ROBERT ECKLEY', 'MCKIBBEN',
#        'BITONTI', 'OTIS', 'PRO STAR', 'MORAVAN', 'MUMM', 'NICHOLSON',
#        'KLINGBERG MINIPLANE', 'SEMPLE', 'KRUETER',
#        'ROTOR FLIGHT DYNAMICS', 'GILPATRICK', 'CONNELL',
#        'ROBIN, AVIONS PIERRE', 'MASNIC', 'MADORIN', 'MCRAE', 'STEEVES',
#        'MARKS', 'WORTHINGTON', 'KITFOX', 'BISHOP-CHRISTIAN', 'BUMFORD',
#        'SUMMERFELDT', 'MULHOLLAND', 'SCHEPERLE', 'DOMAILLE', 'LUCKETT',
#        'RUSSMAN', 'LAMPERT', 'MEEKER', 'POWELL', 'VAN DYKE', 'TWIBELL',
#        'SPORT FLIGHT', 'GAGE', 'SNOWBIRD', 'EXPLORER POST 51', 'LEMOINE',
#        'FORTH', 'VERNON L. COX', 'LUTTRELL-LACKY', 'WHISTLE', 'DEATON',
#        'VEAZIE', 'DEWEESE', 'ELVES', 'GILLESPIE', 'MERLE MUSSON', 'LIMES',
#        'LITHUANIAN FACTORY OF AVIATION', 'CRESCENZI', 'MARCELLUS',
#        'REVELL', 'EZEKIEL', 'AS+ LTD.', 'BOEING-BROWN', 'TILBERT',
#        'POWERS', 'DICKINSON', 'MERLIN', 'SKY STAR', 'DOTSON',
#        'GRAY MINIPLANE', 'STELLY', 'COREY', 'FREDENBURG', 'HEAD',
#        'CARRISON-SEIMAN', 'VAN HORN', 'LITTLE', 'OWENS/SMYTH', 'PRICE',
#        'AEROTECHNIK', 'MINI ACE', 'FARLAND', 'LOEHLE-AVIA',
#        'WSK PZL-KROSNO', 'PREVATT', 'ROMINGER', 'CHARLES RAYMOND', 'SISK',
#        'HEWITT', 'BOWLES/IRWIN', "O'DAY", 'GEORGE EVENSON', 'HANKS',
#        'TOCHOLKE', 'SAUDER', 'DEARINGER', 'HORTON', 'POPPENHAGEN',
#        'CONKEY/WAPELHORST', 'GRAHAM', 'BARTON', 'CHESTER',
#        'CORBEN BABY ACE', 'ELLIOT', 'YASECKO', 'KRAFT', 'STEWARD',
#        'QUALLINE', 'SLAYBAUGH', 'VANWINKLE', 'HOFFMAN, WOLF, FLUGZEUGBAU',
#        "ULTRAVIA AERO INT'L", 'SPORTSMAN', 'HERNANDEZ CHALLENGER',
#        'EMROTH-EMAIR', 'GEIDE', 'HAMPSON', 'CULBERTSON', 'STOUT',
#        'MROTEK', 'SCHULER', 'RAMESBOTHAM', 'ATKINSON', 'BELL/TSIRAH',
#        'WESTCOTT', 'FERNANDEZ', 'CRESAP', 'FLIGHTSTAR', 'KARR', 'JACKSON',
#        'GREEN CASTLE', 'GRAZIER', 'DICKMANN', 'KENOYER', 'MUDRY',
#        'THOCKER', 'TUBB', 'COURSEY', 'ROZENDAAL', 'RALPH TAYLOR', 'BINS',
#        'CROUCH', 'RICHARDS LANCAIR', 'DICKSON',
#        'AERO VODOCHODY AERO. WORKS', 'KEITH', 'ENSEY', 'DELLICKER',
#        'FLIGHT STAR', 'BURNS BURN', 'KARMY', 'LINDBERG', 'COLLIER',
#        'KEN SERIGHT', 'LEIBERT', 'AEROSTAR, S.A', 'VANATTA', 'TUPOLEV',
#        'FLEMING', 'MOODY', 'DUBIS', 'ZUKOWSKI', 'OPPERMAN',
#        'HOSTER/VOLMER', 'PEREYRA', 'WIEDEMANN', 'FARHAT', 'RICHARDSON',
#        'TRICKLE', 'SIROCCO FLYING CLUB', 'PACHECO', 'BARRIGER',
#        'JOHN T. GARRETT', 'HEFTY', 'MAHAN', 'CRESS', 'CRANE', 'RICHARDS',
#        'BERRY', 'HEMINGWAY', 'HOAC AUSTRIA', 'KEATING', 'HACKETT',
#        'BUESING', 'BILL PARSON', 'COLUMBIA', 'PASSADORI NORMAN',
#        'TESCHENDORF', 'ROCHETTE', 'CHARLES J. KEUTHAN', 'CATCHOT',
#        'THEIS', 'HUTTON RAND ROBINSON', 'ALLEN-WAYNE PITTS', 'KUNC',
#        'ROSEN', 'CUMBERLAND', 'BASINSKI', 'GORDON PRICE', 'DEVENDORF',
#        'DUFF', 'IVAN LANGSTON', 'SHOAF', 'JAQUISH', 'PORTER',
#        'EUGENE CLEMENTS', 'HENDRIX', 'THACKER', 'GOWAN', 'HAMMER',
#        'MARSH-TURNER', 'TRAVIS C. ELMORE', 'CAPSTAFF', 'CROSBY',
#        'DRESBACH', 'HENRY', 'NOE', 'STAUDAUCHER', 'GIERTZ', 'KOHLES',
#        'SIEFERT', 'MC ARDLE', 'BOCCHER', 'GOODWIN', 'WOOD', 'ROE-WAYNE',
#        'ROSS/STONECIPHER', 'WOLF', 'SHERMAN POWELL', 'SHAFER',
#        'RANS S-12 AIRAILE', 'DIETRICH', 'STIRITZ', 'DFL HOLDINGS INC.',
#        'REIFFER', 'MORAN', 'NIQUETTE', 'AEROSTAR-RAVEN',
#        'SLINGSBY AVIATION PLC', 'FRONSMAN', 'HILLAM', 'EICHMAN', 'GOODE',
#        'LARDAS', 'GARNER', 'GOBLE', 'KENNESON', 'SHAPLEY', 'KEARNS',
#        'STRATTON', 'MITTEER', 'BAUER', 'VELOCITY', 'IVERSLIE',
#        'POOR BOYS TOYS INC', 'PECK', 'VALLEY ADVENTURERS, INC.',
#        'RIEKKENEN', 'SIMPSON', 'ROTZ', 'HEFNER PITTS', 'HAINES', 'JURKA',
#        'KELLUMS', 'FAIRCHILD HELI-PORTER', 'FINGERHUT REVOLUTION',
#        'LORELLO', 'SOUTHWEST FLORIDA AVIATION', 'SOUTHERN AERO',
#        'COMEAUX', 'REYNOLDS', 'HIGGENS', 'NORTH AMERICAN-AERO CLASSICS',
#        'HALLAM', 'BURGESS', 'SHUTT', 'RODDIE', 'NEWBERG', 'KEAGGY-DAVID',
#        'REILLY', 'AS+ LTD', 'BRASHEARS', 'LOUTTIT', 'JOHN W. CULP',
#        'BARRIGAR', 'POHLMAN/POHLMAN', 'UNIVERSAL', 'RANS, INC.',
#        'MIKOWSKI', 'BLACKWELL', 'ZHUHAI HELICOPTER CO.', 'REED-MADSEN',
#        'FORD', 'CIERNIA', 'ADRIAN DAVIS', 'SEGO TOOL', 'BECKHAM',
#        'REVOLUTION', 'STRIPLIN AIRCRAFT CORPORATION', 'SALDAIRIAGA',
#        'RODGERS/GAUST', 'ROEBUCK', 'MARK EWART', 'BLUE DENNEY', 'SCHRAMM',
#        "SIGGI'S AIRPLANE WORKS", 'JOHN T. SIMPSON', 'BIHN', 'CADY',
#        'MAYERS', 'DANIEL', 'POLING', 'VIA INC', 'CHRISTOPHER COATS',
#        'NERSTROM-TAILWIND', 'PALERMO', 'TWIN COMMANDER ACFT. CORP.',
#        'SUTTON', 'RASER', 'SHERMAN', 'CHINESE A/F AERO IND DEV CTR',
#        'BROMLEY', 'GOINS', 'IRENEUSZ', 'CHARLES HOLMES', 'WILDE MICKEY',
#        'TANKERSLEY', 'STANEK', 'WASIELAK', 'ZWART', 'WALTER J COLLIE',
#        'FREIJE', 'BURCHINAL', 'SWEET-HOUSE', 'NICKELSON MARTIN',
#        "DUCI'S VANS", 'JOHN S. HICKEY', 'GOUGH-HERRMAN', 'ZITO',
#        'VICTOR MARSH', 'DUSKIN', 'RAMSEYER', 'BROCK', 'STARCK', 'KRIPS',
#        'WAXENFELTER', 'FROBERG', 'AMERICAN BLIMP CORP.', 'JAEGER',
#        'WILLIAM SARGENT', 'FOSTER/HILSMAN', 'PORAT', 'DENNIS L. LONG',
#        'STEWART 51 INC.', 'KAAS', 'STAR-LITE ENGINEERING LTD',
#        'ORLANDO HELI AIR INC.', 'MASAK', 'LERILLE', 'MCCLEAD', 'SCHRACK',
#        'QUAD CITY ULTRALIGHT AIRCRAFT', 'BOMBARDIER', 'DANGREMOND',
#        'DAVID MCELHANNON', 'M2', 'READ', 'DEBERRY', 'MORRISON',
#        'BUTLER TOOL', 'STEMME', 'KREATZ', 'JOHN H. KORB JR.', 'MADER',
#        'MOHR', 'MORELLI', 'WATERS', 'PAPA 51 LTD., CO.', 'RANS INC.',
#        'JACOB TUSSEL', 'CAWOOD', 'SHEETS', 'MEJIA', 'GIRGEN', 'WOLFE',
#        'ARNER', 'ROBERT E. BEAN', 'FONES', 'GISCLAIR', 'BLACKMORE',
#        'FIFE', 'HAWKER AIRCRAFT LTD.', 'OFFORD', 'TILLMAN',
#        'PROGRESSIVE AERODYNE INC.', 'HARTZLER', 'NARRIN-WHITTMAN',
#        'NOLLEY', 'STROUD', 'ECTOR AIRCRAFT COMPANY', 'HOFFMANN',
#        'MONTGOMERY', 'KOSTER', 'FRANDSEN', 'KERR', 'TRACY', 'FITHIAN',
#        'BRUNNEMER', 'LANE PROGRESSIVE AERODYNE, INC', 'ROSS',
#        'MASTOPIETRO', 'PERSON', 'OVERTON', 'VOLLMERS', 'MEEUWSEN',
#        'STUBBE-KITFOX', 'PEEBLES/LANCAIR 360', 'NAUER',
#        'AIR COMMAND INTERNATIONAL, INC', 'SHOEMAKER', 'MCCARTY', 'COOK',
#        'DE MALIGNON', 'BAGGARLEY', 'MIEHL', 'WILES', 'MARCHETTI',
#        'PROGRESSIVE AERODYNE', 'LUCKEY', 'PREECE', 'FENNELL',
#        'M. C. THOMAS', 'DEAN R. FELLOWS', 'SIX/HUBER', 'LESEMANN',
#        'RAYMOND C. VOEGELE', 'WHETZEL', 'WAKELY', 'KITE', 'MASSEY',
#        'DORNBOS', 'EKSTROM-FARRINGTON', 'BIBB', 'NEEDHAM', 'STUBLER',
#        'KOSKELLA', 'SIMONS', "JOBE'S", 'VERTICAL CONCEPTS INC.',
#        'CULVER-REVOLUTION', 'WEBER-MUSTANG II', 'ANKENBRUCK',
#        'HOPKINS BUCKEYE INDUSTRIES', 'HUGHES CASSUTT', 'CORA', 'BARKLAGE',
#        'FIESELER FLUGZEUGBAU', 'DUNCAN', 'BOGNUDA LIVIO', 'NICKS',
#        "O'NEIL", 'EVARTS AVIATION INC.', 'HUNDERE', 'GOODYEAR AEROSPACE',
#        'AUXIER HERSCHEL A JR.', 'FOREIT', 'BURSON', 'BAC-AEROSPATIALE',
#        'PAINTON', 'W.S. BOWERS, JR.', 'ZEIDLER', 'PETERS', 'REINHOLD',
#        'C.B. WITHUN', 'BECKER WAG AERO', 'PITCAIRN', 'TOMSCHIN',
#        'ILYUSHIN', 'HORNER-RYAN', 'THE OLD HEN CROW', 'STANTON',
#        'BLANTON', 'ARMBRUSTER', 'HOLIMAN', 'SID CHAMPION',
#        'MICHAEL L. THIBAULT', 'DENNIS POINTER', 'PARKMAN', 'DEAN',
#        'AEGERTER, SIMON', 'RICHARD YOUNG', 'PACIFIC AVIATION COMPOSITES',
#        'TROHOSKI', 'ABRAHAM J G II/ERICKSON K', 'COELHO',
#        'GETTIS H. HUDSON', 'STERN', 'MILLER/BELL', 'LEE S. HARVARD',
#        'MONOCOUPE', 'ZIVKO AERONAUTICS', 'COOPER', 'KEIL', 'CALKINS',
#        'SCOTT A. GEORGE JR.', 'MINER', 'GALLOB', 'MIL', 'DELONG',
#        'DELEEUW', 'PUSHKAR', 'DRYER', 'SLY', 'DAVID C. BOCK',
#        'STEVE HILL', 'FREDERICK SWEET', 'WITZEL', 'DAVIS/CLEAVER',
#        'REINDL', 'BEAN', 'ZEMP', 'HOSKINS CRAIG',
#        'RAYTHEON CORPORATE JETS', 'VENTURA', 'ELAM', 'DURRWACHTER',
#        'KAWASAKI', 'IVES', 'DAWE', 'OAKES', 'NARZINSKI', 'BARRETT BENSEN',
#        'BERRICK', 'STOCK', 'R.M. BISHOP', 'R.O. AND D.O HEWITT', 'WIDNER',
#        'WSK PZL WARZAWA-OKECIE', 'EUGENE HUGHES', 'MATTER', 'BOONE',
#        'MICHAEL W. CAMPBELL', 'BELL/MASON', 'ENGLEMAN', 'BOYD DAN',
#        'ABRAMS', 'HAMMOND', 'ROBERT W. FERRELL', 'MURRAY R. GARDNER',
#        'NATIONS', 'BEN TRAVIS', 'DEHAAN', 'TOMAN', 'POSKUS', 'CROZIER',
#        'HORNBECK', 'SALIBA', 'KUCKI', 'D. WAYNE SMITH', 'BLANCO',
#        'FLAHERTY', 'SOUTH MISSISSIPPI LIGHT AIRCRA',
#        'AB SPORTINE AVIACIJA', 'PRENDERGAST', 'DONALD WHITE', 'DEVOR',
#        'HEILIG-READING', 'KEEN', 'LIBERSAT', 'ROBERT R. CALLAHAN', 'ZLIN',
#        'MODROW', 'DUCI', 'JASPER', 'MAHLER', 'WHITHINGTON',
#        'LARSON SMITH MINIPLANE', 'LAKELAND ULTRALITES INC.',
#        'JOHN HUBBARD', 'PARKS', 'HARRY TOMLINSON',
#        'WILLIAMSON/WILLIAMSON', 'GADBURY', 'WALENTINE', 'BUSS',
#        'MCMILLAN', 'GUY', 'ALLEN-CHARLES', 'BLACKBURN JOHN D. JR.', 'NIX',
#        'RADER', 'QUICKSILVER AIRCRAFT', 'HODRE-BUULL-KOLB', 'EWERTZ',
#        'TROY', 'UNDERWOOD', 'WILDERODER', 'HAERING AVID FLYER',
#        'WILLIAM JAY KINNEY', 'WILLIAM JOHN SCHULZ', 'ARNET PEREYRA AERO',
#        'COLEMAN', 'KILPATRICK', 'JOHANNES-ROBERT', 'KLOTZ',
#        'ALSON G. SILER', 'MICHAEL L. LUCKEY', 'DINKEL-BROOK CORP',
#        'PINICK', 'WALKER', 'WIRTH', 'ROTORDYNE', 'WROBLEWSKI',
#        'SCHWARZLER', 'VAN GROUW', 'VALENZA', 'WILD GOOSE', 'REICHERT',
#        'DIEHL', 'GENTRY', 'GLOVER', 'SPAGNOLETTI', 'NYE',
#        'NO AMERICAN/ROGERS B L', 'BOSICK', 'PRATT', 'BANTING', 'ZDYBEL',
#        'ISMARI', 'GILES', 'LINDSTRAND', 'DRAPER',
#        'BOEING - CANADA (DE HAVILLAND)', 'KENDALL/MCKAUGHLIN', 'WATKINS',
#        'EDDIE A. SMITH', 'MINTZ', 'THOMSON', 'LUHNAU', 'HOWLETT',
#        'KENNETH MILLER', 'LORAL CORP.', 'GODBOUT', 'COUGHLIN',
#        'STREIFTHAU', 'KNOX', 'FREDERICK', 'STATZ', 'OEHLING',
#        'CORBIN/KING', 'CARTERCOPTERS', 'SWERTFEGER', 'RHEA', 'ZIELKE',
#        'QUEST II WALSH LTD.', "O'HARA BOB", 'PRUDHOMME',
#        'EAA CHAPTER 229', 'SLATER', 'DANA A. MOORE', 'MINCE', 'STIRLING',
#        'IZATT', 'LUTES', 'KITCHENS', 'KRETSINGER', 'COHEN',
#        'BURAK STANLEY A', 'AERO COMP INC', 'TRIKE',
# ...
#        'SCHWEIZER(HUGHES)', 'RITTER JOHN I', 'CHICCO MIGUEL E',
#        'CHARLES J NORRIS', 'GERALD DONOVAN', 'CLARK JAMES T', 'JANSEN',
#        'SIMMONS GARY F', 'ENDLER GLASAIR/GLASAIR 1-TD', 'SPANI WAYNE M',
#        'PERNER/PITTS', 'EVOLUTION 19', 'SALERNO KENNETH G JR',
#        'D & K AVIATION', 'MICHAEL DEAN GRISSOM', 'CANION MICHAEL W',
#        'APPLEGATE', 'KUBASSEK DAVID', 'RADFORD DARREL F',
#        'GILBERT THOMAS JEFFREY', 'MITCHELL DERRYLE V',
#        'BRITISH AIRCRAFT CORP.', 'HILLARD CHARLIE R', 'MCINTOSH DONALD W',
#        'MARK GOLDBERG', 'THOMAS J HANKAMP', 'RANDALL MARVIN L',
#        'JAMES D RIGGS', 'MENZIMER GARY RAY', 'CHAPMAN', 'JAMES F HAKE',
#        'MICHAELIAN', 'RALPH', 'ROGER M ALLEN', 'KING JOHN E JR',
#        'ROSE HERBERT D', 'CHARLES D WALKER', 'BRADLEY RODERICK W',
#        'BOYD BRUCE', 'MIKE REED', 'GREENE R/GREENE S',
#        'HOSTEIN K/HOSTEIN S', 'JAMES M RAULERSON', 'PAUL GAYWOOD E',
#        'TUKAN', 'PACIFIC AEROSPACE LTD', 'HUNTER GEORGE', 'KERR GERALD',
#        'WALKER EDGAR E', 'DEDEAUX GARY G', 'CROFT ROBERT C', 'LEONARDO',
#        'JEFF JARDINE', 'COBALT AIRCRAFT INDUSTRIES INC',
#        'RUDDER DWIGHT K', 'CHANCEY GERRY M', 'RANS INC',
#        'MOONEY AIRCRAFT CORPORATION', 'MILLER STEVEN M',
#        'PARKS RICHARD A', 'AIRMAX CONSTRUCOES AERONAUTICA',
#        'RUDBERG TODD W', 'TRUDEL', 'DJI', 'THOMAS J MURRAY',
#        'GODWIN JEFF E', 'HENCKEN WILLIAM', 'SC AEROSTAR SA',
#        'MCMILLAN JOEL L', 'BUSCHMANN/VANZEE', 'EMERSON', 'BRAD J BATES',
#        'ERIS E. ERVIN', 'BELLET JAMES J', 'HICKOX ANDY',
#        'CHARLES A BRAZIL', 'FREEMAN HERITAGE COLLECTION', 'SCHAFFER',
#        'THOMAS STEPHEN', 'BRYANT C CROSBY', 'BOROM MARCUS P',
#        'FLEETWOOD JACK', 'RUSSELL E OBERG',
#        'WESTERN INTERNATIONAL AVIA INC', 'HIMSL VINCENT S',
#        'BARBER WARREN D', 'THOMAS G PARKHURST', 'PETERSON LANCAIR',
#        'STAUDACHER JON', 'FLUGZEUGPRODUKTIONS-UND VERTRI',
#        'SIX CHUTER WEST LLC', 'JOHN A BREWER', 'STILL MICHAEL J',
#        'METCALFE ROBERT B', 'MAURER ELMO A', 'RIGGS KENNETH W',
#        'CLOUD JEFFREY FERRELL', 'VANDERARK', 'HOMER', 'JOHN ROSCOE',
#        'RUTTEN PHIL J', 'BUEHLMANN PETER', 'KARPAYEV VLADYSLAV V',
#        'DOSHIER WILBERT A', 'PIPER / LAUDEMAN', 'MOTLEY GARY W',
#        'DRIGGERS QUILLAN E', 'TODD FOLEY', 'KEVIN LEUE', 'WEAVER DAVID A',
#        'BROCK STEINER', 'JONES KENT C', 'MICHAEL ADAMCZYK',
#        'CZECH SPORT AIRCRAFT A.S.', 'CORBEIL SHAWN', 'HALLEY KFT',
#        'BROWNING GREGORY S', 'KELLEY DERRICK/LEZA', 'X-AIR LLC',
#        'CONSTRUCCIONES AERONAUTICAS', 'BARNES STEVEN D',
#        'GULFSTREAM AEROSPACE LP', 'JUST', 'DAYTON A DABBS',
#        'HARROP BLAKE', 'GELDERMANN BERT E', 'BRYK STEVEN L',
#        'TOMLINSON TRACY L', 'ZODIAC', 'MATHENY LARRY E',
#        'SKWIRA MATTHEW J', 'QUARTZ MOUNTAIN AEROSPACE', 'FOXFLY INC',
#        'VERTICAL AVIATION TECHNOLOGIES', 'WAYNE MILLER', 'GREGORY NEWMAN',
#        'SOMERTON DAVID J', 'BAKER VICTOR R', 'SKYRUNNER',
#        'SHANKS V ROGER', 'OLIVER LAWRENCE R', 'HASTINGS THOMAS G',
#        'BEECH AIRCRAFT CO.', 'SCHEINEMAN-VAN BUREN', 'SOKO',
#        'ROBERT SNYDER', 'MACDONALD CRAIG', 'REILLY CHARLES W', 'BEREZNAK',
#        'JOHNSON GERALD', 'LYONS ROBERT', 'BESARICK', 'PFLUGRADT',
#        'MILLS MICHAEL', 'FLIGHTWORKS CORP', 'FAIRCHILD FUNK',
#        'LYNN PERRY', 'ANDERSON DARRELL L', 'TERRY G. OLSON',
#        'AMES ANGIER M', 'RAGLE', 'SASSER ALLEN L', 'CARR B L',
#        'HAWLEY RICHARD', 'PAGE RUSSELL L', 'S.Z.D.', 'SMITH DENNIS P',
#        'BORDIUK', 'STONE JAMES R', 'STANLEY ERNIE SIGURD', 'KEN OLSON',
#        'IRVIN STEPHEN D', 'BROWN JOSEPH', 'HEARD ALAN E', 'WELLS ELGIN M',
#        'L-BIRD LLC', 'SENO LOUIS C SR', 'AMERICAN AIR RACING LTD',
#        'MICHAEL R ALEXANDER', 'HARTLINE J BON', 'LAMINAR',
#        'BERGER BERNARD M', 'CHRISTOPHER LORD', 'BELAIR', 'CREECH JERRY',
#        'BARRY MAGGIO', 'DIVEN ROBERT', "JETSON'S AVIATION LLC",
#        'WITTMAN D R/WITTMAN D M', 'AEROPRO CZ S R O', 'PEET CHARLES',
#        'ROGER G WHITE', 'I.C.A.-BRASOV (ROMANIA)', 'DAVIDSON, RONALD A.',
#        'RHOADS', 'JAMES DONALD BAKER', 'GARCIA BENIGNO', 'JAMES WIEBE',
#        'DEVRIES WM H', 'MORRISON MARVIN E JR', 'COSENTINO GAREY A',
#        'ZS DELTA-BIELSKO WROCLAW', 'ELDRIDGE GEORGE', 'LITE FLIGHT',
#        'JIM GREEN', 'IRLBECK THOMAS H', 'SORENSEN DANNY S', 'MASON HAL J',
#        'GIPPSAERO PTY LTD', 'DOBBS GEORGE', 'BRYAN C L/LABRASH R D',
#        'ASTON KINSEY', 'DAN JELINEK', 'RGJ AVIATION LLC', 'CRAIG A REED',
#        'SCHEMPP HIRTH FLUGZEUGBAU GMBH', 'SAFARI', 'ROBERT MILES',
#        'BEST OFF', 'HONDA AIRCRAFT CO LLC',
#        'SCHEMPP-HIRTH FLUGZEUGBAU GMBH', 'AERO ELI SERVIZI', 'TOOMEY',
#        'MICROLITES PTYLTD', 'WAYNE D. TEEL', 'LAVIA ARGENTINA S.A.',
#        'ALLEN W INKS', 'HERZOG AVIATION', 'GERALD DAN COPPOCK', 'ICP',
#        'WALTER C SMYTHE', 'DELL LAWRENCE', 'AIRGYRO AVIATION LLC', 'QAC',
#        'KAWASAKI HEAVY INDUSTRIES LTD.', 'BLUE OAK LLC.',
#        'JAMES E CAUSEY', 'HARBIN', 'STODDARD HAMILTON', 'AIRTIME',
#        'AERO DESIGNS', 'LANCE M HOOLEY', 'EGGLESTON DANIEL', 'GUIMBAL',
#        'BOSKO WR/BOSKO CE', 'HALLADAY ROY', 'HIMMEROEDER HANSGEORG',
#        'EDWARD R. SUGG', 'ROBERT L COONS', 'GRUBER', 'SCHWEIZER 300CBI',
#        'HONDA AIRCRAFT', 'RAYMON A. KING', 'BEARDEN BIPLANE', 'KRELING',
#        'RICHARD SILVA', 'SA300', 'HARGROVE', 'CAPITAL HOLDINGS 226 LLC',
#        'LEROUX JOHN F', 'AIRPLANE FACTORY', 'AUDENRIED', 'POBEREZNY',
#        'EUGENE WELLS', 'ULTRALITE SRO', 'BKF', 'SILVEIRA JONATHAN A',
#        'SCOTT TAYLOR', 'DARREN M. VINELLI', 'CLIFFORD E MASSEY',
#        'SABERWING', 'CZECH SPORT', 'ROBERT R. REILAND', 'HILL GROUP LLC',
#        'EMMET SMITH', 'AIRBORNE WINDSPORTS', "VAN'S AIRCRAFT",
#        'STOL AIRCRAFT CORP', 'WARNER AEROCRAFT', 'REMPE',
#        'OSTERTAG WALTER G', 'JAMES A GRAY', 'PEREIRA', 'HOGAN',
#        'DENNIS L ZUMBALT', 'MARLOW', 'EPIG', 'BERKEY', 'GASKINS',
#        'MORRISON ROCKY V', 'EUROPA', 'KAMINSKAS', 'BARROWS', 'ACRO',
#        'PAVEL VAGNER', 'STORCH', 'OTTERBACK', 'ALLIANT AVIATION',
#        'ELMWOOD', 'JORDAN VALLEY LLC', 'JM KEMP', 'VOUGHT',
#        'RYAN JOHN STEFFEY', 'CHISTOV', 'RATHEON AIRCRAFT COMPANY',
#        'BRADSHAW / MCCAULEY', 'S.A.N.', 'DARYL BAKER', 'DAVID S MEEK',
#        'DALE BERKBIGLER', 'AURORA', 'ALISPORT', 'DAVID SHOTWELL',
#        'S M & T AIRCRAFT', 'GRIFF', 'JAMES', 'KARNS', 'TRELLA',
#        'QUICKSILVER AIRCRAFT NORTHEAST', 'KIRK ELLIS WENDELL',
#        'HOWARD STEVEN C', 'ROLLADEN SCHNEIDER', 'SKYBOLT',
#        'TEXTRON AVIATION', 'MERIT AVIATION LLC', 'DONALD BERNARD HIGGS',
#        'GIBB', 'ICON', 'AIRVAN', 'BIURO PROJEKTOWE B BOGUMIL BER',
#        'THOMAS WILD', 'WILLIE BENNETT', 'CASHEN', 'BRUMBAUGH DAVID R',
#        'JUDD', 'VALLDEJULI JOHN A', 'RICHARDS HEAVYLIFT',
#        'STODDARD-HAMILTON', 'JONKER SAILPLANES', 'REIMS AVIATION CESSNA',
#        'CAPES', 'GIGER FRANK R', 'SHIRLEY CARL', 'MORIARTY MARVIN',
#        'CAPELLA', 'DG FLUGZEUGBAU', 'SCODA AERONAUTICAL',
#        'INFINITY POWER PARACHUTES', 'COZY', 'THOMAS LEE',
#        'GEORGE W. FELIX', 'SILVERLIGHT AVIATION LLC', 'REED MIKE',
#        'FOXWORTHY RICK A', 'WINGTIP TO WINGTIP LLC',
#        'LLEWELLYN, WARWINC W', 'KITTY HAWK', 'RICHARD B CARPENTER',
#        'CZECH SPORT AIRCRAFT', 'HIGGINS JOHN H/WILLIAMS JOHN D', 'PAVEL',
#        'NEW GLASAIR', 'SYMPHONY AIRCRAFT IND INC', 'JAVRON', 'ROTARY',
#        'OAS', 'ANGEL AIRCRAFT CORPORATION', 'JOHN SAMPLE',
#        'TEAM ROCKET F-1', 'THUNDER MUSTANG', 'MICHAEL A. WATSON', 'MAGNI',
#        'AIRBORNE AMERICA', 'MERWIN', 'AVIASTROITEL', 'LAVIA ARGENTINA',
#        'ORLICAN', 'INNOVATOR', 'LIGHTNING AVION EAB LLC', 'RAF',
#        'AMERICAN LEGAND AIRCRAFT', 'AUGUSTAWESTLAND', 'BOWER',
#        'ROTORCRAFT DEVELOPMENT CORPORA', 'RANS S-12',
#        'PIPISTREL ITALIA SRL', 'BUCKMAN', 'HOLMGREN',
#        'KEUTHAN AIRCRAFT CORP', 'DAYTON-WRIGHT', 'N126C LLC', 'DAHER',
#        'OSPREY 2', 'RHOADS, LARRY E', 'TEAM', 'COYOTE', 'CHAD LEWIS',
#        'THATCHER', 'KOSTRAZEWA ANDRE', 'VOLMER', 'LANKENAU',
#        'AIR CREATION/SIDES RICK A', 'NEW KOLB AIRCRAFT CO LLC', 'FURLONG',
#        'KADE', 'SEELE', 'PARACHUTE ICARUS', 'ROBERT D CARR JR',
#        'GREG MILLER', 'WAG AERO', 'DAKOTA', 'ROTORSPORT UK LTD',
#        'PERFORMER', 'SIEBEL', 'USKOSKI', 'MCSWAIN', 'TEAM ROCKET',
#        'ARROW-FALCON EXPORTERS, INC.', 'AVIAMILANO', 'JEWETT',
#        'PILATUS AIRCRAFT', 'DEROUSSE', 'RAVEN AIRCRAFT CORPPRATION',
#        'ANG', 'STEPHENS WILLIAM E', 'CZECH', 'KJOSTAD JORGEN A',
#        'SPARROWHAWK', 'RALPH C KIMBALL', 'AERO BRISTELL',
#        'CCX-2000-0081 LLC', 'CARBON', 'ROTORSPORT UK', 'ZLIN AVIATION',
#        'CO Z', 'BLEVINS KAMRON', 'HUTSON', 'FORD STEPHEN L',
#        'ANTHONY MATTIOLI', 'AFICIONADO', 'ECLIPSE', 'EXPRESS',
#        'WALTON DANIEL J', 'EMBRAER SA', 'MOONEY INTERNATIONAL CORP',
#        'CREEK MICHEL W', 'PLANTE', 'RANDY WAYNE MALONEY', 'HECKEL',
#        'ZENAIR ZODIAC', 'RIVERS LINDSEY LEE', 'ABBETT GERRY',
#        'AGUSTAWESTLAND PHILADELPHIA CO', 'GATES LEARJET CORP',
#        'BABENCO HENRY D.', 'TURCOTTE JR ROBERT L', 'STEINMAN MARK E',
#        'M7 AEROSPACE', 'GEORGE MATTHEW WAGONER', 'WAG-A-BOND TRAVELLER',
#        'VASHON AIRCRAFT', 'POST', 'PHILLIP B ROLLS', 'HONDA',
#        'SCHEMPP-HIRTH K G', 'BURG FREDERICK S', 'DAVIS DAN B', '777',
#        'JABIRU USA SPORT AIRCRAFT', 'ROTORWAY EXECUTIVE',
#        'MAGNUS AIRCRAFT LLC', 'DESTINY POWERED PARACHUTES',
#        'FORISCH EDWARD', 'ROWE DENNIS A', 'HINE T L/JOHNSON R',
#        'THRUSH AIRCRAFT LLC', 'BRYAN S HAPPELL', 'DAVIS DONALD M',
#        'FIREFLY BALLOONS 2010 INC', 'MICHAEL J ROBBINS', 'SPITFIRE',
#        'MOBI-LIGHT', 'MEYERES F L/MEYERES M M',
#        'PRECISION HELICOPTERS LLC', 'ULTRAMAGIC S A',
#        'JABIRU AIRCRAFT PTY LTD', 'ISRAEL AEROSPACE INDUSTRIESLTD',
#        'MARQUART', 'STORM FURY', 'LEGACY', 'RICHARDS HEAVYLIFT HELO INC',
#        'DOUGLAS K THOMPSON', 'VARNER DAVID L', 'PAGE JOSEPH E',
#        'HARRY CROSBY (VANS)', 'GOODSELL LYNN A', 'ROBERT TREMBLY',
#        'MCCLURE B J', 'JOHN M CORNEAL', 'MUNSON ROGER J',
#        'BHI H60 HELICOPTERS LLC', 'MARK COBY', 'PHILLIPS RALPH W',
#        'PZL WARSZAWA-OKECIE', 'MAXSON PHIL', 'WESTON JAMES',
#        'KEVIN LIPPERT', 'GARRISON RONALD L', 'COVEY', 'ANTENOR VELAZCO',
#        'TONY DUBEANSKY', 'SCOTT VALDEZ', 'WARE JERRY L',
#        'BOLSTRIDGE WALLACE R', 'VINING JOHN K', 'AIRBORNE AUSTRALIA',
#        'DEWSNUP DAVE', 'CABRI', 'FERACA EDWARD M', 'CURNUTT ELTON E',
#        'SILVERLIGHT AVIATION', 'WHEELER C / WHEELER K',
#        'EARTHSTAR AIRCRAFT', 'SWANN LYNN J', 'MYRON OLESON',
#        'ESLINGER C W/ESLINGER S M', 'SCOTT MILLS', 'PAYNE STEVEN R',
#        'BAILEY N MOYES', 'JOPLIN', 'DEHAVILLAND CANADA',
#        'GARY JAMES LAIL', 'TURBINE CUBS OF WYOMING LLC', 'MADERA',
#        'RICHARD S CARPENTER', 'DRIVER', 'KEVIN P STOLHAMMER',
#        'MILLSAP DENNIS', 'BOROM', 'STEPHEN L KRUER', 'TUCKER TIMOTHY E',
#        'KUYKENDALL CHARLES', 'ALEXANDER VAGNER', 'WEISS DENIS',
#        'HPH, SPOL. S.R.O.', 'LITEFLITE PTY LTD', 'LARRY H SLIGAR',
#        'ALASKAN AIR ADVENTURES LLC', 'COMCO IKARUS', 'MARLOWE THOOFT',
#        'LORAH ELDEN A', 'SUPERMARINE', 'COLLINS ROBERT S', 'HALEY',
#        'FLYING K ENTERPRISES', 'STOUT GARRY V', 'HUMMER', 'SCHMITT',
#        'MANTOOTH', 'SEGARRA LUCAS JR', 'KLAPP PETER A', 'AVE STEPHEN',
#        'JOEL A BOWKER', 'BULFER JAMES G', 'HERRICK DAVID A',
#        'QUAD CITY ULTRALIGHT', 'SPROUL KEITH A', 'GORDON SCOT A', 'BELY',
#        'COLE PAUL B', 'FONVILLE', 'MICHAEL W MORGAN', 'GEORGE A. THIEL',
#        'WYDER ROBERT G', 'BACH JOSEPH E', 'SHARP RALPH R',
#        'DOAN VERNON D', 'HÉLICOPTÈRES GUIMBAL', 'CULP JOHN S', 'TANDEM',
#        'SONERAL', 'RICHARDSON ANDREW P', 'SEA & SKY INC',
#        'ZUBER THOMAS P', 'ROTOWAY INTERNATIONAL', 'BEVILACQUA JEFFREY L',
#        'CAVALIER', 'RANDAL C REIMER', 'Z-HI-MAX', 'GREGG ORIGER',
#        'HALL TERRENCE / HALL CATHIE', 'JACK A FROHBIETER',
#        'SANTA FE AIRCRAFT LLC', 'GERALD JONES', 'ISSITT', 'ERIC A MUNZER',
#        'PHOENIX AIR SRO', 'K COPTERS', 'JAHNKE LIONEL G',
#        'ELVIN JACK R JR', 'LEONARDO SPA', 'RAY EARL D',
#        'SYRACUSE V F/SYRACUSE C D', 'MONTE CLARK', 'MICHAEL V CRANFORD',
#        'CHR INTERNATIONAL', 'AMERICAN LEGEND AIRCRAFT COMPA', 'MINI-MAX',
#        'CAMERON BALLOONS U S', 'CRUISER', 'CHARLES C MENGER JR',
#        '2021FX3 LLC', 'WALTER TACHIKI', 'LEACH MICHAEL', 'MILLER ROGER',
#        'WIGHT ALBERT A', 'BLAKE D BARRYMORE', 'CHRISTAVIA',
#        'JOBY AERO INC', 'EMBRAER EXECUTIVE AIRCRAFT INC',
#        'CHRISTOPHER P GAGE', 'MOYNIHAN RICHARD D', 'SHELTON JOSEPH G',
#        'MCKENZIE JOHN P', 'DARRELL D. DUGGER', 'SPANGENBERG',
#        'ROSS JONATHAN', 'DISTAR CZ AS', 'GREGORY S MILLER',
#        'AXELL CHARLES L', 'HONDA JET', 'RAVIRAJ MOHIL', 'TUTTLE BRUCE C',
#        'S D MARTIN', 'SIKORSKY AIRCRAFT CORP', 'DWYER MICHAEL D',
#        'HARTZ PAUL', 'NORDQUIST RICHARD A', 'PARADISE AIRCRAFT USA LLC',
#        'SPARROW HAWK', 'ADAMS DENNIS ALLEN', 'SACHSE STEPHAN', 'FPNA',
#        'FERNANDES DALE R', 'BARBER ROBERT L', 'HENDERSON CLIFFORD S',
#        'PF CUB FLYERS LLC', 'HENRY L BERRIER JR', 'DIETRICH RYAN',
#        'ADAMS BALLOONS LLC', 'SAWBY SCOTT', 'PIPER-HARRIS', 'KODIAK',
#        'SUPERIOR', 'BEARHAWK', 'KYLE M SWARD / LARRY W SWARD',
#        'CHARLES R KYLE', 'BLUE SIDE UP INC', 'JUSTICE FRANK K',
#        'WINGREN NORMAN', 'QUICKSILVER AIRCRAFT CO', 'SPARKS RALPH A',
#        'PYKA INC', 'TWENTY SECOND STREET LLC', 'EASTABROOKS JOHN T',
#        'BRUCE R PROUSE', 'FRAZIER ROBERT L', 'CO-Z DEVELOPMENT CORP',
#        'GRUMMAN AMERICAN AVN. CORP', 'VAN LEHN RICHARD GLENN',
#        'FOSTER WILLIAM D', 'CESSNA AIRCRAFT CO.', 'MEYER FRED J',
#        'FAHEY WILLIAM J', 'MCDANIEL JAMES D', 'BOYLE JOSEPH E',
#        'HPH SPOL SRO', 'AMD', 'WALTER S JOHNSON III', 'BURRILL STEVEN E',
#        'PEPPERD GREG J', 'WHITTRIDGE RICHARD D', 'CRAWFORD JAMES R',
#        'BAKER EUGENE L', 'ROBERT FITTS', 'BUCKER', '737',
#        'JAMES C GEYMAN', 'GMK VENTURES LLC', 'BLACKSHAPE', 'BELIEVER',
#        'KAKELDEY RONALD O', 'CASSULT RACER', 'ARNOLD J/JONES D L',
#        'SPAUR CHARLES', 'GEIST DONALD R', 'DUFFY RUSSELL A',
#        'STUCKY STEVEN D', 'ALLAN G PIXLEY', 'VICKERS-SLINGSBY',
#        'MXR TECHNOLOGIES INC', 'EASTER WILLIAM C', 'UNITED CONSULTANTS',
#        'COLUMBIA HELICOPTERS', 'VULCANAIR', 'WHITTEN ROBINSON',
#        'MILLER-THORP', 'HOLLAND MIKE', '5 RIVERS LLC', 'HOLLIER B C',
#        'MESCHLER GARY R', 'C A S A', 'SONEX AIRCRAFT', 'ICP SRL',
#        'HARVEY J BROCK', 'DRONE', 'C M STUHRENBERG/P C POLETE',
#        'HOFFMAN DAVID J', 'GODDARD DICK SIM', 'THOMAS WAYNE L',
#        'STUCKER GARY', 'UVIFY', 'FALL MARTIN', 'JACKSON DENNIS',
#        'BOEING (STEARMAN)', 'FLIGHT DESIGN GENERAL AVN GMBH',
#        'RAY E ROBERTS', 'JAVRON EXPERIMENTAL', 'LEON E EVERETT',
#        'BELL TEXTRON CANADA LTD', 'STORY CHARLES BRAD', 'SUTPHIN JOHN E',
#        'HISSERICH NICHOLAS S', 'BUXBAUM MARK EDWARD', 'CONWAY PHILIP J',
#        'OWEN KINGSLEY B', 'KNOTT VERNON W', 'GATES LEAR JET CORP.',
#        'AUTOGYRO USA LLC', 'PIPISTREL ITALIA S R L', 'MCKENNA GLEN R',
#        'WILLIAM L BELL', 'SKILES KENNETH C', 'KUMHYR DAVID B',
#        'JACQUNEAUX GLEN R', 'WREN RONNIE D', 'ANGUS WATT',
#        'MOSSMAN MICHAEL D', 'MERIWETHER JON', 'WAGAERO',
#        'HIBBARD NORMAN E', 'HARTUNIAN ROBERT', 'AIRGYRO', 'ARTER WARREN',
#        'SHIREY DAVID A', 'MARY ALEXANDER', 'SEABOURN SCOTT R',
#        'SCODA AERONAUTICA LTDA', 'CORNFORD CRAIG H', 'AAA AIRCRAFT LLC',
#        'SEAMAX AIRCRAFT', 'SWENSEN', 'WASZAK ARTHUR B',
#        'GREEN L/GILNER D', 'KINGERY MICHAEL C', 'YATES MIKE E',
#        'ST CLAIR DAVID L', 'EVANS JAMES JAY', 'MCGLAUGHLIN RICHARD',
#        'AEROPRAKT MANUFACTURING SP ZOO', 'BALCOMB KENNETH C III',
#        'PERYERA ARNET', 'SCOTT TERRY G', 'RHINEHART', 'STEPHEN J HOFFMAN',
#        'SCHMIDT RANDALL M', 'ECLIPSE AEROSPACE INC', 'PIPISTREL D O O',
#        'MULHOLLAND ROBERT A', 'DETRICK DONALD G', 'SEACE DAVID A',
#        'DANIEL ANTHONY PROCTOR', 'CHILDS MICHAEL  A', 'PHANTOM',
#        'GREG HOBBS', 'JAMES R DERNOVSEK', 'ORLICAN S R O',
#        'ROYSE RALPH L'], dtype=object)

# %%
aviation_data_clean['Make'].unique().sort()
print(aviation_data_clean['Make'].unique())
# Out:
# ['Stinson' 'Piper' 'Cessna' 'Rockwell' 'Mcdonnell Douglas'
#  'North American' 'Beech' 'Bellanca' 'Navion' 'Enstrom' 'Smith' 'Bell'
#  'Grumman' 'Beechcraft' 'Maule' 'Air Tractor' 'Aerospatiale' 'Mooney'
#  'Boeing' 'Curtis' 'Schleicher' 'Quickie' 'Lockheed' 'Embraer' 'Hughes'
#  'Swearingen' 'De Havilland' 'Bell Helicopter' 'Bede Aircraft' 'Convair'
#  'Beachner' 'Canadair' 'Douglas' 'Sons Mustang' 'Dassault/sud' 'Sikorsky'
#  'Bell/textron' 'Robertson' 'Aeronca' 'Smith Miniplane' 'Mitsubishi'
#  'Mcdonnell-douglas' 'Taylorcraft' 'Ted Smith' 'Robinson' 'Raven'
#  'Ercoupe' 'Rockwell Comdr' 'Howard Aircraft Corp.' 'Porterfield' 'Nihon'
#  'Great Lakes' 'Balloon Works' 'Pitts' 'Fairchild Hiller' 'Kaman'
#  'Weatherly' 'Eagle' 'Barnes' 'Schweizer' 'Starduster Ii' 'Homebuilt'
#  'Smith Mini' 'Smith Aerostar' 'Rockwell Intl' 'Hiller' 'Schreder' 'Varga'
#  'Hatz' 'Nord Aviation' 'Crook' 'American Yankee' 'Helio' 'Colonial'
#  'Gulfstream American' 'Benson' 'Luscombe' 'Mckinley Eaa' 'Airmate'
#  'B??lkow' 'Snow' 'Rockwell Commander' 'Rotorway' 'Gulfstream' 'Champion'
#  'Fournier Aviation' 'Curtiss-wright' 'Aero Commander' 'Mbb-bolkow'
#  'Piper-aerostar' 'Rockwell Intl.' 'Ryan' 'Jurca' 'Martin-pitts'
#  'S.n.i.a.s.' 'Goodyear' 'Rand' 'Rutan' 'Burkhart Grob Flugzeugbah'
#  'Sud Aviation' 'Avres Corp.' 'Grum Amer' 'Evans Aircraft' 'Schweizer Sgs'
#  'Ayres' 'Stampe Renard' 'Fairchild' 'Pitts Special' 'Tailwind'
#  'Hiller-soloy' 'Aerotek-pitts' 'Avian Balloon' 'Hartman' 'Spezio'
#  'Dauntless' 'Mbb' 'Bell/soloy' 'Raz-mut' 'Christian' 'Funk Aircraft Co.'
#  'Mong Sport' 'Rayan' 'Starfire' 'Osprey' 'Hudson' 'Continental'
#  'Gates Learjet' 'Scorpion' 'Thunder Balloons, Ltd.' 'Moore Bell' 'Blanik'
#  'Taylor' 'Lake' 'Brantley' 'Bryan' 'Bell 47g-3b' 'Volmer Aircraft'
#  'Citabria' 'Martin' 'Nash Cassutt Racer' 'Playmate' 'Oldfield' 'Bac'
#  'Broyill-cowan-murray' 'Erco' 'Brantly' 'Callair'
#  'Consolidated Aeronautics Inc.' 'Continental Mk5a' 'Arctic' 'Thurston'
#  'Swanson' 'Adams' 'Mignet' 'Starduster' 'Hardie' 'Savage' 'Starke'
#  'Mccall' 'Fokker' 'Scheicher' 'Bensen' 'Wing' 'Gregg' 'Learjet' 'Mcclary'
#  'Midget' 'Na' 'I.c.a. Brasov - Romania' 'Southern Airmotive Corp Sac'
#  'Barrett' 'Varieze' 'Cameron Ballon' 'I.c.a. Brasov' 'Peter Clark'
#  'Davis' 'Bellance' 'Rockwell International' 'Downer Aircraft Industries'
#  'Pterodactyl' 'Ryan Aeronautics' 'Grumman American' 'nan' 'Clancy'
#  'Bell-cont 42g' 'Britten-norman' 'Waco' 'Goans' 'Glassflugel' 'Pietenpol'
#  'Miller' 'Aeronca Champion' 'Coot' 'Breezy' 'Junior Ace' 'Globe'
#  'Lark (i.c.a.)' 'Republic' "Rockwell Int't" 'Mong' 'American' 'Firefly'
#  'Texas Helicopter Corp.' 'Thorp' 'Rotorway Aircraft, Inc.' 'Omac'
#  'Bucker Jungmann' 'Steen' 'Alon' 'Austin' 'Morrisey'
#  'Eipper Mx Ii Quicksilver' 'Hallquist' 'Aeronca Champ' 'Q-berry' 'Oar'
#  'Siai Marchetti' 'Corben' 'Sonerai' 'Bell Helicopter Textron'
#  'Boeing Stearman' 'Eiriavion Oy' 'Condor' 'Eaa' 'Von Berg' 'Menees'
#  'Engineering & Research' 'Dragon Fly' 'Auster' 'Air & Space'
#  'Quicksilver' 'Cassutt' 'Mustang' 'Lawson Special' 'Cameron' 'Bently'
#  'Wayne Ison' 'Lindgren Evans' 'American Aviation' 'Falkenthal'
#  "Villine's" 'Consolidated Aero' 'Davenport' 'Schempp-hirth' 'Bennet'
#  'Vari-eze' 'Long-ez' 'Fairchild/swearingen' 'Flitecraft' 'Foster'
#  'Scorpion Too' 'Navy' 'Glasflugel' 'Tanke' 'Wainscott' 'Ken Brock'
#  'Saville Hummer' 'Cougar' 'General Balloon' 'Raven Industries'
#  'Boeing Vertol' 'Tomcat' 'Bowers Flybaby' 'Volksplane' 'E.l. Craig'
#  'Eipper-formance' 'C. Eff' 'J.a.mullan' 'Flagg' 'Arctic Aircraft'
#  'Vanhoose/scorpio' 'Johnson, Douglas L.' 'Short Bros.'
#  'Rolladen-schneider' 'Froehlich' 'Temco' 'Amateur Built'
#  'Mcdonald Douglas' 'Tifft-v' 'Beagle Aircraft' 'Aerosport' 'Cgs Aviation'
#  'Gates Lear Jet' 'Frank Turben' 'Hollman' 'Burke-parker' 'Norman Negus'
#  'Piccard' 'Javelin Aircraft' 'Teal' 'Willbird'
#  'Israel Aircraft Industries' 'Cromwell/pitts' 'Smith, Ted Aerostar'
#  'Obryon' 'Pace' 'Pratt-read' 'John Tylenda' 'Monnett'
#  'Scheibe Flugzeugbau' 'Eagle (ultralight)' 'Harrison Volmer' 'Dodd'
#  'Beckner' 'Glasair' 'Rand Kr1' 'Rotec' 'Vans Aircraft' 'Burkhart Grob'
#  'Eaa Biplane' 'Gray' 'Brown' 'Weedhopper' "Gemini Int'l." 'Molino Oy'
#  'Manta' 'Waspair' 'Consolidated-vultee' 'Murrayair'
#  'Kit Built (rotorway)' 'Ware Teenie' 'Eagle Aircraft Co.'
#  'Anderson, Greenwood' 'Continental Copters' 'Partenavia' 'Cgs' 'Let'
#  'Ercoupe (eng & Research Corp.)' 'Mitchell' 'Wizard' 'Walston'
#  'Pteradactyl' 'Spencer' 'Brantly Helicopter' 'Logan' 'Tuk Gregory'
#  'Airmass' 'Swift' 'Ultralight Flight' 'Carter' 'Rietman' 'Boland'
#  'North American Rockwell Corp.' 'Holmes' 'Fairchild Swearingen'
#  'Eippen Aircraft' 'Goldwing' 'Skypower' 'Vector' 'Rogers'
#  'Cummings Quickie' 'Forney' 'Eipper' 'Schaffer-provencher'
#  'Intl Ultralight' 'Parson' 'Aircoupe' 'Herpst' 'Grumman-schweizer'
#  'Siai-marchetti' 'Ryan-navion' 'Ultralight Engineering'
#  'Artic Aircraft Corp.' 'Mcdonald' 'Yarnell' 'Barnstormer'
#  'Link-johnson-chessman' 'Rotec Engineering, Inc.' 'Sunburst' 'Dg'
#  'Johnson' 'Monerai' 'Texas Helicopter' 'Dial-thorp' 'Para-sail'
#  'Lombard Dilley' 'Meyers Aircraft Co.' 'Mareik-bensen'
#  'Eastern Ultralight' 'Stolp' 'Garlick' 'Eipper Formance' 'Prout' 'Kate'
#  'Smith-poston' 'American Aerolights' 'Aleson' 'Bowlin' 'Monnett - Larsen'
#  'Thorpe' 'Hamilton' 'Long' 'Twitchell' 'Clark' 'Rotec/botsford'
#  'Vans-rupert' 'Mattison' 'Gilbert L. Houston' 'Eames' 'Viking'
#  'Flug-und Fahrzeugwerke (ffa)' 'Curtiss' 'Wsk Pzl Mielec' 'J. Roberts'
#  'Sportavia-putzer' 'Gyaki' 'Easy Riser' 'American Eagle' 'Hackett/mckown'
#  'E.r. Hutson' 'Condor Ii' 'Finamore' 'Sopwith' 'Breezy Rlu'
#  'Rand Robinson' 'Dimaria' 'Laister' 'Vangrunsven' 'Berkshire' 'Schippers'
#  'Kane' 'Pietenpal' 'Chamberlain' 'Monke' 'Trager' 'Pestes' 'Grau'
#  'Fisher' 'Swain' 'Naval Aircraft Factory' 'Black' 'Zenair'
#  'Pietonpol-imrie' 'Beemer' 'Aerostar' 'Berwin' 'Camair Aircraft Corp.'
#  'Lowther' 'Pierce' 'Burnett' 'Jodel' 'Casa' 'Scarboro' 'Corbin' 'Aerotek'
#  'Arrow Aircraft Co.' 'Demeter' 'Leonard' 'Manta Products' 'Teratorn'
#  'Grieme' 'Midwest Microlites -' 'Semco' 'Bird' 'Pioneer' 'Prell' 'Catto'
#  'Starflight' 'Stewart' 'Mockrud' 'Edwards' 'Waspair Tomcat'
#  'West-heckman' 'Kuster' 'Johnston' 'Bucker Flugzeugbau'
#  'British Aircraft Corp. (bac)' 'Warren' 'Stol Aircraft'
#  'Pterodactyl/lambert' 'Clarks Pitt Special' 'Eipper Quicksilver'
#  'Wormley' 'Brandt' 'Mortensen' 'Kruer' 'Anderson Aircraft Corp.'
#  'Fueslein' 'Kecskes' 'Jilek-smith Miniplane' 'Gulfstream-schweizer'
#  'Eipper Quicksiver E' 'Pilatus' 'Kimbal' 'Hordemann' 'Kemmeyer'
#  'Hawker Siddeley' 'Lanny Rundell' 'Alderfer' 'Deley Starduster'
#  'Hight Smaragd' 'Highcraft' 'Popelka' 'Short Brothers' 'Baking' 'Wichawk'
#  'Jordan' 'Delts Wing Kites' 'Airbus Industrie' 'Bradey'
#  'Westland Helicopters' 'Morton' 'Teman' 'Jodel-bernier' 'Gary Wilson'
#  'Rider' 'Lazair' 'Kepple' 'Skov-papworth' 'Paul S. Kerr'
#  'Motorized Gliders' 'Vickers' 'Sabreliner Corp.' 'Rygg' 'Striplin'
#  'Yaple, Robert G.' 'Young-losey' 'Jodell' 'Wells/rand'
#  'British Aerospace' 'Lark Aviation' 'Dassault' 'Bach' 'Gordon' 'Shuey'
#  'Moseley/scorpion' 'Maupin' 'Harvey' 'Panaplane' 'Ultraclassics'
#  'Vampire' 'Chance Vought' 'Robert H. Low' 'Keith A Smith' 'Gardner'
#  'Heinemann' 'American Aviation Corp. (aac)' 'Sigers' 'Teratorn Acft Inc.'
#  'Eagle Balloons' 'Gross' 'Southern' 'Shark' 'Swanson/bensen' 'Vari'
#  'Alleva' 'Bengtson' 'Robert Mcdonnell' 'Lee M. Brown' 'Bowers'
#  'Birdman Enterprises' 'Owen Robert R' 'Martin Company' 'Bliss Corbin'
#  'Unknown' 'Sturges' 'Folke Wulf' 'American Aircraft' 'Fornaire'
#  'Brown, R. M. Jr.' 'Pzl-mielec' 'Bowen-powell' 'Beasley, Gerald L.'
#  'Teratorn Aircraft, Inc.' 'William Freeman' 'Murphy-charles'
#  'Rally Rotec' 'Hall-cavalier' 'Christen Eagle' 'Soneria' 'Olson' 'Gable'
#  'Ginn' 'Harper/cricri' 'Meyers' 'Brubaker' 'Pietenpol-grega'
#  'Ultraflight' 'Istenes' 'Wagner' 'Germany Wetherell' 'Leblanc' 'Jakel'
#  'Lee' 'William A. Waas' 'Lycan' 'Stolp Starduster Corp.' 'Robert Judd'
#  'Ultralight Flight, Inc.' 'Baugh-hubert' 'Sorrell' 'Halfpap' 'Storey'
#  'Robert B. Boston' 'Griffin Trane Inc.' 'Interstate' 'Humer' 'Griffin'
#  'John R Jones' 'Howard E. Lee' 'Stephens' 'Ritz' 'Applebay Sailplanes'
#  'Monett-keating' 'Rearwin' 'Amer. Aerolight' 'Peter A. Yarger'
#  'Jordan Henry J' 'Entwicklungsgemeinschaft' 'Ufm' 'Gillmore' 'Culver'
#  'Ultralight Soaring' 'Haxton' 'Jerry D. Fish' 'Teraton' 'Cessna Wren'
#  'Travel Air' 'Experimental Amateur Built' 'Morgan T. Melton' 'Sperling'
#  'Bobby Wayne Watkins' 'Mosley High School' 'Vance-hamm' 'Nesmith'
#  'Vultee' 'Heveron' 'Burns' 'Sims - Basset' 'Intermountain Mfg. (imco)'
#  'E.l. Griggs' 'Collins' 'S.i. Briggs' 'Demick James A'
#  'Bell-olympic Helicopters, Inc.' 'Zappia Gabriel J' 'Dahlman'
#  'Arnold Forest' 'Tate' 'Lighthizer, Richard E.' 'Darrell W. Mc Moran'
#  'Bakeman-chapman' 'Fred Williams' 'Lindsay Davis' 'Donald E. Bradshaw'
#  'Whitman' 'Vaughn' 'Bastian' 'Hayes' 'Calypso' 'Shindler-smiley'
#  'Ultralight Ufm' 'Universal Stinson' 'Russell St. Arnold' 'Cessna Ector'
#  'Phaneuf' 'Miller Air Sports' 'Head Balloons, Inc.' 'Ungerecht' 'Harris'
#  'Jett' 'Denil' 'Agusta' 'Focke-wulf' 'William T. Hodges' 'Reicher'
#  'Drake' 'Pickel' 'Fuller/findlay' 'Windecker Research'
#  'Robert Eggebrecht' 'Thomas' 'Garre Leo J' 'Brewer'
#  'Hamburger Flugzeugbau (hfb)' 'Kallansrud/pitts' 'Mccoy'
#  'Mitchell Ronald A' 'Harbaugh John T' 'Crosetti' 'Harvard'
#  'Light Aero,inc. (ashley)' 'Jack L. Bigham' 'Four Seasons Aviations'
#  'Moore' 'Aspen' 'Wells' 'Stevens' 'Kragnes' 'Reed'
#  'Pennington-eaa Biplane' 'Donald W Devine' 'Corlett-beahm'
#  'Barry Zielinski' 'Hart-thorp' 'Kenneth Roebuck' 'Hardy'
#  'Douglas Swanningson' 'Rawdon Bros. Aircraft' 'Lounsbery' 'Gyrocopter'
#  'Fuji' 'Polliwagen' 'Crowder' 'Saabye' 'Emair' 'Milentz' 'Masselink'
#  'Jim Mckinstry' 'Mcclellan J. Grote' 'Lyoyd Thompson' 'Auton - Dunham'
#  'Benjamin' 'Sevdy Pitts Special' 'Mitchell Harvey' 'Engel' 'Aronson'
#  'Stracener Experimental' 'Hilliard' 'Marr/eckburg' 'Kirst Allen J'
#  'Bainbridge' 'Ehlers' 'Johnson-rand' 'Canard, Inc.' 'Smelko' 'Cirrus'
#  'Sederberg' 'Huff' 'Condor Aircraft' 'Wisconsin State Prison' 'Istvanick'
#  'Wheat' 'Slingsby' 'Mcculloch' 'Vickers Slingsby' 'Lester F.w. West'
#  'Greer' 'Jack Boldt' 'Gamble' 'Holder' 'Centrair' 'Dempsey' 'Earnst'
#  'Stearman' 'Dassault-breguet' 'Silvaire' 'Airship Industries'
#  'Ringsdorf-mcconnell' 'Galloway' 'Bedeell' 'Heekin' 'Steens' 'Chadwick'
#  'Jenkins' 'E.t. Meredith Iii' 'Mcpherson' 'Haney'
#  'Briegleb Amature Built' 'Otis G. Lyons' 'Joel K. Senter' 'Hildebrand'
#  'Brians' 'General Dynamics' 'Killian' 'Failing/rand-robinson' 'Pzl'
#  'Neumann-everett' 'Leslie J. Royal' 'Richard E. Rowland' 'Borreson'
#  'Kibler-bede' 'Shindler' 'Kokes' 'Quinn Aviation' 'Polliwagen Inc.'
#  'Burch' 'Lett' 'Rand/robinson' 'William G. Cloaninger' 'Petracca'
#  'Larry Robbins' 'Fain' 'John H. Mc Clain, Jr.' 'Wag-aero, Inc.'
#  'Robert Thibodeau' 'Dietz' 'New Standard' 'Kauffman' 'Hazelrige'
#  'Frank H Marchetti' 'James Gress' 'Woolsey' 'Neyman-pietenpol'
#  'Christopher D. Brown' 'Schubert' 'Stampe' 'Larry Schindler'
#  'James Postlewait' 'Earl F. Folsom' 'Mcfarland' 'Jones' 'Star Duster Too'
#  'Ronald C. Render' 'Richard A. White' 'Ronald Houk' 'Pezetel'
#  'Mike Stone' 'Mar-flite' 'Advanced Technology' 'Skyranger' 'James/viking'
#  'Mitchell/bede' 'Duce Project' 'Valentin' 'Emroth Emair'
#  'Roger W. Stigen' 'Jauch' 'Welch' 'Thornhill' 'Pzl-bielsko' 'Stolt-adams'
#  "Conover's" 'Peterson' 'Jonas' 'Pitts Spl.' 'Laux Pitts' 'Todd' 'Brokaw'
#  'Vanbenthuysen John' 'Wippler' 'Lon J. Mcknight' 'Challenger' 'Univair'
#  'Aerofab Inc.' 'Douglas Maselink' 'Leone' 'Willie' 'Skurich' 'Leslie'
#  'Hodson' 'Ken Brock Mfg. Co' 'Ofria' 'Silvaggio'
#  'S. Piccolotto/dave Morss' 'Saab-fairchild' 'Lewis-pexton' 'Carothers'
#  'Parsons' 'Lonnie W. Ratliff' 'Dorfman,william A.' 'John Patrick Coleman'
#  'Gary E. Wilson' 'Brisbin' 'Lagatore' 'Gensen' 'Bill Mccarley'
#  'Griffin, Thomas' 'Douglas C. Campbell' 'Robert D. Campbell'
#  'Adams William C' 'Monnet' 'World Wide Industries' 'Socata' 'Stephenson'
#  'Commings' 'Bushby' 'Kuhn' 'Universal Aircraft Industries'
#  'Wayne Mathews' 'Whigham' 'Henley' 'Folsom' 'Swanningson' 'Patrick Henry'
#  'Shaffer' 'Durkota' 'Jim Elliott' 'Ltv' 'Glen Davis'
#  'Christen Industries' 'Bob White' 'Easley' 'Joachim Hoehne'
#  'Donald R. Casper' 'Perkins' 'Morley' 'Steinorth' 'Rjb Aviation'
#  'Taylor Lonsdale' 'Vere Eze' 'Blythe' 'Baby Bird' 'Day'
#  'Ltv Aerospace Industries' 'Russell' 'Glaser-dirks' 'Aviation Adv.'
#  'Wing Aircraft Co.' 'Conner' 'Hanson' 'Wright' 'Brewster' 'Milliken'
#  'Beaupre Elfering' 'Wsk' 'Jackman' 'Myers' 'Collin Campbell'
#  'Denney Aerocraft' 'Soward' 'Jerry Cox' 'Langeford' 'Fly Baby'
#  'Arbaugh Evans' 'Morris B. Stephens' 'Hispano Aviacion'
#  "Bauer's Mitchell Wing" 'Bernard Darmstadt' 'Green' 'Air' 'Rose'
#  'Hall Christen Eagle' 'Nelson/nelson' 'Avian' 'Carnes' 'Randy Tredo'
#  'Beaver' 'Sanders' 'Repliea 78 Ral' 'Robbins' 'Bensen-jansen'
#  'Edward R. Merkner' 'Quick Silver' 'H. Preiss' 'Andrew D. Moore'
#  'Mellema' 'Steen Skybolt' 'Charles S.hatchette' 'Mathew M. Kerr'
#  'Piasecki Acft. Corp.' 'Lazarini' 'Stainbrook' 'Jerry Berry'
#  'Goertz Bushby' 'Stevenson' 'Bell-campbell' 'Whittman' 'Patton Pitts'
#  'Weiss-haynes' 'Rose Rhinehart' 'Hansen' 'Troutman' 'Huizenga'
#  'Randolph R.clark' 'Woodrow S.a.' 'Kenneth Patsch' 'Cherry'
#  'Steven Soper' 'Samuel R. Hoskins' 'Wheeler' 'Bomberger'
#  'Capetown Builders' 'Collins Charles A' 'Jaks' 'Attebery-stainbrook'
#  'Thorp Aero, Inc.' 'Pate' 'Ward' 'Bernard' 'E. E. Schilling'
#  'David Gordon' 'Senior Aero Sport' 'Wise' 'Roger Warnell' 'Star-lite'
#  'Erickson' 'Russell Post' 'Brennan' 'Mayala' 'Passonno' 'Hegsted'
#  'Friling/cothern' 'Eugene Boos' 'Benham' 'Phillips' 'Lawrence'
#  'Joe Almon' 'Shanks/becker' 'Ellis' 'Tapaszy' 'Rarsch' 'Murphy'
#  'Forbes-wolfram Special' 'Alexander' 'Nord (sncan)' 'Jerome Dodge' 'Inav'
#  'Star Duster' 'Mccoy Robert-michael' 'White Lightning Aircraft Corp.'
#  'Floyd R.harris' 'Walter D. Burleson' 'Gillon' 'Smith & R. Mathews'
#  'Stahl-ameter' 'Buhl' 'James Olivier' 'Jere L. Rosser' 'Ralley'
#  'Koons-donald' 'Houk' 'Turnbloom' 'Hickham' 'Devries' 'Mullinax'
#  'Rohdecap/thorp' 'Moore-van' 'North American-maslon' 'Solem' 'Atr'
#  'Beggs' 'Kosch' 'Marrone' 'Dornier' 'Michael D. Mansfield' 'Air Command'
#  'Richard A. Brown' 'Strissel' 'Prue Standard' 'Resney' 'Kenny Deward'
#  'Barlow' 'Aero Mirage' 'Replica' 'Verbeek' 'Sprague' 'Mclachlan' 'Hunter'
#  'Devore Sunbird' 'Cremer' 'Jagger' 'Mclane' 'Frimelt Werner Moni'
#  'Spartan' 'Law' 'Woehrle' 'Pik' 'Beausoleil' 'Moss Timothy C' 'Noonan'
#  'Meyer' 'Northrop' 'Huffman' 'Moni' 'Butler' 'Ham' 'Aerodynamics .'
#  'Zank' 'Gaston/lakes' 'Greco Bruno' 'Bannwart' 'Kennedy' 'Concept'
#  'Denney' 'Talbott' 'Mcentee' 'Rollins' 'Teague' 'Lowder' 'Noble' 'Kiesel'
#  'Wayne Hooks' 'Great Lakes Adams' 'Budde Cassutt' 'Dubois' 'Fleet'
#  'Hastings' 'Hendrickson' 'Scharschmidt' 'Roe/pietenpol' 'Watts' 'Rushton'
#  'Buccaneer' 'Allen' 'Burkholder' 'William M. Burge' 'Arnold' 'Embree'
#  'Maxfield' 'Reder' 'Lutz' 'Sawyer' 'Canton' 'Boyles' 'Hall'
#  'Government Aircraft Fact (gaf)' 'Tomishin' 'National Balloon'
#  'Kolb Company' 'Woody' 'Geiger' 'Mercer' 'Commonwealth' 'Ellsworth'
#  'Bakeng' 'G&c Helicopters' 'Bennetter-stevens' 'Willi/bensen' 'Nixon'
#  'Klien' 'Rogers-gibson' 'Watkins/monnett' 'Questair' 'Napper'
#  'Extra Flugzeugbau' 'Pugh' 'Stits' 'Warnke' 'Parrish' 'Merchant' 'Couden'
#  'Durbin' 'Lamb' 'Herman' 'Sadler' 'Alexander Volksplane' 'Stoopin'
#  'Crump' 'Mandley' 'Isgrigg' 'Crusenberry' 'Colman' 'Timm' 'Hess'
#  'Gribosh' 'Hill' 'Hodges' 'Shiner' 'Weber' 'Bunch Eaa Biplane'
#  'Morane-saulnier' 'Barnett' 'Grosvenor' 'Page' 'Surline' 'Paxton'
#  'Marrek Smyth' 'Marlow Hilyard' 'Kitchen' 'Dreyer-starduster'
#  'Start & Flug' 'Neff' 'Anderson Pitts' 'Falcon Special' 'Fischer'
#  'Henderson' 'Cirrus Design Corp.' 'Hernandez' 'New' 'Schumann' 'Hyde'
#  'Stolp-starduster Too' 'Hurd/drifter' 'Starr' 'Judge' 'Mccurry' 'Chappel'
#  'Lloyd Feary' 'Bost' 'Bohnker' 'Byron/sorrell' 'Craven' 'Koopsen'
#  'Kerlin' 'Terry' 'Anderson-tucker' 'Teratron' 'Baron' 'Darlington'
#  'Helfrich-leonard' 'Locolce/blackwell' 'Van Wormer' 'Rutgers' 'Franklin'
#  'Huntley' 'Hahn' 'Gulfstream Aerospace' 'Classic Aircraft Corp.'
#  'Sollars' 'Applebay' 'Fantasy Sky Promotions' 'Silliman' 'Costa' 'Geddes'
#  'Atkins' 'Ferris' 'Williams' 'Krall' 'Vans' 'Shirlan Dickey' 'Townson'
#  'Van' 'Stanford' 'Braswell' 'Prairie Flyers' 'Rossi Pitts' 'Rosenmayer'
#  'Falco' 'Cocks' 'Wittman' 'Hulliberger' 'Mace' 'Sackett'
#  'Debarry/starduster' 'Tedford' 'Latham Alco' 'Garlick/guppy' 'Commens'
#  'Arthur' 'Thunder And Colt' 'Young-owens' 'Banks/mong' 'Billings/humbyrd'
#  'Dillinger' 'Snyder' 'Heibel' 'Svensson' 'Bingelis' 'Barker'
#  'Cessna Robertson' 'Shannon' 'Pilgrim' 'Shamgaugh' 'Roman' 'Autra'
#  'Vangorden' 'Lewis' 'Laycock' 'Arlington' 'Hicks/mervin' 'Experimental'
#  'Mickelson' 'Saab-scania Ab (saab)' 'Klob-gordon' 'Sandridge' 'Hitchcock'
#  'Tesori' 'Knowles' 'Beard' 'Sloan' 'Bumgartner/hirt' 'G.d.i.e.' 'Murphey'
#  'Mason' 'Lehman/jerrell' 'War Replicas' 'Stolp-adams' 'Harmon' 'Warwick'
#  'Eller' 'Composite Aircraft Mfg Co.' 'Aeromot' 'Rodgers' 'Stearns'
#  "Craven's Quickie" 'Jennings' 'Aircraft Parts & Dev. Corp' 'Halstead'
#  "Van's/fish" 'Poehls' 'Upchurch' 'Dyar' 'Lee, David' 'Schmahl' 'Lowe'
#  'Thiessen' 'Sharp' 'Morse' 'Coutz' 'Vestal' 'Donner/parton' 'Bridges'
#  'Tesmer Glassair' 'Grigg/bowers' 'Galbreath' 'Smithgall Pitts Special'
#  'Davis Starship' 'Fields' 'Avions Max Holste' 'Pazmany' 'Billings/white'
#  'Zengel' 'Ruschke' 'Glassair Iii' 'Holman/sears' 'Bloodworth' 'Dilley'
#  'Cushing' 'Good' 'Job' 'Whittaker' 'Hadley' 'Oregon Helicopters'
#  'Uhley-mason' 'Cox/pitts' 'Beneteau' 'Beauchesne/wells'
#  'Schuning/teratorn' 'Renninger' 'Vehafric' 'Wood-oldfield'
#  'Musick/terratorn' 'Stitts' 'Progress Aero R&d' 'Henry Vickers' 'Salmon'
#  'Bristow' 'Lowe/bensen' 'Mirsepasy' 'Wittman, S.j.' 'Cloud' 'King'
#  'Cabrinha/free Spirit' 'Bonds & Bungey' 'Prospector' 'James Eggleston'
#  'Abbott' 'Lancair' 'Gatzemeyer 88' 'Keener' 'Bratton' 'Dammann'
#  'Acroduster' 'Skelton' 'Mccormick' 'Cocchiarella' 'Dormoy' 'Tierra Ii'
#  'Feil' 'Brumbaugh/hubin' 'Bradley' 'Ruppercht' 'Monett' 'Rayne' 'Clatti'
#  'Harris-hafen' 'Minicab' 'Woods' 'Yakovlev' 'Maxair' 'Wesley'
#  'Sours/midget Mustang' 'Cooley' 'Howe' 'Evanson' 'Niedzielski' 'Skilling'
#  'Fletcher' 'Hancock' 'Stolp Starduster' 'Stits-itrich' 'Zimmerman'
#  'Smeesters' 'Roger Nelson' 'Baker/santiago Pitts' 'Brickman'
#  'Rand Engineering' 'Mannon-underwood' 'Wychen' 'Wheeler Acft. Co.'
#  'Funk, D.d. Aviation Co.' 'Eickmeier' 'Mccomb' 'Pond'
#  'Warren/keleher/lark' 'Bell-kitz Kopters' 'Burdette' 'Bruce Mckinney'
#  'Lanier' 'Logan, B.a.' 'Wittman Tailwind' 'Nelsen-david' 'Saint Louis'
#  'Edward' 'Bryce Duster' 'Crawford-gordon' 'Senior Aerosport/paet'
#  'Tundermann Venne' 'Long E-z-e' 'Steele' 'Davidson' 'Waldron' 'Mancini'
#  'Stanger' 'Conn' 'Biagi, Arthur R.' 'Thompson' 'C&j Sontheimer' 'Groves'
#  'Heindenreich' 'Ransome' 'Burton' 'Reid' 'Link' 'Wohlers'
#  'Talmadge Scott' 'Smyth Sidewinder' 'Freeman H Easton' 'Walter Hudson'
#  'James A Nelson' 'Farrington' 'Swing' 'Becker' 'Jolly' 'Daniels' 'Hood'
#  'Truckee Meadows' 'Stolt' 'Bennett' 'Avions Mudry' 'Ryan, Robert R.'
#  'Dan T. Zelazo' 'Williams, Robert G.' 'Lerstang' 'Michael C. Quigley'
#  'Lightcap' 'Bell-moore' 'Toussaint/quad City' 'Cunningham'
#  'Robert Van Scoyoc' 'Cecil, Richard C.' 'Sabelino' 'Goss' 'Bataller'
#  '67 Flying Dutchman' 'Rollins-bowers' 'Sattler' 'Cullen/roth'
#  'Spezio Sport' 'Lund' 'Briegleb' 'Grace' 'Gyroflug' 'Cirrus Klappmeier'
#  'Vanek' 'Aerodyne' 'Ray Edmistonn' 'K. W. Jeffers' 'Eugene M. Veras'
#  'Sukhoi' 'Buchanan' 'Robert C. Campbell' 'Childs' 'Eugene N. Rausch'
#  'Spark/acroduster' 'Gary Williams' 'Oo-culley' 'Dickey' 'Mingess-bennett'
#  'Cassuit' 'Hardesty/hays' 'Larsen Charles Bennett' 'Selstad'
#  'E.j. Novotny' 'Huffaher' 'Charles T. Brietigam' 'Ronald D. Cothern'
#  'Olsen' 'George R. Losey' 'David B. Robertson' 'Cloutier'
#  'Wheeler Technology, Inc.' 'Custom Aerotech, Inc.' 'Fouga'
#  'Finn A. Arnold' 'Bell-continental Copters' 'Forbing' 'Leffler/mcfarlane'
#  'Bryant Rowland' 'Bd 4- Francisco' 'Boson' 'Hilvety' 'Bennert' 'Prosser'
#  'Warkentin' 'Don G. Kaye' 'Illi' 'Naaman Haren' 'Harper' 'Vaden'
#  'Alfred Stevens' 'Micalizio' 'Calvart' 'Neal' 'Heinrichs'
#  'Fisher Flying Products' 'Trice' 'Christen/walter' 'Aerospatiale/socata'
#  'Brose' 'Trammel' 'Miles Atwood' 'Bob Sandlin' 'Morris' 'Blaine Laux'
#  'Comben' 'Dooley' 'Parrigin' 'Massegee' 'Roger A Hansen' 'Ely' 'Blaise'
#  'Moffitt, William A.' 'Folland' 'Carlson Aircraft' 'Jeff Pierson' 'Palen'
#  'Erik K. Van Der Kaay' 'Melton' 'Historical Aircraft Corp.' 'Skytek'
#  'James Cote' 'Joseph W. Hillbrand' 'E Tn Plts Starduster' 'Joe L. Harr'
#  'Daniel S. Taylor' 'Olsen-gordon' 'Marier' 'Dean Bartel' 'Young'
#  'Fogarty Pitts' 'Craig A. Gordon' 'Taylor Titch' 'Robert Bressler'
#  'Lowe/law' 'Asta' 'Astar' 'Virgil D. Hawks' 'Mocock' 'Rans Company'
#  'Walter Chandler' 'Riddell' 'Hagg' 'Donald E. Samuels'
#  'Huddleston/becktold' 'Questaire' 'Avions Marcel Dassault'
#  'Parker Warren' 'Latham' 'Bartholomew Kolb' 'Elliott' 'Clyde L. King'
#  'Monocoupe Aircraft' 'Glassair' 'Herbert W. Ross' 'David Lowe' 'Akins'
#  'Sunrise Ultralight' 'Paulbicke' 'Glasair Iii' 'Burnett, Jerry D.'
#  'Brault Glasair' 'Snider' 'Fred B. Stencel' 'Townsend' 'Schwartz'
#  'Smelser' 'Fagerberg' 'Rutan Aircraft Factory' 'Rudolph Zeller'
#  'Donald L. Hedeman' 'W. R. Mathis' 'Aerospace Tech. Of Australia'
#  'Richard Cheney' 'Vuncannon' 'Gildersleeve' 'Universal Globe' 'Tierra'
#  'Corley Hubert' 'Australite' 'George E Heide, Jr.' 'David K. Maxwell'
#  'Beamont' 'Dave Ronneberg' 'Alexander Schleicher' 'Greg Smith'
#  'Larocque, Raymond E.' 'Peecher' 'Charles Raucci, Jr.' 'Gremminger'
#  'Avid Flyer Inc.' 'Hagaman Pitts' 'Bronner' 'Weaver' 'Rider-charles'
#  'Duffy' 'Jack Thomas' 'Allan R. Goldman' 'Green-fowler' 'Heal'
#  'Paul M. F. Walker' 'Sebly Amateur Built' 'Sterns' 'Daniel La Lee'
#  'Lgs Aviation, Inc.' 'Jerrell' 'Derego' 'Wilbur D. Batman' 'Galaxy'
#  'Lacey' 'Moeckel' 'E.c Trynka' 'Morrison-keitel' 'Airnew, Inc.'
#  'Donald R. Lee' 'Schrader, Edward' 'Lucky' 'Aerospace' "O'connell"
#  'Valentin Gmb H' 'Maridon' 'Grimm' 'English' 'Fink, Charles H.'
#  'Al White' 'Hinton' 'Warner, David B.' 'Gordorn Price'
#  'Laurent A. Cloutier' 'Taylor Air Command' 'Clifton Dixon' 'Schultz'
#  'Lars' 'Milner, Dick G' 'Canadian Car & Foundry' 'Beckloff' 'Manville'
#  'Benson/ambrocini/wentzel' 'Harold J. Eagen' 'Weyerts'
#  'Pilatus Britten-norman' 'Beierle' 'Friling' 'Hocker' 'Tullis'
#  'Icard, Claude M.' 'Bates, Frank L' 'Cresawn Pitts' 'Merritt'
#  'Timothy Wingate' 'Bell-k Copter' 'Donald W. Sorrels' 'John H. Logan'
#  'Hoffmeyer' 'Boland/poe' 'Joseph A. Mullan' 'Abernathy' 'Christian Ind.'
#  'Joseph P. Frasca' 'Lyons Stueckle' 'Ullman' 'Cano' 'Bentley'
#  "O'dell, Herbert L." 'Challenger Ii' 'Denney Aircraft Behn' 'Mcholland'
#  'Lassiter' 'Don Jackman' 'Winchester' 'Mahan Hardaway' 'Jesse Knight'
#  'Balkema/boven' 'Willkins-wayne' 'Georga L. Atwood' 'Advanced Aviation'
#  'Speyer' 'Kitfox Ten, Inc' 'Bell-transworld' 'Hiller-osborn'
#  'North American-kenney' 'John W Upton' 'Quickie Aircraft' 'Devenport'
#  'Kinkade E.5' 'Smith/davis' 'Alvin D. Campbell' 'Walter R. Penney'
#  'Mosley Hs' 'James Houston' 'Air Trans. Inc' 'Warfield'
#  'Aero Mercantil S.a.' 'Raymond Bristow' '85 Manista' 'Quad City'
#  'Richard C. Ballow' 'Ralph Legate' 'Kna,ken,dac,wel' 'Avions Fairey'
#  'Michael Conner' 'D.w. Owens' 'Robert L. Rice' 'Wind Ryder' 'Jr. Ace'
#  'Ankerman, Donald L.' 'William D. Weeks' 'Gerald G. Holland'
#  'Maya, Jaime' 'James D. Riehm' 'Avid Aircraft' 'R. W. Switzer'
#  'Tomlinson' 'Pzl-okecie' 'George Adrian' 'Carey Glassair' 'Mcewen Dick'
#  'Stoltzfus' 'Guy Whisenant' 'Flight Works Capella' 'Rose Wesley'
#  'Eichblatt' 'Craig Morehead' 'Larry E. Medlin' 'Wishon' 'Shewmaker'
#  'Sam R. Crowell' 'Gillespie/pitts' 'Lawrence H. Macey' 'Aviat' 'Nanchang'
#  'Corbus/winters' 'Cedric Lewellen' 'Mcquen' 'Robert Griffiths'
#  'Brantly-hynes' 'E.e. Shilling' 'James D. Bierly' 'Cobb Intl'
#  'Donald E. Crocker' 'Ardovino Mariucci' 'Willis' 'Schweitzer'
#  'Richard N. Burns' 'A. H. Gettings' 'Rutter' 'Wicks' 'Ronnie Baker'
#  'Hopkins, R. And M.' 'Parrish, Paul' 'Wayne K. Giles' 'Jacanin'
#  'Commander' 'Lewis-starduster' 'Barton, Robert A.' 'Takemoto'
#  'Murdock/gates/field' 'Pokorney Smith' 'Vandenbos/thorp' 'James J. Dean'
#  'Mclaughlin' 'Guzzino, P.a.' 'William Bovard' 'Peres' 'Victor E. Nigro'
#  'Dennis L. Fetters' 'Goehring' 'Harriman' 'Danny W. Sadek' 'Madsen'
#  'Bell-world' 'Jimi Youngblood' 'Dofka, Martin F.'
#  'Holmes-salley/starduster Too' 'Virgil Larson' 'Bernard W. Resnik'
#  "O'donnell" 'Borgaes' 'John Schackel' 'Johansen' 'Daniel M. Dent'
#  'Townsend-snyder' 'Berkshire Mfg.' 'Krug' 'Kory G. Cornum'
#  'Thomsen, Horst' 'Haas' 'Hauser, William C.' 'James Snyder'
#  'George A Chaffee' 'James Schwarzman' 'Chapuis' 'Dewitt, Richard A.'
#  'Greth' 'Robert D. Waldron' 'Alkire' 'Rans' 'Donald L. Betchan' 'Mercury'
#  'Bull' 'Cessna Reems' 'Edra/mcdermitt' 'John K. Groff Jr.'
#  'John Mitchell' 'Jarrell' 'Bacon' 'Danny M Damron' 'Broussard'
#  'Schneider/brashear' 'John S. Holzemer' 'Stuart J. Carter'
#  'R.p. Williams' 'Frost' 'Benson-callaway' 'Gerald Barker' 'Schaknowski'
#  'Tbm, Sa' 'Woodstock' 'William C. Keiling' 'Lamb/starduster' 'Reif'
#  'Dale Conover' 'Snodgrass' 'Curt Hoffstad' 'York' 'Warren-thomas'
#  'Tennessee Engineering & Manf' 'Slade H. Holmes' 'Tinsman' 'Troy Bellah'
#  'Sparks-schreder' 'Rettberg' 'Abrams/nuding' 'Lanceair'
#  'Golightly, Robert B.' 'Clatanoff' 'Carlson' 'Smitrovich' 'Mcilraith'
#  'Richard O. Middlen' 'Swich' 'Franklin-sullivan Technologies' "O'connor"
#  'James R. Prideaux' 'Harkness, Richard W.' 'Gilbert' 'Vuncannon Rotorway'
#  'Patrick F. Bowers' 'Pasporello, J.f.' 'Marcy' 'R.w. Sherman'
#  'Todd Goudeau' 'Colgate, Henry A.' 'Litchford' 'Mason, Jack A.'
#  'Van Arsdell/brent,m.' 'Lydick' 'Cuevas, Orlando S.' 'Donald Rhodes'
#  'Shaw' 'Croy' 'Bunn, Richard B.' 'Don Showalter' 'Keller' 'Ferran'
#  'Bates' 'H. Raymond' 'Bertone' 'American General Aircraft' 'Cessna Soloy'
#  'Morgan' 'Schicora' 'Huddleston-bell' 'Langerud' 'Asselyn'
#  'Root, Arthur T.' 'Acro Sport' 'E.l. Erickson' 'Mistretta' 'Barr'
#  'Kibiuk' 'Silva' 'John Thomason' 'Roy Rey' 'Vaughan' 'Fawcett'
#  'Kojima, Jun Lewis' 'Violet' 'Kertesz' 'Siegel' 'Mcreynolds' 'Iseman'
#  'Bruce' 'Dobbs' 'Tuttle' 'Snobird' 'Homer Davis' 'Steven Kurtis'
#  'Macphee' 'Mcmillin' 'Leveck' 'Haltom' 'T.r. Bristol' 'Witts & Church'
#  'Zeigler' 'Extra' 'Forest Ripley' 'Rapp' 'Hockenbury' 'Grove' 'Bryant'
#  'Meador' 'Rainey' 'Larkin' 'Rambow' 'John Shufflebarger' 'Us/lta'
#  'Wsk Pzl' 'Schmidt' 'Amato' 'Mark Streitz' 'Henry J. Camacho' 'Drlik'
#  'Claude E. Merrin' 'Pzl Warzawa-okecie' 'Sayer, Trevor A.'
#  'Robert L. Kennedy' 'Skillman' 'Tucker' 'Emory W. Greer, Jr.'
#  'Reims Aviation' 'Gritter' 'Romig' 'Raymond' 'Smitrvich Starduster'
#  'Sill/thomas' 'Irving Siewert' 'Glenn' 'Daniel Squire' 'Titan Aircraft'
#  'Doellefeld' 'Crowser' 'Wernega' 'Adolfson' 'Hoopes' 'Wiley'
#  'American Eurocopter' 'Schultz/bowers' 'Quad City Aircraft' 'Rolando'
#  'Hancock- Harris' 'Stark Rand' 'Zbacnick' 'Beatty' 'Curry' 'Stoeckler'
#  'Krowell' 'Ferdon' 'Riches' 'Nall' 'Harral' 'Howard W. Dutton' 'Hadaller'
#  'Sukane' 'Gera' 'Kit Fox' 'Darst' 'Aero Falcon Intl., Inc.' 'Brauch'
#  'Love, Sanford W.' 'Wm. D. Butterill Mustang' 'Walter D. Courtney'
#  'Ekins' 'R.d. Bell/pietenpol' 'Kope' 'Ultimate' 'R. J. Mcnaul'
#  'Jordi, Ronald H.' 'Bradford Pietenpol' 'Sheats' 'Busby' 'Reher, Kent O.'
#  'Keuthan' 'Lach' 'Coen' 'Mascola' 'Westholm' 'Smyth' 'Ferrie' 'Sterner'
#  'Wilson' 'Legrand' 'Alfred F. Dibernardino' 'R&k Special'
#  'Scaled Composites' 'Kewley' 'Cornwell' 'Mcinroy' 'White' 'Kelm' 'Cryder'
#  'Featherston' 'Emmert' 'Schlappi' 'Hannah' 'Silver' 'Springer' 'Lovern'
#  'Bowermaster' 'Hawkins & Powers' 'Flake' 'Scott' 'Vacey' 'Cooprider'
#  'Angel Elbert S Jr' 'Bell-carson' 'Albrecht' 'Steven Ulrich' 'Krotje'
#  'Jetstream' 'Cleveland' 'Braegger' 'Upton' 'Wonder' 'Ebershoff' 'Carson'
#  'Golightly' 'Sommerauer' 'Palmer' 'Nelson' 'Clunis' 'Furche-bielsko'
#  'Plummer' 'Oconnell' 'Cannon' 'Lampman' 'Roberts' 'Gansheimer' 'Argo'
#  'Jenks' 'Mikoyan Mig' 'Harper, Jack M.' 'Corby Starlet'
#  'Daffron, Harold C.' 'Piotrowski' 'Unrein' 'Kelley'
#  'American Champion (acac)' 'Fighter Rebuilders' 'Defelici'
#  'Randolph Flagg' 'Wallace' 'Foote' 'Robert O. Ely' 'Abc' 'Talago'
#  'Back Forty Developments' 'Asher' 'Newgard' 'Jacobson' 'Remote Sensing'
#  'Laurel Aero Club' 'Vavra, Martin A.' 'Rich' 'Ferguson' 'Air Creation'
#  'Hesterlee' 'Blackmun, Larry' 'Robl' 'Richmond' 'Hallstrom'
#  'Townsend, H.l.' 'Kelly' 'Mid State Ultra Light' 'Hillberg'
#  'Praker Thorp' 'Bradford' 'Staudacher' 'Wray' 'Parker' 'Perth Amboy'
#  'Donner Pitts' 'Latter' 'Kopp' 'Maxair Aircraft Corp.' 'Pecchio'
#  'Wsk Pzl Krosno' 'Hayes/pietenpol' '1st Ftr Gp' 'Popehn Arthur J.'
#  'Prue Irving Owen' 'Hruby' 'Falen' 'Schumacher' 'Twibell Richard Dale'
#  'Arthur Alan Blind' 'Bellah' 'Schell' 'Mascari' 'Stolte' 'Riley, Donald'
#  'Marvin E. Eubanks' 'Stephen' 'Payne Foster' 'Bourque Experimental'
#  'Mustari' 'Mueller' 'Derr' 'Fullana' 'Hunsberger' 'Hucke, Ronald L.'
#  'Frank M. Kopecky' 'Bambrick' 'Sam Hale' 'Hickey' 'Freeman' 'Hawk'
#  'Edward A. Alderfer' 'Donovan' 'Inman' 'Aces High' 'Montana'
#  'Miller, John' 'Lattimore-dwyer' 'Arthur Chase' 'Starman' 'Groce'
#  'Keuthan, Charles J.' 'Stugart' 'Stulp' 'Hankins/dickerson'
#  'Lafrance V-witt' 'Allen D. Potts' 'Schreiber-stitts' 'Watson'
#  'Advance Aviation' 'Advanced Acft' 'Robert Eldon Idler' 'Mankovich'
#  'Frith' 'Walton' 'A. Le Francois' 'Thalman' 'Donald E. Kovol'
#  'William P. Bouda' 'James Chisum' 'Eurocopter' 'Smart' 'Wdl' 'Singer'
#  'Mooney, Dan' 'Quickie-myers' 'Oestreich' 'Prest' 'Ultralight'
#  'Dooley, James M' 'James B. Edwards' 'Corley' 'Thomas E. Georges'
#  'Simcox' 'Mcmurtrie' 'Winn' 'Bony' 'Glines' 'Larsen' 'Rey' 'Rans/hine'
#  'S M A N' 'Stan G. Hallam' 'Herron' 'Angel' 'George'
#  'United Consultant Corp.' 'North American-barene' 'Brisendine'
#  'Glen A. Senecal' 'Fighter Escort Wings Ltd' 'Lessel' 'Bartholomew'
#  'Weeks' 'P. D. Chambers' 'William Mc Glumphy' 'Colvin' 'Elvin N. Kier'
#  'Timothy J Brown' 'Render' 'Wyman' 'Hoover' 'Larson, C.h.' 'Gay' 'Matto'
#  'Stuart/wagner' 'Beebe, Dale G.' 'Craighead' 'Roy' 'Bruce Tifft'
#  'Morrison, Marvin E.' 'Schmanski' 'Burken' 'Hinshaw, Keith T.'
#  'Cumberland-pitts Special' 'Beecher' 'Wente' 'Ryan Aeronautical' 'Roggio'
#  'Baker' 'Bulsky' 'Andris' 'Garrison' 'Haseloh, D. W.' 'Eccker, Donald E.'
#  'Packard/squire' 'K. A. Covington' 'Stembridge' 'Kirkpatrick' 'Swant'
#  'Duke, Clarence E.' 'Briggs' 'Baxter-wilson' 'Fabre' 'Korzep'
#  'Axell, Charles' 'Bubel, John A.' 'Knapp' 'Sorrel' 'Godkey'
#  'Grunska Earl J' 'Harding' 'Pitcher' 'Stol' 'Erwin' 'Purdy' 'Bailey'
#  'Schlagenhauf' 'Moncrief' 'Cornelius' 'Knoll-bensen' 'Burchfield'
#  'Devaughn' 'Tom Kilgore' 'Stokes' 'Bronislaus' 'Joy' 'Berg'
#  'Walter W. Bell' 'Ball' 'Tupta-smith Miniplane' 'Issoire-aviation'
#  'Willingham, Dave L.' 'Ed Bergreen' 'Rocky Mountain' 'Spreuer' 'Kemp'
#  'Cocchi' 'Pincince' 'Griner' 'Sagerser' 'Field' 'Miller, Terry W.'
#  'Knosp' 'Nicolas Beasely' 'Kashpureff' 'First Strike' 'Koval' 'Botteron'
#  'Stafford' 'Edwin J. Estenson' 'Craig' 'Quadcity' 'Margeson/heidebrink'
#  'Darrell' 'Williams Bell' 'Steinke' 'K. Davey And B. Davey'
#  'Kenneth Savidge' 'Revolution Helicopter' 'Pederson' 'Fox Aircraft Corp.'
#  'Mcnulty' 'Hughlett' 'Van Zwoll' 'Yothment' 'Guevremont'
#  'Ronneberg/murphy' 'Kinner' 'Birdman Enterprises, Inc.' 'Park' 'Gettig'
#  'Ronsrans' 'Kraetzner' 'Insua' 'Short' 'Isaacson' 'Markwood'
#  'Elan Glaser Dirks' 'Josephson' 'Bristol' 'Kiesel Easy' 'Kevin Naser'
#  'Floyd' 'Morrow' 'Patin' 'Gillet' 'Chambers' 'Welles' 'Gift'
#  'Balloonbau Woerner Gmbh' 'Sinclair' 'Sjostrand' 'Haugen' 'Hard' 'Snyded'
#  'Fratus' 'Mcclintic-piercie' 'Deangelo' 'Menear Pitts'
#  'Pro-built Aviation' 'Rasmussen' 'Rudy' 'Clapp' 'Cheney' 'Donegan Benton'
#  'Schlitter' 'Rupe' 'Louks' 'Madsen/rans' 'Chard' 'Blatter-pitts'
#  'Kelosky' 'Roisum Team' 'Lopez Lancair' 'Crowley/zenair' 'Petrik'
#  'Fallbeck' 'Eaa Chapter 163' 'Pezold' 'Bischoff' 'Cooke' 'Lodge'
#  'Lynch Starduster' 'Diamond Aircraft Industries' 'Sellors' 'Krugler'
#  'Hardesty/hays Quickie' 'Mcclung' 'Schafer' 'Graichen' 'Koutz' 'Herring'
#  'Robert Eckley' 'Mckibben' 'Bitonti' 'Otis' 'Pro Star' 'Moravan' 'Mumm'
#  'Nicholson' 'Klingberg Miniplane' 'Semple' 'Krueter'
#  'Rotor Flight Dynamics' 'Gilpatrick' 'Connell' 'Robin, Avions Pierre'
#  'Masnic' 'Madorin' 'Mcrae' 'Steeves' 'Marks' 'Worthington' 'Kitfox'
#  'Bishop-christian' 'Bumford' 'Summerfeldt' 'Mulholland' 'Scheperle'
#  'Domaille' 'Luckett' 'Russman' 'Lampert' 'Meeker' 'Powell' 'Van Dyke'
#  'Twibell' 'Sport Flight' 'Gage' 'Snowbird' 'Explorer Post 51' 'Lemoine'
#  'Forth' 'Vernon L. Cox' 'Luttrell-lacky' 'Whistle' 'Deaton' 'Veazie'
#  'Deweese' 'Elves' 'Gillespie' 'Merle Musson' 'Limes'
#  'Lithuanian Factory Of Aviation' 'Crescenzi' 'Marcellus' 'Revell'
#  'Ezekiel' 'As+ Ltd.' 'Boeing-brown' 'Tilbert' 'Powers' 'Dickinson'
#  'Merlin' 'Sky Star' 'Dotson' 'Gray Miniplane' 'Stelly' 'Corey'
#  'Fredenburg' 'Head' 'Carrison-seiman' 'Van Horn' 'Little' 'Owens/smyth'
#  'Price' 'Aerotechnik' 'Mini Ace' 'Farland' 'Loehle-avia' 'Wsk Pzl-krosno'
#  'Prevatt' 'Rominger' 'Charles Raymond' 'Sisk' 'Hewitt' 'Bowles/irwin'
#  "O'day" 'George Evenson' 'Hanks' 'Tocholke' 'Sauder' 'Dearinger' 'Horton'
#  'Poppenhagen' 'Conkey/wapelhorst' 'Graham' 'Barton' 'Chester'
#  'Corben Baby Ace' 'Elliot' 'Yasecko' 'Kraft' 'Steward' 'Qualline'
#  'Slaybaugh' 'Vanwinkle' 'Hoffman, Wolf, Flugzeugbau'
#  "Ultravia Aero Int'l" 'Sportsman' 'Hernandez Challenger' 'Emroth-emair'
#  'Geide' 'Hampson' 'Culbertson' 'Stout' 'Mrotek' 'Schuler' 'Ramesbotham'
#  'Atkinson' 'Bell/tsirah' 'Westcott' 'Fernandez' 'Cresap' 'Flightstar'
#  'Karr' 'Jackson' 'Green Castle' 'Grazier' 'Dickmann' 'Kenoyer' 'Mudry'
#  'Thocker' 'Tubb' 'Coursey' 'Rozendaal' 'Ralph Taylor' 'Bins' 'Crouch'
#  'Richards Lancair' 'Dickson' 'Aero Vodochody Aero. Works' 'Keith' 'Ensey'
#  'Dellicker' 'Flight Star' 'Burns Burn' 'Karmy' 'Lindberg' 'Collier'
#  'Ken Seright' 'Leibert' 'Aerostar, S.a' 'Vanatta' 'Tupolev' 'Fleming'
#  'Moody' 'Dubis' 'Zukowski' 'Opperman' 'Hoster/volmer' 'Pereyra'
#  'Wiedemann' 'Farhat' 'Richardson' 'Trickle' 'Sirocco Flying Club'
#  'Pacheco' 'Barriger' 'John T. Garrett' 'Hefty' 'Mahan' 'Cress' 'Crane'
#  'Richards' 'Berry' 'Hemingway' 'Hoac Austria' 'Keating' 'Hackett'
#  'Buesing' 'Bill Parson' 'Columbia' 'Passadori Norman' 'Teschendorf'
#  'Rochette' 'Charles J. Keuthan' 'Catchot' 'Theis' 'Hutton Rand Robinson'
#  'Allen-wayne Pitts' 'Kunc' 'Rosen' 'Cumberland' 'Basinski' 'Gordon Price'
#  'Devendorf' 'Duff' 'Ivan Langston' 'Shoaf' 'Jaquish' 'Porter'
#  'Eugene Clements' 'Hendrix' 'Thacker' 'Gowan' 'Hammer' 'Marsh-turner'
#  'Travis C. Elmore' 'Capstaff' 'Crosby' 'Dresbach' 'Henry' 'Noe'
#  'Staudaucher' 'Giertz' 'Kohles' 'Siefert' 'Mc Ardle' 'Boccher' 'Goodwin'
#  'Wood' 'Roe-wayne' 'Ross/stonecipher' 'Wolf' 'Sherman Powell' 'Shafer'
#  'Rans S-12 Airaile' 'Dietrich' 'Stiritz' 'Dfl Holdings Inc.' 'Reiffer'
#  'Moran' 'Niquette' 'Aerostar-raven' 'Slingsby Aviation Plc' 'Fronsman'
#  'Hillam' 'Eichman' 'Goode' 'Lardas' 'Garner' 'Goble' 'Kenneson' 'Shapley'
#  'Kearns' 'Stratton' 'Mitteer' 'Bauer' 'Velocity' 'Iverslie'
#  'Poor Boys Toys Inc' 'Peck' 'Valley Adventurers, Inc.' 'Riekkenen'
#  'Simpson' 'Rotz' 'Hefner Pitts' 'Haines' 'Jurka' 'Kellums'
#  'Fairchild Heli-porter' 'Fingerhut Revolution' 'Lorello'
#  'Southwest Florida Aviation' 'Southern Aero' 'Comeaux' 'Reynolds'
#  'Higgens' 'North American-aero Classics' 'Hallam' 'Burgess' 'Shutt'
#  'Roddie' 'Newberg' 'Keaggy-david' 'Reilly' 'As+ Ltd' 'Brashears'
#  'Louttit' 'John W. Culp' 'Barrigar' 'Pohlman/pohlman' 'Universal'
#  'Rans, Inc.' 'Mikowski' 'Blackwell' 'Zhuhai Helicopter Co.' 'Reed-madsen'
#  'Ford' 'Ciernia' 'Adrian Davis' 'Sego Tool' 'Beckham' 'Revolution'
#  'Striplin Aircraft Corporation' 'Saldairiaga' 'Rodgers/gaust' 'Roebuck'
#  'Mark Ewart' 'Blue Denney' 'Schramm' "Siggi's Airplane Works"
#  'John T. Simpson' 'Bihn' 'Cady' 'Mayers' 'Daniel' 'Poling' 'Via Inc'
#  'Christopher Coats' 'Nerstrom-tailwind' 'Palermo'
#  'Twin Commander Acft. Corp.' 'Sutton' 'Raser' 'Sherman'
#  'Chinese A/f Aero Ind Dev Ctr' 'Bromley' 'Goins' 'Ireneusz'
#  'Charles Holmes' 'Wilde Mickey' 'Tankersley' 'Stanek' 'Wasielak' 'Zwart'
#  'Walter J Collie' 'Freije' 'Burchinal' 'Sweet-house' 'Nickelson Martin'
#  "Duci's Vans" 'John S. Hickey' 'Gough-herrman' 'Zito' 'Victor Marsh'
#  'Duskin' 'Ramseyer' 'Brock' 'Starck' 'Krips' 'Waxenfelter' 'Froberg'
#  'American Blimp Corp.' 'Jaeger' 'William Sargent' 'Foster/hilsman'
#  'Porat' 'Dennis L. Long' 'Stewart 51 Inc.' 'Kaas'
#  'Star-lite Engineering Ltd' 'Orlando Heli Air Inc.' 'Masak' 'Lerille'
#  'Mcclead' 'Schrack' 'Quad City Ultralight Aircraft' 'Bombardier'
#  'Dangremond' 'David Mcelhannon' 'M2' 'Read' 'Deberry' 'Morrison'
#  'Butler Tool' 'Stemme' 'Kreatz' 'John H. Korb Jr.' 'Mader' 'Mohr'
#  'Morelli' 'Waters' 'Papa 51 Ltd., Co.' 'Rans Inc.' 'Jacob Tussel'
#  'Cawood' 'Sheets' 'Mejia' 'Girgen' 'Wolfe' 'Arner' 'Robert E. Bean'
#  'Fones' 'Gisclair' 'Blackmore' 'Fife' 'Hawker Aircraft Ltd.' 'Offord'
#  'Tillman' 'Progressive Aerodyne Inc.' 'Hartzler' 'Narrin-whittman'
#  'Nolley' 'Stroud' 'Ector Aircraft Company' 'Hoffmann' 'Montgomery'
#  'Koster' 'Frandsen' 'Kerr' 'Tracy' 'Fithian' 'Brunnemer'
#  'Lane Progressive Aerodyne, Inc' 'Ross' 'Mastopietro' 'Person' 'Overton'
#  'Vollmers' 'Meeuwsen' 'Stubbe-kitfox' 'Peebles/lancair 360' 'Nauer'
#  'Air Command International, Inc' 'Shoemaker' 'Mccarty' 'Cook'
#  'De Malignon' 'Baggarley' 'Miehl' 'Wiles' 'Marchetti'
#  'Progressive Aerodyne' 'Luckey' 'Preece' 'Fennell' 'M. C. Thomas'
#  'Dean R. Fellows' 'Six/huber' 'Lesemann' 'Raymond C. Voegele' 'Whetzel'
#  'Wakely' 'Kite' 'Massey' 'Dornbos' 'Ekstrom-farrington' 'Bibb' 'Needham'
#  'Stubler' 'Koskella' 'Simons' "Jobe's" 'Vertical Concepts Inc.'
#  'Culver-revolution' 'Weber-mustang Ii' 'Ankenbruck'
#  'Hopkins Buckeye Industries' 'Hughes Cassutt' 'Cora' 'Barklage'
#  'Fieseler Flugzeugbau' 'Duncan' 'Bognuda Livio' 'Nicks' "O'neil"
#  'Evarts Aviation Inc.' 'Hundere' 'Goodyear Aerospace'
#  'Auxier Herschel A Jr.' 'Foreit' 'Burson' 'Bac-aerospatiale' 'Painton'
#  'W.s. Bowers, Jr.' 'Zeidler' 'Peters' 'Reinhold' 'C.b. Withun'
#  'Becker Wag Aero' 'Pitcairn' 'Tomschin' 'Ilyushin' 'Horner-ryan'
#  'The Old Hen Crow' 'Stanton' 'Blanton' 'Armbruster' 'Holiman'
#  'Sid Champion' 'Michael L. Thibault' 'Dennis Pointer' 'Parkman' 'Dean'
#  'Aegerter, Simon' 'Richard Young' 'Pacific Aviation Composites'
#  'Trohoski' 'Abraham J G Ii/erickson K' 'Coelho' 'Gettis H. Hudson'
#  'Stern' 'Miller/bell' 'Lee S. Harvard' 'Monocoupe' 'Zivko Aeronautics'
#  'Cooper' 'Keil' 'Calkins' 'Scott A. George Jr.' 'Miner' 'Gallob' 'Mil'
#  'Delong' 'Deleeuw' 'Pushkar' 'Dryer' 'Sly' 'David C. Bock' 'Steve Hill'
#  'Frederick Sweet' 'Witzel' 'Davis/cleaver' 'Reindl' 'Bean' 'Zemp'
#  'Hoskins Craig' 'Raytheon Corporate Jets' 'Ventura' 'Elam' 'Durrwachter'
#  'Kawasaki' 'Ives' 'Dawe' 'Oakes' 'Narzinski' 'Barrett Bensen' 'Berrick'
#  'Stock' 'R.m. Bishop' 'R.o. And D.o Hewitt' 'Widner'
#  'Wsk Pzl Warzawa-okecie' 'Eugene Hughes' 'Matter' 'Boone'
#  'Michael W. Campbell' 'Bell/mason' 'Engleman' 'Boyd Dan' 'Abrams'
#  'Hammond' 'Robert W. Ferrell' 'Murray R. Gardner' 'Nations' 'Ben Travis'
#  'Dehaan' 'Toman' 'Poskus' 'Crozier' 'Hornbeck' 'Saliba' 'Kucki'
#  'D. Wayne Smith' 'Blanco' 'Flaherty' 'South Mississippi Light Aircra'
#  'Ab Sportine Aviacija' 'Prendergast' 'Donald White' 'Devor'
#  'Heilig-reading' 'Keen' 'Libersat' 'Robert R. Callahan' 'Zlin' 'Modrow'
#  'Duci' 'Jasper' 'Mahler' 'Whithington' 'Larson Smith Miniplane'
#  'Lakeland Ultralites Inc.' 'John Hubbard' 'Parks' 'Harry Tomlinson'
#  'Williamson/williamson' 'Gadbury' 'Walentine' 'Buss' 'Mcmillan' 'Guy'
#  'Allen-charles' 'Blackburn John D. Jr.' 'Nix' 'Rader'
#  'Quicksilver Aircraft' 'Hodre-buull-kolb' 'Ewertz' 'Troy' 'Underwood'
#  'Wilderoder' 'Haering Avid Flyer' 'William Jay Kinney'
#  'William John Schulz' 'Arnet Pereyra Aero' 'Coleman' 'Kilpatrick'
#  'Johannes-robert' 'Klotz' 'Alson G. Siler' 'Michael L. Luckey'
#  'Dinkel-brook Corp' 'Pinick' 'Walker' 'Wirth' 'Rotordyne' 'Wroblewski'
#  'Schwarzler' 'Van Grouw' 'Valenza' 'Wild Goose' 'Reichert' 'Diehl'
#  'Gentry' 'Glover' 'Spagnoletti' 'Nye' 'No American/rogers B L' 'Bosick'
#  'Pratt' 'Banting' 'Zdybel' 'Ismari' 'Giles' 'Lindstrand' 'Draper'
#  'Boeing - Canada (de Havilland)' 'Kendall/mckaughlin' 'Watkins'
#  'Eddie A. Smith' 'Mintz' 'Thomson' 'Luhnau' 'Howlett' 'Kenneth Miller'
#  'Loral Corp.' 'Godbout' 'Coughlin' 'Streifthau' 'Knox' 'Frederick'
#  'Statz' 'Oehling' 'Corbin/king' 'Cartercopters' 'Swertfeger' 'Rhea'
#  'Zielke' 'Quest Ii Walsh Ltd.' "O'hara Bob" 'Prudhomme' 'Eaa Chapter 229'
#  'Slater' 'Dana A. Moore' 'Mince' 'Stirling' 'Izatt' 'Lutes' 'Kitchens'
#  'Kretsinger' 'Cohen' 'Burak Stanley A' 'Aero Comp Inc' 'Trike'
#  'Aeronca-bubeck Irving' 'Mckinnis' 'Saab' 'Lockwood' 'Scovil'
#  'Bair Helicopters, Inc.' 'Birx' 'Stuart' 'Sportavia Putzer' 'Pagan'
#  'Owens/richburg' 'Weinzierl' 'Muxlow' 'Aero Design Eleven'
#  'Walden A. Cooper' 'Taylor Smith' 'Air & Space.' 'Hartline' 'Mccan'
#  'Loomis' 'Greenleaf' 'Brice' 'Emigh Aircraft' 'Hutchins' 'Cone'
#  'Smith Arthur Fox' 'Grunska' 'Noteman' 'Oveross' 'Ludeman' 'Morphew'
#  'Hing' 'Mclarty' 'Daniel A. Shapiro' 'Richard Shaffer' 'Gifford'
#  'Avions Mudry Et Cie' 'Heli-eagle Inc.' 'Cecil' 'Rosenvall' 'John Thomas'
#  'Kurzenburger Stuka' 'Rawdon' 'As+ (russia)' 'Geiling' 'Hilyard'
#  'Meadows' 'Eaton' 'Starduster Too' 'Froelich' 'Edgerly' 'Daniel J. Zoerb'
#  'Truthan' 'Bryant/rhodus' 'Curtis-wright' 'Lunn (vans)' 'Haessler'
#  'Rans Employee Flying Club' 'Hoye' 'Blanc' 'Schwarz' 'Mcclish'
#  'New Piper' 'Double D Enterprises' 'Davis/crouch' 'Europa Aviation Inc'
#  'Worldwide Aero Corp' 'Spurgeon' 'Kashan Michael' 'Mccann' 'Hartzell'
#  'Norton' 'Rowley' 'Creed' 'Staudacher Aircraft, Inc.' 'Helfer'
#  'Interavia' 'James Browning' 'Keith Kinden' 'Airbus' 'Chilian' 'Witlock'
#  'Warrington' 'Mead' 'Burton/boyton' 'Steel/vans' 'Floroski' 'Lutke'
#  'Jim Weseman' 'Fudold' 'Bohner' 'Cianchette' 'Halsmer' 'Comeau' 'Root'
#  'Ryskamp' 'Daniel J. Lee' 'Aero Tek, Inc.' 'Leslie Briggs' 'Romero'
#  'Kokenge' 'Kollier' 'Solo Wings' 'Showalter' 'Summers' 'Brown/morrison'
#  'Eachon' 'Hamer' 'Haskins' 'Barclay/vincent' 'Dickenson' 'Redsell' 'Ladd'
#  'Rosenbarger' 'Follmer' 'Foulke' 'Grooms' 'Triple S Aero Inc'
#  'Pulsar Aircraft Corp.' 'Trammell' 'Aerosports Connection' 'Clearwaters'
#  'Phelps' 'Freund' 'Fogerson Richard D' 'Perrucci Randall J'
#  'Cable-breigler' 'Flurry' 'Mockler' 'Mihlebach' 'Eugene L. Capozzi'
#  'Jack Mcdaniel' 'E. J. Humphrey' 'Worgull' 'Sikorsky/orlando' 'Rowe'
#  'Woodruff Lancair' 'Temco Luscombe' 'William J. Knowles'
#  'Alvin R. Kemmet' 'Joseph A. Grimaud' 'University Of Alabama' 'Holt'
#  'Moseler' 'Galaxy Balloons, Inc.' 'Harwell/gardner' 'Tolle'
#  'Arthur P. Matthews' 'Weste' 'Steven R. Jackson' 'Hallett'
#  'Craig R. Merrill' 'Jim Price' 'Bollinger' 'Camillo Annaloro' 'Fowler'
#  'Wildman' 'Raytheon' 'O Loughlin' 'John S. Eberle' 'Otero-pitts' 'Horne'
#  'Dever' 'J And J' 'Messerschmitt-boelkow-blohm' 'Lockheed-martin'
#  'Murdock' 'Gick' 'Collette' '2000 Mccoy' 'Landes/karich/schmidt' 'Larson'
#  'Grob' 'Cartercopter' 'Dehavilland' 'John D. Lueck' 'Larry Groover'
#  'Barackman Vans' 'Worldwide Aeros' 'Nord' 'Purvis/thorpe'
#  'Whittman Tailwind' 'Neely B D' 'S.n.i.a.s' 'Robert D. Wood' 'Fish'
#  'Sutton Tailwind' 'Western International' 'Flugzeugbau' 'Aero Vodochody'
#  'Michael E. Nourse' 'Landry' 'Schneider, Edmund, Pty.'
#  'Boeing Helicopters Div.' 'Gibbs' 'Bartels' 'Ascher' 'Eurocopter France'
#  'Meshko Zenair' 'Lenart' 'Avia Stroitel' 'Harlow' 'Vangilder'
#  'Larry R. Kinsey' 'Fox' 'Jacques J. Mistrot' 'Empson' 'Jerome Wells'
#  'Arnet Pereyra' 'Fobes' 'Sandell' 'Boyd Young' 'Arthur Lee Beer'
#  'David G. Holmes' 'Joe Underwood' 'Cap' 'Steen Aero Lab'
#  'Bensen Aircraft Corp.' 'Boykin B J' 'Knab-douglas' 'Perlick'
#  'Motley Vans' 'Maule Air Inc.' 'Leonard Walters' '1977 Colfer-chan'
#  'Kirchner' 'Baldwin' 'Brault' 'Garrett' 'Gideon' 'Blucher'
#  'Conrad Menzel' 'Geertz' 'Herriford' 'Russell Heyn' 'Musso' '2001 Mcgirl'
#  'Eaa Chapter 40' 'Stampe Et Renard' 'Noorduyn Aviation' 'Interplane'
#  'Torno' 'Packwood' 'Giackino' 'Cameron Balloons' 'Vanderbeek' 'Shaub'
#  'Patalivo' 'Broyles' 'Shanklin' 'Potez-air Fouga' 'Masko' 'Bowman'
#  'Kaines' 'Bucker-jungmann' 'Arctic Aircraft Corp.' 'Terminella' 'Mottier'
#  'Rudolph' 'Breiter' 'Chek' 'Melenyk' 'Houston' 'Garro' 'Griffith-boyd'
#  'Tibert' 'Johansen/thiessen' 'Sparks' 'Kenneth West' 'Floback'
#  'Cuevas, Orlando S' 'Laporte' 'Pitenpol Aircamper' 'Levitsky' 'Reitz'
#  'Aerostar International Inc' 'Raum' 'Druine' 'Mcdougall' 'Anderson'
#  'W. E. Simmons Max Air' 'World Helicopters' 'Pohl'
#  'Mitchell Aircraft Corp' 'Schnitz' 'Hutton' 'Veith' 'Payne'
#  'Kolb Twin Star' 'Mdhi' 'Mcintosh' 'Ag-cat Corporation' 'Schuchart'
#  'Charles' 'Holsclaw' 'Palmer/wilgus' 'Curtis-travel Air' 'Efaw'
#  'Morton S. Dismuke' 'Delbridge' 'Hauck' 'Dassault Aviation' 'Grice'
#  'Donald A Chiasson' 'Zacharius' 'Dominiak' 'Arctic Aircraft Co. Inc.'
#  'Schuetz Miniplane' 'Pdps Pzl-bielsko' 'Md Helicopters, Inc.' 'Humphreys'
#  'Hoskins' 'John Greenlee' 'Matey' 'Troy A. Woodland' 'Shank' 'Harter'
#  'Spears' 'Sparke' 'Jacobs' 'Andre' 'Gelasi' 'Colburn' 'Murray' 'Carver'
#  'Digimas' 'Slepcev' 'Von Claparede Clemen' 'Cameron Balloon'
#  'Aviastrottel' 'Rhoades' 'Ellsberg' 'Worner' 'Bok' 'Kainz' 'Edge'
#  'Woodrow Stolp-adams' 'Nicolosi' 'Irwin' 'Meester' 'Norton/cloeren'
#  'Fetherolf' 'Landoll' 'Bass' 'James D. Smith' 'Esbenshade' 'Vermeys'
#  'Schenfield' 'Lyon' 'Robert N. Gilmore' 'Vernon D. Pitts' 'Byrd'
#  'Whitty, Philip J.' 'Gillette' 'Convair Div. Of Gen. Dynamics' 'Heard'
#  'Vernon' 'Borgman' 'Farrand' 'Wolter' 'H.s. Mosley' 'Grandman'
#  'Louis Edmondson' 'Stiles' 'Quitzau, Carl' 'Cameron Balloons Us'
#  'Richard S. Anderson' 'Wilburn' 'Hillyer' 'Harleman' 'Robinette' 'Conrad'
#  'Bitton/sport Flight Aviation' 'Ellenberger/werner' 'Korsch' 'Knight'
#  'Saumure' 'Krejci' 'Gunderson' 'Unander' 'Bell/garlick' 'Moore Sammie'
#  'Skystar Aircraft Corp' 'Doyle' 'Trenti' 'Annis' 'Kopp Robert E' 'Potts'
#  'Stadden' 'Thornley' "Ultravia Aero Int', Inc." 'Douglas/basler' 'Betts'
#  'Gary L. Zeigler' 'Bozeman' 'Cox' 'Hoagland' 'Halfacre' 'Greg Grouleff'
#  'Woodley' 'Grote' 'Howard Harder' 'Lett R/campbell K' 'Brunger'
#  'Gallagher' 'Piper/cub Crafters' 'Fairchild Dornier' "D'apuzzo" 'Sierra'
#  'Yoder' 'Piper Aerostar' 'Glaser-dirks-flugzeubau' 'Mulligan' 'Aubrey'
#  'Nolan' 'Aero Partners One Llc' 'Taber' 'Wattier' 'Golden Circle Air'
#  'Paxhia' 'Schutte' 'Kendall, Blair' 'Cirrus Design Corporation' 'Golias'
#  'Frank Fitzgerald' 'Karl & Dot, Inc.' 'Helicopters & Airplanes, Inc.'
#  'Boucher' 'Galbraith' 'Harrison' 'Frennance' 'Bumgarner' 'Firm'
#  'Lindstrand Balloons' 'Hulle' 'Meeuwsen Gordon' 'Quinn' 'Castle'
#  'Wsk Pzl Swidnik' 'Murawski' 'Lidster' 'Howard Aircraft' 'Bar/curtiss'
#  'Fay' 'Seattle Aerotech' 'Infinity' 'Aune' 'Denzer' 'Waltz' 'Grenier'
#  'Mckean' 'Pank' 'Welborn' 'Kenneth Parmerter' 'Hale' 'Zawada'
#  'Bushby Aircraft' 'Jackie' 'Eskildsen' 'Cosmos' 'Bredl' 'Thurmond'
#  'Desimone' 'Micket' 'Mcconnell' 'Baughman' 'Gavilan' 'Bilgri' 'Eckstein'
#  'Wehrlen' 'Schempp-hirth K.g.' 'Aerostar International' 'Aurandt'
#  'Jackovich' 'Giroux' 'Kaminski' 'Crawford' 'Southworth' 'Williamson'
#  'Arns' 'Rare Aircraft' 'Corken/guillet' 'Menzies' 'Niemann' 'Hiperlight'
#  'Reviere' 'Hildebrandt' 'Pravecek Lawrence' 'Puhl'
#  'Eurocopter Deutschland Gmbh' 'Tomash' 'Clarence F. Callahan' 'Rebholz'
#  'Royse' 'Goff' 'Brooks' 'Huene' 'Reiley' 'Lockamy' 'Adler' 'Frank'
#  'Terning' 'Siemens' 'Minkler' 'Eells' 'Charles Maxted' 'Mikoyan Gurevich'
#  'Sabian' 'Paiement' 'Paige' 'Ronald Levee' 'Tanner' 'Golden' 'Kline'
#  'Madewell' 'Rutledge' 'Iv Inc.' 'Wondrasek' 'Carriere' 'Craig N. Moen'
#  'Laferriere' 'Mork' 'Hubbard' 'Arima' 'Riddell (lancair)'
#  'A Pair Of Jacks' 'John H. Heiring' 'Asmus' 'Ramsay' 'Hickman' 'Girard'
#  'Clyde K Carrier' 'Shepherd' 'Caron' 'Aaa Aircraft Leasing'
#  'Anderson Rotorway' 'Eurocopter Deutschland' 'Creekmore'
#  'Preceptor Aircraft' 'Lipscomb' 'Barber' 'Lonnie Johnson'
#  'Aircraft Mfg & Dev. Co. (amd)' 'Mielec' 'Farmer R B' 'Silvius'
#  'Raytheon Aircraft Company' 'Carlisle' 'Polsgrove' 'Havir'
#  'Classic Fighter Industries' 'Bornhofen' 'Rothrock' 'Gilbertson'
# ...
#  'WEAVER STANLEY R/ROBINSON SCOT' 'EVOLUTION AIR LLC' 'EXTRA FLUGZEUGBAU'
#  'THOMAS E HUDZINSKI' 'AMSTUTZ CURTIS J' 'ARCTIC AIRCRAFT CO INC'
#  'ROBERT HAMBLIN' 'AVIONS MUDRY CIE' 'JESS LLC' 'ERNEST T CHRISTLEY'
#  'TAPPEN CHRIS' 'REIMS AVIATION S.A.' 'KENNETH B HINES' 'SCHRODER DAVID'
#  'MALINOWSKI WALTER S' 'MAGNAGHI AERONAUTICA SPA' 'Michael S. Logan'
#  'PAUL R SEIPT' 'Bob Frederick' 'WILLIAM D TELFAIR/ZIA Z TELFAI'
#  'LEVY ADAM V' 'AG-CAT CORPORATION' 'MCKENNA' 'SPORTINE AVIACIJA'
#  'TURBO THRUSH' 'BELL-TELLIJOHN' 'GEFA-FLUG GMBH' 'AIRPARTS NZ LTD'
#  'PRESCOT E. WILKIE' 'WARD CHRISTOPHER BARRY' 'WELLS JOHN L JR'
#  'BUCKEYE POWERED PARACHUTES INC' 'AERO-ACE'
#  'BARNES RICHARD B/HOWE MICHAEL' 'JORDAN JOHN' 'URBANCZYK MIROSLAW'
#  'Nunley' 'SLIP STREAM' 'LAWRENCE O NOLTE'
#  'Airbus Helicopters Deutschland' 'CODY HAWKINS' 'SCHWEIZER(HUGHES)'
#  'RITTER JOHN I' 'CHICCO MIGUEL E' 'CHARLES J NORRIS' 'GERALD DONOVAN'
#  'CLARK JAMES T' 'JANSEN' 'SIMMONS GARY F' 'Endler Glasair/Glasair 1-TD'
#  'SPANI WAYNE M' 'PERNER/PITTS' 'Evolution 19' 'GOLDEN CIRCLE AIR'
#  'SALERNO KENNETH G JR' 'D & K AVIATION' 'MICHAEL DEAN GRISSOM'
#  'CIRRUS DESIGN' 'CANION MICHAEL W' 'APPLEGATE' 'KUBASSEK DAVID'
#  'RADFORD DARREL F' 'GILBERT THOMAS JEFFREY' 'MITCHELL DERRYLE V'
#  'BRITISH AIRCRAFT CORP.' 'HILLARD CHARLIE R' 'MCINTOSH DONALD W'
#  'MARK GOLDBERG' 'THOMAS J HANKAMP' 'RANDALL MARVIN L' 'JAMES D RIGGS'
#  'STEELE' 'MENZIMER GARY RAY' 'CHAPMAN' 'JAMES F HAKE' 'Michaelian'
#  'RALPH' 'ROGER M ALLEN' 'KING JOHN E JR' 'ROSE HERBERT D'
#  'CHARLES D WALKER' 'BRADLEY RODERICK W' 'AEROTECHNIK' 'BOYD BRUCE'
#  'MIke Reed' 'GREENE R/GREENE S' 'HOSTEIN K/HOSTEIN S' 'JAMES M RAULERSON'
#  'PAUL GAYWOOD E' 'Tukan' 'PACIFIC AEROSPACE LTD' 'HUNTER GEORGE'
#  'KERR GERALD' 'WALKER EDGAR E' 'DEDEAUX GARY G' 'CROFT ROBERT C'
#  'LEONARDO' 'JEFF JARDINE' 'COBALT AIRCRAFT INDUSTRIES INC'
#  'RUDDER DWIGHT K' 'CHANCEY GERRY M' 'SHINER' 'RANS INC'
#  'Mooney Aircraft Corporation' 'MILLER STEVEN M' 'PARKS RICHARD A'
#  'AIRMAX CONSTRUCOES AERONAUTICA' 'RUDBERG TODD W' 'Trudel' 'DJI'
#  'THOMAS J MURRAY' 'Godwin Jeff E' 'HENCKEN WILLIAM' 'SC AEROSTAR SA'
#  'MCMILLAN JOEL L' 'BUSCHMANN/VANZEE' 'EMERSON' 'BRAD J BATES'
#  'Eris E. Ervin' 'BELLET JAMES J' 'HICKOX ANDY' 'CHARLES A BRAZIL'
#  'FREEMAN HERITAGE COLLECTION' 'SCHAFFER' 'THOMAS STEPHEN'
#  'BRYANT C CROSBY' 'BOROM MARCUS P' 'FLEETWOOD JACK' 'RUSSELL E OBERG'
#  'WESTERN INTERNATIONAL AVIA INC' 'HIMSL VINCENT S' 'BARBER WARREN D'
#  'AVID' 'THOMAS G PARKHURST' 'Peterson Lancair' 'STAUDACHER JON'
#  'Flugzeugproduktions-und Vertri' 'SIX CHUTER WEST LLC' 'JOHN A BREWER'
#  'STILL MICHAEL J' 'METCALFE ROBERT B' 'MAURER ELMO A' 'RIGGS KENNETH W'
#  'CLOUD JEFFREY FERRELL' 'VANDERARK' 'HOMER' 'JOHN ROSCOE' 'RUTTEN PHIL J'
#  'BUEHLMANN PETER' 'KARPAYEV VLADYSLAV V' 'DOSHIER WILBERT A'
#  'PIPER / LAUDEMAN' 'MOTLEY GARY W' 'DRIGGERS QUILLAN E' 'TODD FOLEY'
#  'Kevin Leue' 'WEAVER DAVID A' 'BROCK STEINER' 'JONES KENT C'
#  'MICHAEL ADAMCZYK' 'Czech Sport Aircraft a.s.' 'CORBEIL SHAWN'
#  'HALLEY KFT' 'GRAY JIM ROBERT' 'Piaggio' 'BROWNING GREGORY S'
#  'KELLEY DERRICK/LEZA' 'X-AIR LLC' 'Construcciones Aeronauticas'
#  'BARNES STEVEN D' 'Gulfstream Aerospace LP' 'Just' 'DAYTON A DABBS'
#  'HARROP BLAKE' 'GELDERMANN BERT E' 'BRYK STEVEN L' 'TOMLINSON TRACY L'
#  'Zodiac' 'MATHENY LARRY E' 'SKWIRA MATTHEW J' 'QUARTZ MOUNTAIN AEROSPACE'
#  'FOXFLY INC' 'VERTICAL AVIATION TECHNOLOGIES' 'WAYNE MILLER'
#  'GREGORY NEWMAN' 'SOMERTON DAVID J' 'HENDERSON' 'BAKER VICTOR R'
#  'SKYRUNNER' 'SHANKS V ROGER' 'OLIVER LAWRENCE R' 'HASTINGS THOMAS G'
#  'BEECH AIRCRAFT CO.' 'SCHEINEMAN-VAN BUREN' 'SOKO' 'ROBERT SNYDER'
#  'MACDONALD CRAIG' 'REILLY CHARLES W' 'Bereznak' 'JOHNSON GERALD'
#  'LYONS ROBERT' 'BESARICK' 'LITHUANIAN FACTORY OF AVIATION' 'PFLUGRADT'
#  'MILLS MICHAEL' 'FLIGHTWORKS CORP' 'FAIRCHILD FUNK' 'LYNN PERRY'
#  'ANDERSON DARRELL L' 'STANLEY' 'Terry G. Olson' 'AMES ANGIER M' 'Ragle'
#  'SASSER ALLEN L' 'CARR B L' 'HAWLEY RICHARD' 'PAGE RUSSELL L' 'S.Z.D.'
#  'SMITH DENNIS P' 'WITTMAN' 'BORDIUK' 'STONE JAMES R' 'WILHELM'
#  'STANLEY ERNIE SIGURD' 'KEN OLSON' 'IRVIN STEPHEN D' 'BROWN JOSEPH'
#  'HEARD ALAN E' 'WELLS ELGIN M' 'WOLFE' 'L-BIRD LLC' 'SENO LOUIS C SR'
#  'AMERICAN AIR RACING LTD' 'MICHAEL R ALEXANDER' 'HARTLINE J BON'
#  'LAMINAR' 'BERGER BERNARD M' 'PZL SWIDNIK' 'CHRISTOPHER LORD' 'BELAIR'
#  'CREECH JERRY' 'BARRY MAGGIO' 'DIVEN ROBERT' "JETSON'S AVIATION LLC"
#  'WITTMAN D R/WITTMAN D M' 'AEROPRO CZ S R O' 'PEET CHARLES'
#  'Roger G White' 'I.C.A.-BRASOV (ROMANIA)' 'Davidson, Ronald A.' 'Rhoads'
#  'James Donald Baker' 'SPORTAVIA PUTZER' 'GARCIA BENIGNO' 'JAMES WIEBE'
#  'DEVRIES WM H' 'MORRISON MARVIN E JR' 'COSENTINO GAREY A'
#  'ZS DELTA-BIELSKO WROCLAW' 'ELDRIDGE GEORGE' 'LITE FLIGHT' 'JIM GREEN'
#  'IRLBECK THOMAS H' 'SORENSEN DANNY S' 'MASON HAL J' 'GIPPSAERO PTY LTD'
#  'DOBBS GEORGE' 'BRYAN C L/LABRASH R D' 'ASTON KINSEY' 'DAN JELINEK'
#  'RGJ AVIATION LLC' 'CRAIG A REED' 'SCHEMPP HIRTH FLUGZEUGBAU GMBH'
#  'SIBILA' 'SAFARI' 'Schempp Hirth' 'ROBERT MILES' 'Best Off'
#  'HONDA AIRCRAFT CO LLC' 'SCHEMPP-HIRTH FLUGZEUGBAU GMBH' 'WHITTMAN'
#  'Aero Eli Servizi' 'Curtiss Wright' 'Toomey' 'MICROLITES PTYLTD'
#  'WAYNE D. TEEL' 'LAVIA ARGENTINA S.A.' 'ALLEN W INKS' 'HERZOG AVIATION'
#  'BUCHANAN' 'Gerald Dan Coppock' 'ICP' 'WALTER C SMYTHE' 'DELL LAWRENCE'
#  'AIRGYRO AVIATION LLC' 'Qac' 'LAZAIR' 'Kawasaki Heavy Industries Ltd.'
#  'STEMME' 'Blue Oak LLC.' 'James E Causey' 'HARBIN' 'Stoddard Hamilton'
#  'AIRTIME' 'Aero Designs' 'LANCE M HOOLEY' 'Eggleston Daniel'
#  'MD HELICOPTERS' 'Guimbal' 'Bosko Wr/Bosko Ce' 'HALLADAY ROY'
#  'HIMMEROEDER HANSGEORG' 'Edward R. Sugg' 'ROBERT L Coons' 'GRUBER'
#  'COLUMBIA AIRCRAFT Mfg' 'Schweizer 300CBi' 'Honda Aircraft'
#  'RAYMON A. KING' 'BEARDEN BIPLANE' 'Kreling' 'RIchard Silva' 'SA300'
#  'HARGROVE' 'CAPITAL HOLDINGS 226 LLC' 'LEROUX JOHN F' 'Airplane Factory'
#  'MUSTANG' 'Audenried' 'Poberezny' 'Eugene Wells' 'ULTRALITE SRO' 'BKF'
#  'Silveira Jonathan A' 'SCOTT TAYLOR' 'Darren M. Vinelli'
#  'CLIFFORD E MASSEY' 'Saberwing' 'Czech Sport' 'BRM Aero'
#  'Robert R. Reiland' 'Hill Group LLC' 'Britten Norman' 'EMMET SMITH'
#  'Airborne Windsports' "Van's Aircraft" 'STOL Aircraft Corp'
#  'Warner Aerocraft' 'REMPE' 'OSTERTAG WALTER G' 'James A Gray' 'Pereira'
#  'APOLLO' 'HOGAN' 'DENNIS l ZUMBALT' 'FISHER FLYING PRODUCTS' 'MARLOW'
#  'MORAVAN' 'EPIG' 'BERKEY' 'GASKINS' 'MORRISON ROCKY V' 'Europa' 'Kubicek'
#  'Kaminskas' 'Tubbs S/Performance Air Inc' 'NORTHROP' 'BARROWS' 'ACRO'
#  'TL Ultralight SRO' 'PAVEL VAGNER' 'STORCH' 'OTTERBACK' 'Gippsland'
#  'ALLIANT AVIATION' 'HANSON' 'Elmwood' 'Jordan Valley Llc' 'JM Kemp'
#  'Vought' 'RYAN JOHN STEFFEY' 'CHISTOV' 'RAND ROBINSON'
#  'RATHEON AIRCRAFT COMPANY' 'Bradshaw / McCauley' 'S.A.N.' 'DARYL BAKER'
#  'DAVID S MEEK' 'DALE BERKBIGLER' 'AURORA' 'Alisport' 'LOCKWOOD'
#  'DAVID SHOTWELL' 'S M & T Aircraft' 'GRIFF' 'AgustaWestland' 'JAMES'
#  'KARNS' 'Trella' 'Quicksilver Aircraft Northeast' 'KIRK ELLIS WENDELL'
#  'Flightstar Sportplanes' 'Howard Steven C' 'Rolladen Schneider' 'SKYBolt'
#  'Textron Aviation' 'Merit Aviation Llc' 'DONALD BERNARD HIGGS' 'HI-MAX'
#  'GIbb' 'Icon' 'AIRvan' 'Biuro Projektowe B Bogumil Ber' 'Thomas Wild'
#  'WILLIE BENNETT' 'CASHEN' 'Bolkow' 'BRUMBAUGH DAVID R' 'Judd'
#  'VALLDEJULI JOHN A' 'RIchards Heavylift' 'Stoddard-Hamilton' 'ICON'
#  'Liberty Aerospace' 'JONKER SAILPLANES' 'Reims Aviation Cessna' 'CAPES'
#  'AutoGyro' 'Textron Aviation Inc' 'GIger Frank R' 'SHIRLEY CARL'
#  'MORIARTY MARVIN' 'Capella' 'DG Flugzeugbau' 'SCODA AERONAUTICAL' 'HALL'
#  'Phantom Aeronautics' 'Infinity Power Parachutes' 'COZY' 'Pzl Okecie'
#  'THOMAS LEE' 'GEORGE W. FELIX' 'SILVERLIGHT AVIATION LLC' 'Pavel Vagner'
#  'Reed Mike' 'HONDA AIRCRAFT' 'Bede' 'FOXWORTHY RICK A'
#  'WINGTIP TO WINGTIP LLC' 'LLEWELLYN, WARWINC W' 'AutoGyro GmbH'
#  'Kitty Hawk' 'RICHARD B CARPENTER' 'Czech Sport Aircraft'
#  'HIGGINS JOHN H/WILLIAMS JOHN D' 'PAVEL' 'New Glasair'
#  'SYMPHONY AIRCRAFT IND INC' 'Czech Aircraft Works Spol Sro' 'SKYSTAR'
#  'Bae' 'JAVRON' 'Rotary' 'OAS' 'PARSONS' 'Angel Aircraft Corporation'
#  'JOHN Sample' 'TEAM ROCKET F-1' 'Thunder Mustang' 'REims'
#  'Michael A. Watson' 'MAGNI' 'Airborne America' 'MERWIN' 'Aviastroitel'
#  'LAVIA ARGENTINA' 'Orlican' 'INNOVATOR' 'Lightning Avion Eab LLC' 'RAF'
#  'American Legand Aircraft' 'AugustaWestland' 'BOWER'
#  'Rotorcraft Development Corpora' 'WAG-AERO' 'RANS S-12'
#  'Pipistrel Italia SRL' 'Buckman' 'HOLMGREN' 'FLIGHTstar'
#  'Czech Sport AIrcraft' 'Keuthan Aircraft Corp' 'DAYTON-WRIGHT' 'MUDRY'
#  'N126C LLC' 'Daher' 'Osprey 2' 'Rhoads, Larry E' 'CSP Leasing LLC'
#  'Magni' 'Team' 'DAHER' 'COYOTE' 'North Wing UUM INC' 'CHAD LEWIS'
#  'AMERICAN Champion' 'Cub Crafters Inc' 'Thatcher' 'CAPELLA'
#  'KOSTRAZEWA ANDRE' 'Volmer' 'LANKENAU' 'CONDOR'
#  'Air Creation/Sides Rick A' 'QUICKIE' 'NEW KOLB AIRCRAFT CO LLC'
#  'FURLONG' 'Kade' 'Seele' 'Parachute Icarus' 'MONTANA'
#  'AMERICAN EUROCOPTER' 'Robert D Carr Jr' 'GREG MILLER' 'WAG AERO'
#  'DAKOTA' 'ROTORSPORT UK LTD' 'PERFORMER' 'Siebel' 'Uskoski' 'McSwain'
#  'TEAM ROCKET' 'Arrow-Falcon Exporters, Inc.' 'AVIAMILANO' 'Jewett'
#  'COMMANDER' 'Pilatus Aircraft' 'DEROUSSE' 'PIK'
#  'RAVEN AIRCRAFT CORPPRATION' 'Thrush' 'ANG' 'STEPHENS WILLIAM E' 'CZECH'
#  'KJOSTAD JORGEN A' 'Sparrowhawk' 'Ralph C Kimball' 'Robin' 'Muse'
#  'Aero Bristell' 'CCX-2000-0081 LLC' 'Carbon'
#  'REMOS AIRCRAFT GMBH FLUGZEUGBA' 'Rotorsport UK' 'Zlin Aviation' 'CO Z'
#  'Blevins Kamron' 'Hutson' 'FORD STEPHEN L' 'Anthony Mattioli'
#  'AFICIONADO' 'Eclipse' 'SilverLight Aviation LLC' 'Express'
#  'WALTON DANIEL J' 'EMBRAER SA' 'MOONEY INTERNATIONAL CORP'
#  'CREEK MICHEL W' 'Plante' 'Randy Wayne Maloney' 'Heckel' 'Zenair Zodiac'
#  'RIVERS LINDSEY LEE' 'ABBETT GERRY' 'AGUSTAWESTLAND PHILADELPHIA CO'
#  'GATES LEARJET CORP' 'BABENCO HENRY D.' 'TURCOTTE JR ROBERT L'
#  'STEINMAN MARK E' 'DASSAULT AVIATION' 'M7 Aerospace'
#  'GEORGE MATTHEW WAGONER' 'Airbus Helicopters' 'Wag-a-Bond Traveller'
#  'VASHON AIRCRAFT' 'AERMACCHI' 'POST' 'PHILLIP B ROLLS' 'Honda'
#  'SCHEMPP-HIRTH K G' 'BURG FREDERICK S' 'DAVIS DAN B' '777'
#  'JABIRU USA SPORT AIRCRAFT' 'Rotorway Executive' 'MAGNUS AIRCRAFT LLC'
#  'Destiny Powered Parachutes' 'FORISCH EDWARD' 'ROWE DENNIS A'
#  'HINE T L/JOHNSON R' 'THRUSH AIRCRAFT LLC' 'BRYAN S HAPPELL'
#  'DAVIS DONALD M' 'FIREFLY BALLOONS 2010 INC' 'MICHAEL J ROBBINS'
#  'Spitfire' 'Mobi-light' 'MEYERES F L/MEYERES M M'
#  'PRECISION HELICOPTERS LLC' 'ULTRAMAGIC S A' 'JABIRU AIRCRAFT PTY LTD'
#  'ISRAEL AEROSPACE INDUSTRIESLTD' 'MARQUART' 'Storm Fury' 'Legacy'
#  'RICHARDS HEAVYLIFT HELO INC' 'DOUGLAS K THOMPSON' 'VARNER DAVID L'
#  'PAGE JOSEPH E' 'Harry Crosby (Vans)' 'GOODSELL LYNN A' 'ROBERT TREMBLY'
#  'MCCLURE B J' 'John M Corneal' 'MUNSON ROGER J' 'BHI H60 HELICOPTERS LLC'
#  'MARK COBY' 'PHILLIPS RALPH W' 'PZL Warszawa-Okecie' 'MAXSON PHIL'
#  'WESTON JAMES' 'KEVIN LIPPERT' 'GARRISON RONALD L' 'COVEY'
#  'ANTENOR VELAZCO' 'TONY DUBEANSKY' 'SCOTT VALDEZ' 'WARE JERRY L'
#  'BOLSTRIDGE WALLACE R' 'VINING JOHN K' 'AIRBORNE AUSTRALIA'
#  'DEWSNUP DAVE' 'Cabri' 'FERACA EDWARD M' 'CURNUTT ELTON E'
#  'SilverLight Aviation' 'WHEELER C / WHEELER K' 'Earthstar Aircraft'
#  'SWANN LYNN J' 'Focke-Wulf' 'MYRON OLESON' 'ESLINGER C W/ESLINGER S M'
#  'SCOTT MILLS' 'PAYNE STEVEN R' 'BAILEY N MOYES' 'Joplin'
#  'DEHAVILLAND CANADA' 'GARY JAMES LAIL' 'TURBINE CUBS OF WYOMING LLC'
#  'Madera' 'RICHARD S CARPENTER' 'Driver' 'KEVIN P STOLHAMMER'
#  'MILLSAP DENNIS' 'Borom' 'STEPHEN L KRUER' 'Aerospool' 'TUCKER TIMOTHY E'
#  'KUYKENDALL CHARLES' 'ALEXANDER VAGNER' 'WEISS DENIS' 'HpH, Spol. S.R.O.'
#  'LITEFLITE PTY LTD' 'LARRY H SLIGAR' 'ALASKAN AIR ADVENTURES LLC'
#  'COMCO IKARUS' 'ROTARY' 'MARLOWE THOOFT' 'LORAH ELDEN A' 'SUPERMARINE'
#  'COLLINS ROBERT S' 'HALEY' 'Flying K Enterprises' 'STOUT GARRY V'
#  'DIAMOND AIRCRAFT INDUSTRIES' 'Hummer' 'SCHMITT' 'MANTOOTH'
#  'SEGARRA LUCAS JR' 'KLAPP PETER A' 'AVE STEPHEN' 'JOEL A BOWKER'
#  'MONNETT' 'BULFER JAMES G' 'HERRICK DAVID A' 'Quad City Ultralight'
#  'SPROUL KEITH A' 'GORDON SCOT A' 'Bely' 'COLE PAUL B' 'Fonville'
#  'MICHAEL W MORGAN' 'George A. Thiel' 'WYDER ROBERT G' 'BACH JOSEPH E'
#  'SHARP RALPH R' 'DOAN VERNON D' 'Hélicoptères Guimbal' 'CULP JOHN S'
#  'Tandem' 'Soneral' 'RICHARDSON ANDREW P' 'SEA & SKY INC' 'ZUBER THOMAS P'
#  'Rotoway International' 'BEVILACQUA JEFFREY L' 'Cavalier'
#  'RANDAL C REIMER' 'Z-HI-MAX' 'GREGG ORIGER' 'HALL TERRENCE / HALL CATHIE'
#  'JACK A FROHBIETER' 'SANTA FE AIRCRAFT LLC' 'GERALD JONES' 'Issitt'
#  'ERIC A MUNZER' 'Just Aircraft LLC' 'PHOENIX AIR SRO' 'K COPTERS'
#  'JAHNKE LIONEL G' 'ELVIN JACK R JR' 'LEONARDO SPA' 'RAY EARL D'
#  'SYRACUSE V F/SYRACUSE C D' 'MONTE CLARK' 'MICHAEL V CRANFORD'
#  'CHR International' 'American Legend Aircraft Compa' 'Mini-MAX'
#  'CAMERON BALLOONS U S' 'Cruiser' 'CHARLES C MENGER JR' '2021FX3 LLC'
#  'WALTER TACHIKI' 'LEACH MICHAEL' 'MILLER ROGER' 'WIGHT ALBERT A'
#  'BLAKE D BARRYMORE' 'Christavia' 'JOBY AERO INC'
#  'EMBRAER EXECUTIVE AIRCRAFT INC' 'CHRISTOPHER P GAGE'
#  'MOYNIHAN RICHARD D' 'SHELTON JOSEPH G' 'MCKENZIE JOHN P'
#  'Darrell D. Dugger' 'SPANGENBERG' 'ROSS JONATHAN' 'DISTAR CZ AS'
#  'GREGORY S MILLER' 'AXELL CHARLES L' 'Honda Jet' 'RAVIRAJ MOHIL'
#  'TUTTLE BRUCE C' 'S D MARTIN' 'SIKORSKY AIRCRAFT CORP' 'DWYER MICHAEL D'
#  'HARTZ PAUL' 'NORDQUIST RICHARD A' 'PARADISE AIRCRAFT USA LLC'
#  'Sparrow Hawk' 'ADAMS DENNIS ALLEN' 'SACHSE STEPHAN' 'FPNA'
#  'FERNANDES DALE R' 'BARBER ROBERT L' 'HENDERSON CLIFFORD S'
#  'PF CUB FLYERS LLC' 'HENRY L BERRIER JR' 'DIETRICH RYAN'
#  'ADAMS BALLOONS LLC' 'EUROPA' 'STODDARD HAMILTON' 'SAWBY SCOTT'
#  'PIPER-HARRIS' 'Kodiak' 'SUPERIOR' 'BEARHAWK'
#  'KYLE M SWARD / LARRY W SWARD' 'CHARLES R KYLE' 'BLUE SIDE UP INC'
#  'JUSTICE FRANK K' 'WINGREN NORMAN' 'QUICKSILVER AIRCRAFT CO'
#  'SPARKS RALPH A' 'PYKA INC' 'TWENTY SECOND STREET LLC'
#  'EASTABROOKS JOHN T' 'BRUCE R PROUSE' 'FRAZIER ROBERT L'
#  'CO-Z DEVELOPMENT CORP' 'GRUMMAN AMERICAN AVN. CORP'
#  'VAN LEHN RICHARD GLENN' 'FOSTER WILLIAM D' 'Cessna Aircraft Co.'
#  'MEYER FRED J' 'FAHEY WILLIAM J' 'MCDANIEL JAMES D' 'BOYLE JOSEPH E'
#  'SHEA' 'HPH SPOL SRO' 'AMD' 'WALTER S JOHNSON III' 'BURRILL STEVEN E'
#  'PEPPERD GREG J' 'WHITTRIDGE RICHARD D' 'CRAWFORD JAMES R'
#  'BAKER EUGENE L' 'Hawker Aircraft Ltd' 'ROBERT FITTS' 'OSPREY' 'Bucker'
#  '737' 'JAMES C GEYMAN' 'GMK VENTURES LLC' 'BLACKSHAPE' 'Believer'
#  'KAKELDEY RONALD O' 'Rotorsport UK Ltd' 'Cassult Racer'
#  'ARNOLD J/JONES D L' 'SPAUR CHARLES' 'GEIST DONALD R' 'DUFFY RUSSELL A'
#  'STUCKY STEVEN D' 'ALLAN G PIXLEY' 'VICKERS-SLINGSBY'
#  'MXR TECHNOLOGIES INC' 'EASTER WILLIAM C' 'KNIGHT' 'JUST'
#  'UNITED CONSULTANTS' 'Columbia Helicopters' 'VULCANAIR'
#  'WHITTEN ROBINSON' 'MILLER-THORP' 'HOLLAND MIKE' '5 RIVERS LLC'
#  'HOLLIER B C' 'MESCHLER GARY R' 'C A S A' 'SONEX AIRCRAFT' 'ICP SRL'
#  'HARVEY J BROCK' 'drone' 'C M STUHRENBERG/P C POLETE' 'SHORT'
#  'HOFFMAN DAVID J' 'GODDARD DICK SIM' 'THOMAS WAYNE L' 'STUCKER GARY'
#  'Uvify' 'FALL MARTIN' 'JACKSON DENNIS' 'Boeing (Stearman)'
#  'FLIGHT DESIGN GENERAL AVN GMBH' 'RAY E ROBERTS' 'Javron Experimental'
#  'LEON E EVERETT' 'BELL TEXTRON CANADA LTD' 'STORY CHARLES BRAD'
#  'SUTPHIN JOHN E' 'HISSERICH NICHOLAS S' 'BUXBAUM MARK EDWARD'
#  'CONWAY PHILIP J' 'OWEN KINGSLEY B' 'KNOTT VERNON W'
#  'GATES LEAR JET CORP.' 'AUTOGYRO USA LLC' 'PIPISTREL ITALIA S R L'
#  'MCKENNA GLEN R' 'WILLIAM L BELL' 'SKILES KENNETH C' 'KUMHYR DAVID B'
#  'JACQUNEAUX GLEN R' 'WREN RONNIE D' 'SLIPSTREAM' 'EVEKTOR' 'ANGUS WATT'
#  'MOSSMAN MICHAEL D' 'MERIWETHER JON' 'Wagaero' 'HIBBARD NORMAN E'
#  'HARTUNIAN ROBERT' 'AIRGYRO' 'ARTER WARREN' 'SHIREY DAVID A'
#  'MARY ALEXANDER' 'SEABOURN SCOTT R' 'SCODA AERONAUTICA LTDA'
#  'CORNFORD CRAIG H' 'AAA AIRCRAFT LLC' 'SEAMAX AIRCRAFT' 'Swensen'
#  'WASZAK ARTHUR B' 'GREEN L/GILNER D' 'KINGERY MICHAEL C' 'YATES MIKE E'
#  'ST CLAIR DAVID L' 'EVANS JAMES JAY' 'MCGLAUGHLIN RICHARD'
#  'AEROPRAKT MANUFACTURING SP ZOO' 'BALCOMB KENNETH C III' 'PERYERA ARNET'
#  'SCOTT TERRY G' 'RHINEHART' 'STEPHEN J HOFFMAN' 'SCHMIDT RANDALL M'
#  'ECLIPSE AEROSPACE INC' 'Hagerty' 'AIRBORNE WINDSPORTS' 'PIPISTREL D O O'
#  'MULHOLLAND ROBERT A' 'DETRICK DONALD G' 'SEACE DAVID A'
#  'DANIEL ANTHONY PROCTOR' 'CHILDS MICHAEL  A' 'PHANTOM' 'GREG HOBBS'
#  'JAMES R DERNOVSEK' 'ORLICAN S R O' 'ROYSE RALPH L']

# %%
#this is a copy of 'aviation_data' with the missing values replaced
aviation_make_filled = aviation_data_clean.fillna({'Make':'UNKNOWN'}) #for all na values in the make column changes na->UNKNOWN
aviation_make_filled.head()

# %%
aviation_data_clean['Model'].value_counts()
# Out:
# 152                     2367
# 172                     1756
# 172N                    1164
# PA-28-140                932
# 150                      829
#                         ...
# CASA 1-131E                1
# 2T1A2                      1
# Stoddard HamiltonSH3       1
# SZD 51-1 Junior            1
# FOKKER DR-1                1
# Name: Model, Length: 12318, dtype: int64

# %%
#using value counts to check categorical feature's distribution
aviation_data_clean['Injury.Severity'].value_counts()
# Out:
# Non-Fatal    67357
# Fatal(1)      6167
# Fatal         5262
# Fatal(2)      3711
# Incident      2219
#              ...
# Fatal(68)        1
# Fatal(35)        1
# Fatal(31)        1
# Fatal(55)        1
# Fatal(47)        1
# Name: Injury.Severity, Length: 109, dtype: int64

# %%
for x in aviation_data_clean:
    #save the Injury.Severity to a variable
    fatality_injury = x['Injury.Severity']
    
    #extract the incident type and make true or false?
    fatality_binary = int(falatity_injury['True'])
    
    #add the incident year and month to each row in aviation_data_clean
    x['fatality_binary'] = fatality_binary

# %%
for x in aviation_data_clean:
    #save the document date to a variable
    string_date = x['Event.Date']
    
    #extract the incident year and month from the string, and cast to int
    incident_year = int(string_date[0:4])
    incident_month = int(string_date[5:7])
    
    #add the incident year and month to each row in aviation_data_clean
    x['incident_year'] = incident_year
    x['incident_month'] = incident_month

# %% [markdown]
# My logic
#
# We have a lot of data and the first step is to consider which variables best support conclusions that will produce actionable recommendations; these will be the focus of my investigation. Due to time constraints, I will be first consider variables with more complete data.
#
# The variable that stands out to me as the independent variable is make and model of various aircrafts. The dependent variables that I think will best inform on safety are 'Fatality', 'Damage to Plane', and level of injury. Correlations found from these data will be crucial in making an informed decision around which aircrafts to purchase because they most directly relate to the loss of human life.
#
# However, I will address in my final summary other variables that can impact safety or partially explain the accidents.

# %% [markdown]
# # Data cleaning
#
# In this section, I will next the make, model, and fatality columns to make a new DataFrame where a percentage fatality can be calculated that is not biased on the number of samples in this particular data set.

# %% [markdown]
# Now, I'll prepare the dataframe for further analysis. I'll fix the missing value issue only for the columns I intend to use later and I'll update empty cells consistently with the way unknown values are treated in their respective columns.

# %%
#check for duplicates
#check for null values/missing/placeholder values
#check data types, make sure that they are consistent
#decide if any rows should be removed
#summary info()
#calculate the % fatality

# %% [markdown]
# # Visualizations and Insights
#
# Do I reference Tableau? How to I include it in jupyter notebook? Do I have the option of matplotlib or seaborn?
#
# #narrate graph and variable choices for each visualtization thoughout section.
# #describe what I'm seeing on each graph and what it means

# %% [markdown]
# # Conclusion and Future Work
#
# ## Summary of findings
#
# ### Fatality
#
# ### Aircraft Damage
#
# ### Level of injury
#
# ## Actionable Insights
#
# ## Future Work
#
# As next steps, I would suggest the following:
#
#     1.
